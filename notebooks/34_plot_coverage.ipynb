# %% [markdown]
# https://bedtools.readthedocs.io/en/latest/content/tools/genomecov.html

# %% [markdown]
# ## -d Reporting “per-base” genome coverage
# Using the -d option, bedtools genomecov will compute the depth of feature coverage for each base on each chromosome in genome file provided.
#
# The “per-base” output format is as follows:
#
# chromosome
#
# chromosome position
#
# depth (number) of features overlapping this chromosome position.

# %% [markdown]
# ## -bg Reporting genome coverage in BEDGRAPH format.
# Whereas the -d option reports an output line describing the observed coverage at each and every position in the genome, the -bg option instead produces genome-wide coverage output in BEDGRAPH format. This is a much more concise representation since consecutive positions with the same coverage are reported as a single output line describing the start and end coordinate of the interval having the coverage level, followed by the coverage level itself.
#
# For example, below is a snippet of BEDGRAPH output of the coverage from a 1000 Genome Project BAM file:

# %% [markdown]
# -----

# %% [markdown]
# plot bedgraph in R

# %% [markdown]
# get bedgraph of pseudo count

# %% [markdown]
# ```
# %%bash
# head /data/reddylab/Kuei/out/CombEffect_STARR/data/Input1_chr17.bedgraph
# ```
#
# ```
# chr17	201123	201160	1
# chr17	201160	201202	2
# chr17	201202	201259	3
# chr17	201259	201366	4
# chr17	201366	201925	5
# chr17	201925	201968	4
# chr17	201968	202052	3
# chr17	202052	202074	2
# chr17	202074	202130	1
# chr17	206174	206269	1
# ```

# %%
suppressMessages(suppressWarnings(source("config.R")))

# %%
cnames = c("Chrom", "Start", "End", "Depth")
ctypes = c(col_character(), col_double(), col_double(), col_double())

dat = read_tsv(
    "/data/reddylab/Kuei/out/CombEffect_STARR/data/Input1_chr17.bedgraph", 
    col_names = cnames, 
    col_types = ctypes,
    n_max=5)

# %%
dat
# Out:
#   Chrom Start  End    Depth
# 1 chr17 201123 201160 1
# 2 chr17 201160 201202 2
# 3 chr17 201202 201259 3
# 4 chr17 201259 201366 4
# 5 chr17 201366 201925 5

# %%
options(repr.plot.height=5, repr.plot.width=10)

gpt = ggplot(dat, aes(xmin=Start, xmax=End, ymin=0, ymax=Depth)) 
gpt = gpt + 
    geom_rect() + 
    labs(x="Genome (chr17; hg38)", 
         y="Fragment Index", 
         title="Unique STARR-seq fragment sorted by start position") +
    theme_bw() +
    theme(
        title      = element_text(size=17),
        axis.title = element_text(size=15),
        axis.text  = element_text(size=12)
    ) + 
    xlim(201120, 201950)
gpt
# Out:
# plot without title

# %%
cnames = c("Chrom", "Start", "End", "Depth")
ctypes = c(col_character(), col_double(), col_double(), col_double())

dat = read_tsv(
    "/data/reddylab/Kuei/out/CombEffect_STARR/data/Input1_chr17.bedgraph", 
    col_names = cnames, 
    col_types = ctypes)

# %%
options(repr.plot.height=5, repr.plot.width=10)

gpt = ggplot(dat, aes(xmin=Start, xmax=End, ymin=0, ymax=Depth)) 
gpt = gpt + 
    geom_rect() + 
    labs(x="Genome (chr17; hg38)", 
         y="Fragment Index", 
         title="Unique STARR-seq fragment sorted by start position") +
    theme_bw() +
    theme(
        title      = element_text(size=17),
        axis.title = element_text(size=15),
        axis.text  = element_text(size=12)
    )
gpt
# Out:
# plot without title

# %%
options(repr.plot.height=5, repr.plot.width=10)

gpt = ggplot(dat, aes(xmin=Start, xmax=End, ymin=0, ymax=Depth)) 
gpt = gpt + 
    geom_rect() + 
    labs(x="Genome (chr17; hg38)", 
         y="Fragment Index", 
         title="Unique STARR-seq fragment sorted by start position") +
    theme_bw() +
    theme(
        title      = element_text(size=17),
        axis.title = element_text(size=15),
        axis.text  = element_text(size=12)
    ) + xlim(8148987, 8159379)
gpt
# Out:
# Warning message:
# “Removed 1188134 rows containing missing values (geom_rect).”
# plot without title

# %%
cnames = c("Chrom", "Start", "End", "Depth")
ctypes = c(col_character(), col_double(), col_double(), col_double())

dat = read_tsv(
    "/data/reddylab/Kuei/out/CombEffect_STARR/data/TFX2_Dex_chr17.bedgraph", 
    col_names = cnames, 
    col_types = ctypes)

# %%
options(repr.plot.height=5, repr.plot.width=10)

gpt = ggplot(dat, aes(xmin=Start, xmax=End, ymin=0, ymax=Depth)) 
gpt = gpt + 
    geom_rect() + 
    labs(x="Genome (chr17; hg38)", 
         y="Fragment Index", 
         title="Unique STARR-seq fragment sorted by start position") +
    theme_bw() +
    theme(
        title      = element_text(size=17),
        axis.title = element_text(size=15),
        axis.text  = element_text(size=12)
    ) + xlim(8148987, 8159379)
gpt
# Out:
# Warning message:
# “Removed 1829701 rows containing missing values (geom_rect).”
# plot without title
