# %% [markdown]
# # Annotate segments using JASPAR annotation

# %%
# %%bash
# wc -l /data/reddylab/Kuei/out/CombEffect_STARR/data/TFX_Dex/chr17.bed
# wc -l /data/reddylab/Kuei/out/CombEffect_STARR/count_fragment/TFX_Dex/cnt_PER1.bed
# wc -l /data/reddylab/Kuei/out/CombEffect_STARR/count_segment/TFX_Dex/seg_PER1.bed
# Out:
# 6239658 /data/reddylab/Kuei/out/CombEffect_STARR/data/TFX_Dex/chr17.bed
# 4827 /data/reddylab/Kuei/out/CombEffect_STARR/count_fragment/TFX_Dex/cnt_PER1.bed
# 3562 /data/reddylab/Kuei/out/CombEffect_STARR/count_segment/TFX_Dex/seg_PER1.bed

# %% [markdown]
# ## Test: able to parallelize the annotation

# %% [markdown]
# - Realize that the files can be splitted based on the last digit of motif number
# - each split is about 70 motif files

# %%
# %%bash
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# for i in {0..9}; do
#     echo $i
#     ls ${FD_ANN}/MA???${i}.?.tsv.gz | wc -l
# done
# Out:
# 0
# 72
# 1
# 75
# 2
# 76
# 3
# 77
# 4
# 75
# 5
# 73
# 6
# 71
# 7
# 74
# 8
# 76
# 9
# 77

# %%
# %%bash
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# for i in {0..9}; do
#     echo $i
#     ls ${FD_ANN}/chr17_MA???${i}.?.tsv.gz | wc -l
# done
# Out:
# 0
# 72
# 1
# 75
# 2
# 76
# 3
# 77
# 4
# 75
# 5
# 73
# 6
# 71
# 7
# 74
# 8
# 76
# 9
# 77

# %%
# %%bash
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
# FN_ANN=MA0113.3.tsv.gz
#
# wc -l ${FD_ANN}/${FN_ANN}
# echo +++++++++++++++++++++++++++++++++
# zcat  ${FD_ANN}/${FN_ANN}       | head -3
# echo +++++++++++++++++++++++++++++++++
# zcat  ${FD_ANN}/chr17_${FN_ANN} | head -3
# Out:
# 36279 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0113.3.tsv.gz
# +++++++++++++++++++++++++++++++++
# chr10	11650	11667	NR3C1	814	384	+
# chr10	16730	16747	NR3C1	825	399	+
# chr10	16730	16747	NR3C1	826	400	-
# +++++++++++++++++++++++++++++++++
# chr17	82590	82607	NR3C1	808	375	+
# chr17	82590	82607	NR3C1	802	367	-
# chr17	82804	82821	NR3C1	838	418	+

# %%
# %%bash
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
# SLURM_ARRAY_TASK_ID=0
# CHROM=chr17
# FP_ANNS=$(ls ${FD_ANN}/${CHROM}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
# for FP_ANN in ${FP_ANNS}; do
#     echo  ${FP_ANN}
#     zcat ${FP_ANN} | wc -l
#     zcat ${FP_ANN} | head -n 3 | expand -t 12
#     zcat ${FP_ANN} | tail -n 3 | expand -t 12
#     echo ++++++++++++++++++++++++++++++++
# done
# Out:
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA
-
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1580.1.tsv.gz
# 162634
# chr17       60744       60754       ZBTB32      884         395         +
# chr17       61225       61235       ZBTB32      812         307         -
# chr17       62800       62810       ZBTB32      815         309         -
# chr17       83247059    83247069    ZBTB32      838         339         +
# chr17       83247076    83247086    ZBTB32      802         300         -
# chr17       83247115    83247125    ZBTB32      838         339         +
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1600.1.tsv.gz
# 6548
# chr17       75790       75808       ZNF684      801         454         +
# chr17       87422       87440       ZNF684      816         482         -
# chr17       88153       88171       ZNF684      812         475         -
# chr17       83219132    83219150    ZNF684      820         492         -
# chr17       83219986    83220004    ZNF684      829         510         -
# chr17       83228655    83228673    ZNF684      860         575         -
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1620.1.tsv.gz
# 350459
# chr17       60144       60156       Ptf1a(var.3)            878         373         +
# chr17       60345       60357       Ptf1a(var.3)            834         323         -
# chr17       60420       60432       Ptf1a(var.3)            883         379         -
# chr17       83246733    83246745    Ptf1a(var.3)            810         300         +
# chr17       83247025    83247037    Ptf1a(var.3)            811         301         +
# chr17       83247025    83247037    Ptf1a(var.3)            809         300         -
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1630.1.tsv.gz
# 107417
# chr17       60177       60188       Znf281      834         379         -
# chr17       60416       60427       Znf281      842         390         +
# chr17       60441       60452       Znf281      806         346         +
# chr17       83243333    83243344    Znf281      814         354         -
# chr17       83245391    83245402    Znf281      863         419         +
# chr17       83246012    83246023    Znf281      831         376         +
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1640.1.tsv.gz
# 147368
# chr17       61662       61677       MEIS2(var.2)            830         374         -
# chr17       61723       61738       MEIS2(var.2)            805         339         +
# chr17       66455       66470       MEIS2(var.2)            820         360         -
# chr17       83245153    83245168    MEIS2(var.2)            859         418         +
# chr17       83246186    83246201    MEIS2(var.2)            820         360         -
# chr17       83246326    83246341    MEIS2(var.2)            812         349         +
# ++++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA1650.1.tsv.gz
# 85770
# chr17       60371       60383       ZBTB14      826         338         -
# chr17       61186       61198       ZBTB14      837         353         -
# chr17       61959       61971       ZBTB14      853         373         +
# chr17       83230391    83230403    ZBTB14      855         376         +
# chr17       83240011    83240023    ZBTB14      801         308         -
# chr17       83244958    83244970    ZBTB14      803         310         +
# ++++++++++++++++++++++++++++++++

# %%
# %%bash
# FP_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA0030.1.tsv.gz
# FN_ANN=$(basename ${FP_ANN})
# echo $FP_ANN
# echo $FN_ANN
# echo ${FN_ANN%.*.*}
# Out:
# /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17/MA0030.1.tsv.gz
# MA0030.1.tsv.gz
# MA0030.1

# %% [markdown]
# ## Annotate segments generated at the region around PER1 (Ouput; DEX)

# %% [markdown]
# **Give the first test**

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --mem 15G \
#     -o ${FD_LOG}/prep_annotation_output_dex_per1_chr17.0.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set global variables
# CHROM=chr17
# TARGET=PER1
# SAMPLE=TFX_Dex
# SLURM_ARRAY_TASK_ID=0
#
# ### set input and output files
# FP_ANNS=$(ls ${FD_ANN}/${CHROM}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
# FD_OUT=${FD_WRK}/annotation_segment/${SAMPLE}/${TARGET}
# FD_SEG=${FD_WRK}/count_segment/${SAMPLE}
# FN_SEG=seg_${TARGET}.bed
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file: " ${FD_SEG}/${FN_SEG}
# echo
# echo "Show the first few lines of the input file"
# echo ${FD_SEG}/${FN_SEG}
#
# ### init: create output directory
# mkdir -p ${FD_OUT}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     ### set annotation and output files
#     FN_ANN=$(basename ${FP_ANN})
#     echo "ANNOT  file: " ${FP_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#
#     ### annotation segments with a binding site
#     FP_BED_A=${FD_SEG}/${FN_SEG}
#     FP_BED_B=${FP_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25436100

# %% [markdown]
# **Continue Annotating: --array=1-9**

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --array=1-9 \
#     --mem 15G \
#     -o ${FD_LOG}/prep_annotation_output_dex_per1_chr17.%a.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set global variables
# CHROM=chr17
# TARGET=PER1
# SAMPLE=TFX_Dex
#
# ### set input and output files
# FP_ANNS=$(ls ${FD_ANN}/${CHROM}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
# FD_OUT=${FD_WRK}/annotation_segment/${SAMPLE}/${TARGET}
# FD_SEG=${FD_WRK}/count_segment/${SAMPLE}
# FN_SEG=seg_${TARGET}.bed
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file: " ${FD_SEG}/${FN_SEG}
# echo
# echo "Show the first few lines of the input file"
# echo ${FD_SEG}/${FN_SEG}
#
# ### init: create output directory
# mkdir -p ${FD_OUT}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     ### set annotation and output files
#     FN_ANN=$(basename ${FP_ANN})
#     echo "ANNOT  file: " ${FP_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#
#     ### annotation segments with a binding site
#     FP_BED_A=${FD_SEG}/${FN_SEG}
#     FP_BED_B=${FP_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25436101

# %% [markdown]
# ## Annotate segments generated at the region around PER1 (Ouput; DMSO)

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --array=0-9 \
#     --mem 15G \
#     -o ${FD_LOG}/prep_annotation_output_dmso_per1_chr17.%a.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set global variables
# CHROM=chr17
# TARGET=PER1
# SAMPLE=TFX_DMSO
#
# ### set input and output files
# FP_ANNS=$(ls ${FD_ANN}/${CHROM}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
# FD_OUT=${FD_WRK}/annotation_segment/${SAMPLE}/${TARGET}
# FD_SEG=${FD_WRK}/count_segment/${SAMPLE}
# FN_SEG=seg_${TARGET}.bed
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file: " ${FD_SEG}/${FN_SEG}
# echo
# echo "Show the first few lines of the input file"
# echo ${FD_SEG}/${FN_SEG}
#
# ### init: create output directory
# mkdir -p ${FD_OUT}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     ### set annotation and output files
#     FN_ANN=$(basename ${FP_ANN})
#     echo "ANNOT  file: " ${FP_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#
#     ### annotation segments with a binding site
#     FP_BED_A=${FD_SEG}/${FN_SEG}
#     FP_BED_B=${FP_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25436090

# %% [markdown]
# ## Annotate segments generated at the region around PER1 (Input)

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --array=0-9 \
#     --mem 15G \
#     -o ${FD_LOG}/prep_annotation_input_per1_chr17.%a.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set global variables
# CHROM=chr17
# TARGET=PER1
# SAMPLE=Input
#
# ### set input and output files
# FP_ANNS=$(ls ${FD_ANN}/${CHROM}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
# FD_OUT=${FD_WRK}/annotation_segment/${SAMPLE}/${TARGET}
# FD_SEG=${FD_WRK}/count_segment/${SAMPLE}
# FN_SEG=seg_${TARGET}.bed
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file: " ${FD_SEG}/${FN_SEG}
# echo
# echo "Show the first few lines of the input file"
# echo ${FD_SEG}/${FN_SEG}
#
# ### init: create output directory
# mkdir -p ${FD_OUT}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     ### set annotation and output files
#     FN_ANN=$(basename ${FP_ANN})
#     echo "ANNOT  file: " ${FP_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#
#     ### annotation segments with a binding site
#     FP_BED_A=${FD_SEG}/${FN_SEG}
#     FP_BED_B=${FP_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25436080

# %% [markdown]
# -----

# %% [markdown]
# ## Test Ch17 output from the `11_partition.ipynb`

# %% [markdown]
# Give a test

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --mem 20G \
#     -o ${FD_LOG}/prep_annotation_dex_test.0.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_OUT=${FD_WRK}/data/TFX_Dex
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set input and output file names
# SLURM_ARRAY_TASK_ID=0
# CHROM=chr17
# FN_SEG=seg_PER1.bed
# FP_ANNS=$(ls ${FD_ANN}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file:       " ${FD_OUT}/${FN_SEG}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     FN_ANN=$(basename ${FP_ANN})
#
#     ### annotation segments with a binding site
#     echo "ANNOT  file: " ${FD_ANN}/${CHROM}_${FN_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     FP_BED_A=${FD_OUT}/${FN_SEG}
#     FP_BED_B=${FD_ANN}/${CHROM}_${FN_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25398713

# %% [markdown]
# array: 1-4

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --array=1-4 \
#     --mem 20G \
#     -o ${FD_LOG}/prep_annotation_dex_test.%a.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_OUT=${FD_WRK}/data/TFX_Dex
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set input and output file names
# #SLURM_ARRAY_TASK_ID=0
# CHROM=chr17
# FN_SEG=seg_${CHROM}.bed
# FP_ANNS=$(ls ${FD_ANN}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file:       " ${FD_OUT}/${FN_SEG}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     FN_ANN=$(basename ${FP_ANN})
#
#     ### annotation segments with a binding site
#     echo "ANNOT  file: " ${FD_ANN}/${CHROM}_${FN_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     FP_BED_A=${FD_OUT}/${FN_SEG}
#     FP_BED_B=${FD_ANN}/${CHROM}_${FN_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25398698

# %% [markdown]
# array: 5-9

# %%
# %%bash
# ### set environment
# module load bedtools2
# module load perl
# module load gcc
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# export PATH=/data/reddylab/software/homer/bin/:$PATH
#
# ### set log file directory
# FD_LOG=/gpfs/fs1/data/reddylab/Kuei/out/CombEffect_STARR/log
#
# ### run script using sbatch
# sbatch -pnew,all \
#     --array=5-9 \
#     --mem 20G \
#     -o ${FD_LOG}/prep_annotation_dex_test.%a.txt \
#     <<'EOF'
# #!/bin/bash
# ### set directories
# FD_WRK=/data/reddylab/Kuei/out/CombEffect_STARR
# FD_OUT=${FD_WRK}/data/TFX_Dex
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# ### set input and output file names
# #SLURM_ARRAY_TASK_ID=0
# CHROM=chr17
# FN_SEG=seg_${CHROM}.bed
# FP_ANNS=$(ls ${FD_ANN}/MA???${SLURM_ARRAY_TASK_ID}.?.tsv.gz)
#
# ### Print start message
# echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
# echo "Input  file:       " ${FD_OUT}/${FN_SEG}
#
# ### looping through the annotation files
# for FP_ANN in ${FP_ANNS}; do
#     FN_ANN=$(basename ${FP_ANN})
#
#     ### annotation segments with a binding site
#     echo "ANNOT  file: " ${FD_ANN}/${CHROM}_${FN_ANN}
#     echo "Output file: " ${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     FP_BED_A=${FD_OUT}/${FN_SEG}
#     FP_BED_B=${FD_ANN}/${CHROM}_${FN_ANN}
#     FP_BED_O=${FD_OUT}/${CHROM}_${FN_ANN%.*.*}.bedpe
#     bedtools intersect -a ${FP_BED_A} -b ${FP_BED_B} -wo > ${FP_BED_O}
# done
#
# ### Print end message
# echo "Done."
#
# EOF
# Out:
# Submitted batch job 25398707

# %% [markdown]
# rm /data/reddylab/Kuei/out/CombEffect_STARR/data/TFX_Dex/chr17_*

# %% [markdown]
# ## Check the intput files and output results

# %% [markdown]
# for each motif, take a look at the number of locations it binds in the genome and the number of segments that it binds to the specified windows of chromosome 17

# %%
# %%bash
# FD_ANN=/data/reddylab/Kuei/out/annotation/JASPAR2020
#
# i=0
# fpaths=$(ls ${FD_ANN}/MA???${i}.?.tsv.gz)
# for fpath in ${fpaths}; do
#     fname=$(basename ${fpath})
#     echo  ${fpath}
#     echo  ${fname}
#     echo  ${fname%.*.*}.bed
#     wc -l ${FD_ANN}/${fname}
#     wc -l ${FD_ANN}/chr17_${fname}
#     echo ++++++++++++++++++++++++++++++
# done
# Out:
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0030.1.tsv.gz
# MA0030.1.tsv.gz
# MA0030.1.bed
# 167571 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0030.1.tsv.gz
# 3901 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0030.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0040.1.tsv.gz
# MA0040.1.tsv.gz
# MA0040.1.bed
# 369644 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0040.1.tsv.gz
# 6632 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0040.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0050.2.tsv.gz
# MA0050.2.tsv.gz
# MA0050.2.bed
# 175791 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0050.2.tsv.gz
# 5457 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0050.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0060.3.tsv.gz
# MA0060.3.tsv.gz
# MA0060.3.bed
# 228453 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0060.3.tsv.gz
# 6426 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0060.3.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0070.1.tsv.gz
# MA0070.1.tsv.gz
# MA0070.1.bed
# 150966 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0070.1.tsv.gz
# 3798 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0070.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0080.5.tsv.gz
# MA0080.5.tsv.gz
# MA0080.5.bed
# 94344 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0080.5.tsv.gz
# 2915 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0080.5.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0090.3.tsv.gz
# MA0090.3.tsv.gz
# MA0090.3.bed
# 253846 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0090.3.tsv.gz
# 6351 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0090.3.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0100.3.tsv.gz
# MA0100.3.tsv.gz
# MA0100.3.bed
# 890824 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0100.3.tsv.gz
# 24056 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0100.3.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0130.1.tsv.gz
# MA0130.1.tsv.gz
# MA0130.1.bed
# 1851220 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0130.1.tsv.gz
# 60971 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0130.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0140.2.tsv.gz
# MA0140.2.tsv.gz
# MA0140.2.bed
# 127826 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0140.2.tsv.gz
# 2900 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0140.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0150.2.tsv.gz
# MA0150.2.tsv.gz
# MA0150.2.bed
# 32678 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0150.2.tsv.gz
# 1298 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0150.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0160.1.tsv.gz
# MA0160.1.tsv.gz
# MA0160.1.bed
# 491638 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0160.1.tsv.gz
# 13349 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0160.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0470.2.tsv.gz
# MA0470.2.tsv.gz
# MA0470.2.bed
# 26095 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0470.2.tsv.gz
# 980 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0470.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0480.1.tsv.gz
# MA0480.1.tsv.gz
# MA0480.1.bed
# 677296 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0480.1.tsv.gz
# 10784 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0480.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0490.2.tsv.gz
# MA0490.2.tsv.gz
# MA0490.2.bed
# 215357 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0490.2.tsv.gz
# 5656 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0490.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0500.2.tsv.gz
# MA0500.2.tsv.gz
# MA0500.2.bed
# 199680 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0500.2.tsv.gz
# 7922 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0500.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0510.2.tsv.gz
# MA0510.2.tsv.gz
# MA0510.2.bed
# 12264 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0510.2.tsv.gz
# 386 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0510.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0520.1.tsv.gz
# MA0520.1.tsv.gz
# MA0520.1.bed
# 531109 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0520.1.tsv.gz
# 9056 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0520.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0600.2.tsv.gz
# MA0600.2.tsv.gz
# MA0600.2.bed
# 29643 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0600.2.tsv.gz
# 938 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0600.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0610.1.tsv.gz
# MA0610.1.tsv.gz
# MA0610.1.bed
# 273363 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0610.1.tsv.gz
# 4807 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0610.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0620.3.tsv.gz
# MA0620.3.tsv.gz
# MA0620.3.bed
# 68275 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0620.3.tsv.gz
# 2451 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0620.3.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0630.1.tsv.gz
# MA0630.1.tsv.gz
# MA0630.1.bed
# 1542812 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0630.1.tsv.gz
# 34025 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0630.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0640.2.tsv.gz
# MA0640.2.tsv.gz
# MA0640.2.bed
# 236324 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0640.2.tsv.gz
# 6919 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0640.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0650.2.tsv.gz
# MA0650.2.tsv.gz
# MA0650.2.bed
# 295230 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0650.2.tsv.gz
# 9354 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0650.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0660.1.tsv.gz
# MA0660.1.tsv.gz
# MA0660.1.bed
# 247002 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0660.1.tsv.gz
# 5297 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0660.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0670.1.tsv.gz
# MA0670.1.tsv.gz
# MA0670.1.bed
# 788217 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0670.1.tsv.gz
# 26244 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0670.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0680.1.tsv.gz
# MA0680.1.tsv.gz
# MA0680.1.bed
# 175343 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0680.1.tsv.gz
# 3629 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0680.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0690.1.tsv.gz
# MA0690.1.tsv.gz
# MA0690.1.bed
# 260513 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0690.1.tsv.gz
# 6388 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0690.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0700.2.tsv.gz
# MA0700.2.tsv.gz
# MA0700.2.bed
# 619000 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0700.2.tsv.gz
# 14283 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0700.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0710.1.tsv.gz
# MA0710.1.tsv.gz
# MA0710.1.bed
# 1974429 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0710.1.tsv.gz
# 51497 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0710.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0720.1.tsv.gz
# MA0720.1.tsv.gz
# MA0720.1.bed
# 1660737 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0720.1.tsv.gz
# 38197 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0720.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0730.1.tsv.gz
# MA0730.1.tsv.gz
# MA0730.1.bed
# 8890 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0730.1.tsv.gz
# 212 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0730.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0740.1.tsv.gz
# MA0740.1.tsv.gz
# MA0740.1.bed
# 78413 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0740.1.tsv.gz
# 3776 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0740.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0750.2.tsv.gz
# MA0750.2.tsv.gz
# MA0750.2.bed
# 113796 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0750.2.tsv.gz
# 5219 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0750.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0760.1.tsv.gz
# MA0760.1.tsv.gz
# MA0760.1.bed
# 208481 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0760.1.tsv.gz
# 6744 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0760.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0770.1.tsv.gz
# MA0770.1.tsv.gz
# MA0770.1.bed
# 144795 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0770.1.tsv.gz
# 4492 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0770.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0780.1.tsv.gz
# MA0780.1.tsv.gz
# MA0780.1.bed
# 232964 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0780.1.tsv.gz
# 5485 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0780.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0790.1.tsv.gz
# MA0790.1.tsv.gz
# MA0790.1.bed
# 205437 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0790.1.tsv.gz
# 6775 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0790.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0800.1.tsv.gz
# MA0800.1.tsv.gz
# MA0800.1.bed
# 249593 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0800.1.tsv.gz
# 6575 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0800.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0810.1.tsv.gz
# MA0810.1.tsv.gz
# MA0810.1.bed
# 499359 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0810.1.tsv.gz
# 15470 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0810.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0820.1.tsv.gz
# MA0820.1.tsv.gz
# MA0820.1.bed
# 606194 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0820.1.tsv.gz
# 15510 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0820.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0830.2.tsv.gz
# MA0830.2.tsv.gz
# MA0830.2.bed
# 256327 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0830.2.tsv.gz
# 10013 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0830.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0840.1.tsv.gz
# MA0840.1.tsv.gz
# MA0840.1.bed
# 102366 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0840.1.tsv.gz
# 1951 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0840.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0850.1.tsv.gz
# MA0850.1.tsv.gz
# MA0850.1.bed
# 2977689 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0850.1.tsv.gz
# 59315 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0850.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0860.1.tsv.gz
# MA0860.1.tsv.gz
# MA0860.1.bed
# 15179 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0860.1.tsv.gz
# 442 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0860.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0870.1.tsv.gz
# MA0870.1.tsv.gz
# MA0870.1.bed
# 38705 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0870.1.tsv.gz
# 955 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0870.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0880.1.tsv.gz
# MA0880.1.tsv.gz
# MA0880.1.bed
# 1909220 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0880.1.tsv.gz
# 43714 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0880.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0890.1.tsv.gz
# MA0890.1.tsv.gz
# MA0890.1.bed
# 971853 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0890.1.tsv.gz
# 25867 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0890.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0900.2.tsv.gz
# MA0900.2.tsv.gz
# MA0900.2.bed
# 1264328 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0900.2.tsv.gz
# 22976 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0900.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0910.2.tsv.gz
# MA0910.2.tsv.gz
# MA0910.2.bed
# 1175035 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA0910.2.tsv.gz
# 23329 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA0910.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1100.2.tsv.gz
# MA1100.2.tsv.gz
# MA1100.2.bed
# 688322 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1100.2.tsv.gz
# 19086 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1100.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1110.1.tsv.gz
# MA1110.1.tsv.gz
# MA1110.1.bed
# 222570 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1110.1.tsv.gz
# 6224 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1110.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1120.1.tsv.gz
# MA1120.1.tsv.gz
# MA1120.1.bed
# 578048 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1120.1.tsv.gz
# 9768 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1120.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1130.1.tsv.gz
# MA1130.1.tsv.gz
# MA1130.1.bed
# 397400 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1130.1.tsv.gz
# 12208 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1130.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1140.2.tsv.gz
# MA1140.2.tsv.gz
# MA1140.2.bed
# 12419 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1140.2.tsv.gz
# 359 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1140.2.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1150.1.tsv.gz
# MA1150.1.tsv.gz
# MA1150.1.bed
# 424843 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1150.1.tsv.gz
# 11627 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1150.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1420.1.tsv.gz
# MA1420.1.tsv.gz
# MA1420.1.bed
# 26075 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1420.1.tsv.gz
# 779 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1420.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1470.1.tsv.gz
# MA1470.1.tsv.gz
# MA1470.1.bed
# 4309 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1470.1.tsv.gz
# 196 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1470.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1480.1.tsv.gz
# MA1480.1.tsv.gz
# MA1480.1.bed
# 469311 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1480.1.tsv.gz
# 12308 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1480.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1500.1.tsv.gz
# MA1500.1.tsv.gz
# MA1500.1.bed
# 2654224 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1500.1.tsv.gz
# 53820 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1500.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1520.1.tsv.gz
# MA1520.1.tsv.gz
# MA1520.1.bed
# 48060 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1520.1.tsv.gz
# 1178 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1520.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1530.1.tsv.gz
# MA1530.1.tsv.gz
# MA1530.1.bed
# 1391840 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1530.1.tsv.gz
# 37017 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1530.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1540.1.tsv.gz
# MA1540.1.tsv.gz
# MA1540.1.bed
# 405749 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1540.1.tsv.gz
# 9730 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1540.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1550.1.tsv.gz
# MA1550.1.tsv.gz
# MA1550.1.bed
# 84767 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1550.1.tsv.gz
# 2310 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1550.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1560.1.tsv.gz
# MA1560.1.tsv.gz
# MA1560.1.bed
# 121463 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1560.1.tsv.gz
# 6354 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1560.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1570.1.tsv.gz
# MA1570.1.tsv.gz
# MA1570.1.bed
# 897462 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1570.1.tsv.gz
# 27504 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1570.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1580.1.tsv.gz
# MA1580.1.tsv.gz
# MA1580.1.bed
# 249473 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1580.1.tsv.gz
# 7517 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1580.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1600.1.tsv.gz
# MA1600.1.tsv.gz
# MA1600.1.bed
# 6588 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1600.1.tsv.gz
# 292 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1600.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1620.1.tsv.gz
# MA1620.1.tsv.gz
# MA1620.1.bed
# 313091 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1620.1.tsv.gz
# 13859 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1620.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1630.1.tsv.gz
# MA1630.1.tsv.gz
# MA1630.1.bed
# 110665 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1630.1.tsv.gz
# 4735 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1630.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1640.1.tsv.gz
# MA1640.1.tsv.gz
# MA1640.1.bed
# 215857 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1640.1.tsv.gz
# 5256 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1640.1.tsv.gz
# ++++++++++++++++++++++++++++++
# /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1650.1.tsv.gz
# MA1650.1.tsv.gz
# MA1650.1.bed
# 58281 /data/reddylab/Kuei/out/annotation/JASPAR2020/MA1650.1.tsv.gz
# 3841 /data/reddylab/Kuei/out/annotation/JASPAR2020/chr17_MA1650.1.tsv.gz
# ++++++++++++++++++++++++++++++
