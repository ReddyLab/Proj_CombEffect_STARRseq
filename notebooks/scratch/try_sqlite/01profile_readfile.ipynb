# %% [markdown]
# # Profile read file function

# %% [markdown]
# **Set environment**

# %%
#######################################################
### Set environment
###++++++++++++++++++++++++++++++++++++++++++++++++++++

### import common packages
import numpy  as np
import itertools as it
import sys, os, gzip
from   functools import reduce

### update print
from functools import partial
print = partial(print, flush=True)

### set working directories
FD_RES = "/gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect"

### import specific packages
import sqlite3
# https://stackoverflow.com/questions/49456158/integer-in-python-pandas-becomes-blob-binary-in-sqlite
sqlite3.register_adapter(np.int64, lambda val: int(val))
sqlite3.register_adapter(np.int32, lambda val: int(val))


### import packages for benchmark performance
import cProfile, pstats, time, timeit
import matplotlib.pyplot as plt

# %% [markdown]
# **Global variables of database and file**

# %%
#######################################################
### parse arguments
###++++++++++++++++++++++++++++++++++++++++++++++++++++
CHROM   = "chr17"                          #args.chrom
FD_OUT  = os.path.join(FD_RES, "database") #args.fout
FD_INP  = os.path.join(FD_RES, "nuc")      #args.finp
PREFIX  = "test_insert"                    #args.prefix
VERBOSE = True                             #args.verbose

#######################################################
### Global varialbes and I/O
###++++++++++++++++++++++++++++++++++++++++++++++++++++

### file path of fragment database
fdiry  = FD_OUT
fname  = f"{PREFIX}_{CHROM}.db"
FP_DTB = os.path.join(fdiry, fname)

### file path of fragment table
sample  = "Input1_20x"
fdiry   = os.path.join(FD_INP, sample)
fname   = "chr17.bed.gz"
FP_FRG  = os.path.join(fdiry, fname)

### show info
if (VERBOSE):
    print("Global variables:")
    print("Chromsome:  ", CHROM)
    print("Database:   ", FP_DTB)
    print("Input file: ", FP_FRG)
    print()
# Out:
# Global variables:
# Chromsome:   chr17
# Database:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/database/test_insert_chr17.db
# Input file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1_20x/chr17.bed.gz

# %% [markdown]
# ## Setup helper function for reading files

# %%
##################################################
### Helper functions
### ++++++++++++++++++++++++++++++++++++++++++++++

### helper function to get a chunk of file
def get_chunks(gen, rows=10):
    """Divides the data into chunks with size as rows"""
    iterable = iter(gen)
    while True:
        x = list(it.islice(iterable, rows))
        if not x:
            return
        yield x

### helper function to process each row
def prep_line(line):
    """Function to process each line"""
    ### Decode
    lst = line.decode('ASCII').strip().split('\t') 

    ### parse info
    key = "_".join(lst[0:3])
    val = lst[0:3] + lst[4:-1]
    return [key] + val

def gen_line(file, n_chunksize=None, n_lines=None):
    """generate lines or chunks of lines from the file"""
    ### remove file header
    header = file.readline()
    lines  = file
    
    ### preprocess each line
    fun = prep_line
    gen = map(fun, lines)
    
    ### set number of lines read if specified
    if n_lines is not None:
        gen = it.islice(gen, n_lines)
    
    ### set chunks if specified
    if n_chunksize is not None:
        gen = get_chunks(gen, n_chunksize)

    return gen

# %% [markdown]
# ## Test the helper functions

# %%
fpath = FP_FRG
print(fpath)
# Out:
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1_20x/chr17.bed.gz

# %%
with gzip.open(fpath, "rb") as file:
    lines = gen_line(file, n_lines=3)
    for line in lines:
        print(line)
# Out:
# ['chr17_107410_108464', 'chr17', '107410', '108464', '0.512334', '0.487666', '342', '243', '271', '198', '0', '0']
# ['chr17_159026_160040', 'chr17', '159026', '160040', '0.506903', '0.493097', '286', '259', '241', '228', '0', '0']
# ['chr17_159426_160303', 'chr17', '159426', '160303', '0.491448', '0.508552', '224', '247', '199', '207', '0', '0']

# %%
with gzip.open(fpath, "rb") as file:
    chunks = gen_line(file, n_chunksize=3, n_lines=10)
    for chunk in chunks:
        for line in chunk:
            print(line)
        print("++++++++++++++++++++++++++++++")
# Out:
# ['chr17_107410_108464', 'chr17', '107410', '108464', '0.512334', '0.487666', '342', '243', '271', '198', '0', '0']
# ['chr17_159026_160040', 'chr17', '159026', '160040', '0.506903', '0.493097', '286', '259', '241', '228', '0', '0']
# ['chr17_159426_160303', 'chr17', '159426', '160303', '0.491448', '0.508552', '224', '247', '199', '207', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_159510_160362', 'chr17', '159510', '160362', '0.497653', '0.502347', '222', '231', '197', '202', '0', '0']
# ['chr17_159977_160849', 'chr17', '159977', '160849', '0.458716', '0.541284', '198', '229', '243', '202', '0', '0']
# ['chr17_174938_176057', 'chr17', '174938', '176057', '0.468275', '0.531725', '294', '300', '295', '230', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_175103_176248', 'chr17', '175103', '176248', '0.468122', '0.531878', '282', '308', '301', '254', '0', '0']
# ['chr17_177613_178563', 'chr17', '177613', '178563', '0.454737', '0.545263', '221', '256', '262', '211', '0', '0']
# ['chr17_180289_181411', 'chr17', '180289', '181411', '0.223708', '0.776292', '139', '381', '490', '112', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_197552_198593', 'chr17', '197552', '198593', '0.430355', '0.569645', '248', '323', '270', '200', '0', '0']
# ++++++++++++++++++++++++++++++

# %% [markdown]
# ## Profiling

# %%
def read_null(fpath, n_lines):
    pass

# %%
def read_line_by_line(fpath, n_lines):
    with gzip.open(fpath, "rb") as file:
        lines = gen_line(file, n_lines=3)
        for line in lines:
            print(line)

# %%
def read_line_by_chunk(fpath, n_lines, n_chunksize):
    with gzip.open(fpath, "rb") as file:
        chunks = gen_line(file, n_chunksize=3, n_lines=10)
        for chunk in chunks:
            for line in chunk:
                print(line)
            print("++++++++++++++++++++++++++++++")

# %%
n_lines = 10
n_chunksize=3

# %%
### start the profiler
pr = cProfile.Profile()
pr.enable()

### execution
read_null(fpath, n_lines)

### end the profiler
pr.disable()
ps = pstats.Stats(pr).print_stats()
# Out:
#          48 function calls in 0.000 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1932013334.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1932013334.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1439239155.py:1(read_null)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:1278(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3342(compare)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3400(run_code)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:117(<lambda>)
#         4    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/codeop.py:132(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:535(get)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:566(__get__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:81(__init__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:107(__enter__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:116(__exit__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:237(helper)

# %%
### start the profiler
pr = cProfile.Profile()
pr.enable()

### execution
read_line_by_line(fpath, n_lines)

### end the profiler
pr.disable()
ps = pstats.Stats(pr).print_stats()
# Out:
# ['chr17_107410_108464', 'chr17', '107410', '108464', '0.512334', '0.487666', '342', '243', '271', '198', '0', '0']
# ['chr17_159026_160040', 'chr17', '159026', '160040', '0.506903', '0.493097', '286', '259', '241', '228', '0', '0']
# ['chr17_159426_160303', 'chr17', '159426', '160303', '0.491448', '0.508552', '224', '247', '199', '207', '0', '0']
#          358 function calls in 0.017 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         3    0.010    0.003    0.010    0.003 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    0.011    0.003 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#        30    0.005    0.000    0.005    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        18    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         3    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.017    0.009 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#         1    0.000    0.000    0.000    0.000 {function DecompressReader.close at 0x7f2f72aebef0}
#         3    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.017    0.017 /tmp/ipykernel_13762/1907032120.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1907032120.py:9(<module>)
#         1    0.000    0.000    0.011    0.011 /tmp/ipykernel_13762/1093682430.py:26(gen_line)
#         3    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1093682430.py:16(prep_line)
#         1    0.000    0.000    0.017    0.017 /tmp/ipykernel_13762/1116890547.py:1(read_line_by_line)
#         4    0.000    0.000    0.011    0.003 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:372(readline)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:378(__init__)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:385(_init_read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:389(_read_exact)
#         1    0.000    0.000    0.010    0.010 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:405(_read_gzip_header)
#         1    0.000    0.000    0.011    0.011 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:438(read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:489(_add_read_data)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:20(open)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:74(__init__)
#         3    0.000    0.000    0.010    0.003 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:80(read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:93(prepend)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:123(__init__)
#         7    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:298(closed)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:302(close)
#        15    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:206(schedule)
#         6    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:418(_is_master_process)
#         6    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:437(_schedule_flush)
#         3    0.000    0.000    0.006    0.002 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:451(flush)
#         6    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:500(write)
#        15    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:96(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:1278(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3342(compare)
#         2    0.000    0.000    0.017    0.009 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3400(run_code)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:117(<lambda>)
#         4    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/codeop.py:132(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         4    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:12(_check_not_closed)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:59(close)
#         1    0.000    0.000    0.011    0.011 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:66(readinto)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:150(tell)
#         1    0.000    0.000    0.000    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method zlib.crc32}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#        15    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/zmq/sugar/socket.py:474(send)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:535(get)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:566(__get__)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:240(__enter__)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:243(__exit__)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:249(_release_save)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:252(_acquire_restore)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:255(_is_owned)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:216(__init__)
#         3    0.000    0.000    0.005    0.002 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:264(wait)
#         3    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:499(__init__)
#        18    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:507(is_set)
#         3    0.000    0.000    0.005    0.002 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:534(wait)
#        18    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:1050(_wait_for_tstate_lock)
#        18    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:1092(is_alive)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:81(__init__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:107(__enter__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:116(__exit__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:237(helper)

# %%
### start the profiler
pr = cProfile.Profile()
pr.enable()

### execution
read_line_by_chunk(fpath, n_lines, n_chunksize)

### end the profiler
pr.disable()
ps = pstats.Stats(pr).print_stats()
# Out:
# ['chr17_107410_108464', 'chr17', '107410', '108464', '0.512334', '0.487666', '342', '243', '271', '198', '0', '0']
# ['chr17_159026_160040', 'chr17', '159026', '160040', '0.506903', '0.493097', '286', '259', '241', '228', '0', '0']
# ['chr17_159426_160303', 'chr17', '159426', '160303', '0.491448', '0.508552', '224', '247', '199', '207', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_159510_160362', 'chr17', '159510', '160362', '0.497653', '0.502347', '222', '231', '197', '202', '0', '0']
# ['chr17_159977_160849', 'chr17', '159977', '160849', '0.458716', '0.541284', '198', '229', '243', '202', '0', '0']
# ['chr17_174938_176057', 'chr17', '174938', '176057', '0.468275', '0.531725', '294', '300', '295', '230', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_175103_176248', 'chr17', '175103', '176248', '0.468122', '0.531878', '282', '308', '301', '254', '0', '0']
# ['chr17_177613_178563', 'chr17', '177613', '178563', '0.454737', '0.545263', '221', '256', '262', '211', '0', '0']
# ['chr17_180289_181411', 'chr17', '180289', '181411', '0.223708', '0.776292', '139', '381', '490', '112', '0', '0']
# ++++++++++++++++++++++++++++++
# ['chr17_197552_198593', 'chr17', '197552', '198593', '0.430355', '0.569645', '248', '323', '270', '200', '0', '0']
# ++++++++++++++++++++++++++++++
#          1274 function calls in 0.021 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         3    0.004    0.001    0.004    0.001 {method 'read' of '_io.BufferedReader' objects}
#        11    0.000    0.000    0.004    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#       140    0.014    0.000    0.014    0.000 {method 'acquire' of '_thread.lock' objects}
#        14    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        14    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        14    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        28    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        84    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        28    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        14    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.021    0.010 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        36    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#         1    0.000    0.000    0.000    0.000 {function DecompressReader.close at 0x7f2f72aebef0}
#        10    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1648028354.py:9(<module>)
#         1    0.000    0.000    0.021    0.021 /tmp/ipykernel_13762/1648028354.py:6(<module>)
#         5    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1093682430.py:6(get_chunks)
#         1    0.000    0.000    0.004    0.004 /tmp/ipykernel_13762/1093682430.py:26(gen_line)
#         1    0.000    0.000    0.021    0.021 /tmp/ipykernel_13762/488990027.py:1(read_line_by_chunk)
#        10    0.000    0.000    0.000    0.000 /tmp/ipykernel_13762/1093682430.py:16(prep_line)
#        11    0.000    0.000    0.004    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:372(readline)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:378(__init__)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:385(_init_read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:389(_read_exact)
#         1    0.000    0.000    0.004    0.004 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:405(_read_gzip_header)
#         1    0.000    0.000    0.004    0.004 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:438(read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:489(_add_read_data)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:20(open)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:74(__init__)
#         3    0.000    0.000    0.004    0.001 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:80(read)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:93(prepend)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:123(__init__)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:298(closed)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/gzip.py:302(close)
#        70    0.000    0.000    0.001    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:206(schedule)
#        28    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:418(_is_master_process)
#        28    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:437(_schedule_flush)
#        14    0.000    0.000    0.015    0.001 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:451(flush)
#        28    0.000    0.000    0.001    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:500(write)
#        70    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/ipykernel/iostream.py:96(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:1278(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3342(compare)
#         2    0.000    0.000    0.021    0.011 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3400(run_code)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/interactiveshell.py:117(<lambda>)
#         4    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/codeop.py:132(__call__)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#        11    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:12(_check_not_closed)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:59(close)
#         1    0.000    0.000    0.004    0.004 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:66(readinto)
#         1    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/_compression.py:150(tell)
#         1    0.000    0.000    0.000    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method zlib.crc32}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#        70    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/zmq/sugar/socket.py:474(send)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:535(get)
#         2    0.000    0.000    0.000    0.000 /gpfs/fs1/data/reddylab/Kuei/venv/env_jupyter/lib/python3.7/site-packages/traitlets/traitlets.py:566(__get__)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:240(__enter__)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:243(__exit__)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:249(_release_save)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:252(_acquire_restore)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:255(_is_owned)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:216(__init__)
#        14    0.000    0.000    0.014    0.001 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:264(wait)
#        14    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:499(__init__)
#        84    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:507(is_set)
#        14    0.000    0.000    0.014    0.001 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:534(wait)
#        84    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:1050(_wait_for_tstate_lock)
#        84    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/threading.py:1092(is_alive)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:81(__init__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:107(__enter__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:116(__exit__)
#         2    0.000    0.000    0.000    0.000 /nfs/software/helmod/apps/Core/Anaconda3/2019.10-gcb02/x/lib/python3.7/contextlib.py:237(helper)
