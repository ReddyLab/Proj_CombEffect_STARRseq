# %% [markdown]
# # Fragment nucleotide information
#
# **Set environment**

# %%
source ../config_duke.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect

# %% [markdown]
# **Check data**

# %%
ls -d ${FD_RES}/count_fragment/*/chr17.bed.gz
# Out:
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1_20x/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2_20x/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3_20x/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4_20x/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5_20x/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_Dex/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_DMSO/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_Dex/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_DMSO/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_Dex/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_DMSO/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_Dex/chr17.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_DMSO/chr17.bed.gz

# %%
fpath="/gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1/chr17.bed.gz"
zcat $fpath | head
# Out:
# chr17	201123	201925	1
# chr17	201160	201968	1
# chr17	201202	202074	1
# chr17	201259	202052	1
# chr17	201366	202130	1
# chr17	206174	207307	1
# chr17	206269	207286	1
# chr17	206283	207194	1
# chr17	206324	207359	1
# chr17	206326	207274	1
#
# gzip: stdout: Broken pipe

# %% [markdown]
# ## Test loop

# %%
echo ${NODE}
# Out:
# all

# %%
FD_BEDS=($(ls -d ${FD_RES}/count_fragment/{Input?,Input?_20x,TFX?_DMSO,TFX?_Dex}/))
for FD_BED in ${FD_BEDS[@]}; do
   SAMPLE=$(basename ${FD_BED})
   FD_OUT=${FD_RES}/nuc/${SAMPLE}
   
   echo ${FD_BED}
   echo ${FD_OUT}
   echo ${SAMPLE}
   
done
# Out:
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1
# Input1
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1_20x/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1_20x
# Input1_20x
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input2
# Input2
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2_20x/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input2_20x
# Input2_20x
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input3
# Input3
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3_20x/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input3_20x
# Input3_20x
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input4
# Input4
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4_20x/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input4_20x
# Input4_20x
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input5
# Input5
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5_20x/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input5_20x
# Input5_20x
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_Dex/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX2_Dex
# TFX2_Dex
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_DMSO/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX2_DMSO
# TFX2_DMSO
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_Dex/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX3_Dex
# TFX3_Dex
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_DMSO/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX3_DMSO
# TFX3_DMSO
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_Dex/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX4_Dex
# TFX4_Dex
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_DMSO/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX4_DMSO
# TFX4_DMSO
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_Dex/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX5_Dex
# TFX5_Dex
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_DMSO/
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX5_DMSO
# TFX5_DMSO

# %%
### set environment
source ../config_duke.sh
source ../config_load_module_bedtools.sh

sbatch -p ${NODE} \
    --array 0-23 \
    --mem 8G \
    -o ${FD_LOG}/nuc_fragment_chrom.%a.txt \
    <<'EOF'
#!/bin/bash

### set directories & global variables
source ../config_duke.sh
CHROMS=($(seq 1 22) X Y)
CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
TARGET=${CHROM}

#CHROM=chr17
#TARGET=target_PER1

### set input and output
FD_BEDS=($(ls -d ${FD_RES}/count_fragment/{Input?,Input?_20x,TFX?_DMSO,TFX?_Dex}/))
FN_BED=${TARGET}.bed.gz
FN_OUT=${TARGET}.bed.gz

### genome annotation
FD_GEN=${FD_ANN}/genome/hg38/fasta
FN_GEN=${CHROM}.fa

### START Message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

for FD_BED in ${FD_BEDS[@]}; do
    SAMPLE=$(basename ${FD_BED})
    FD_OUT=${FD_RES}/nuc/${SAMPLE}
    
    ### Loop START Message
    echo ++++++++++++++++++++++++++++++++++++++++++++++++
    echo "Input  file: " ${FD_BED}/${FN_BED}
    echo "Output file: " ${FD_OUT}/${FN_OUT}
    echo
    echo "Show the first few lines of the input file"
    echo ${FD_BED}/${FN_BED}
    zcat ${FD_BED}/${FN_BED} | head -n 3
    echo
    
    ### init: create output folder if not exist
    mkdir -p ${FD_OUT}
    
    ### calculate the GC content of each fragment
    bedtools nuc \
        -fi  ${FD_GEN}/${FN_GEN} \
        -bed ${FD_BED}/${FN_BED} |\
        gzip -c > ${FD_OUT}/${FN_OUT}
    
    ### Loop END Message
    echo "Show the first few lines of the output file"
    echo ${FD_OUT}/${FN_OUT}
    zcat ${FD_OUT}/${FN_OUT} | head -n 3
    echo
done

### END message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 27358993

# %%
cat ${FD_LOG}/nuc_fragment_chrom.0.txt
# Out:
# Slurm Array Index:  0
# Time Stamp:         02-16-22+16:53:40
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1//chr1.bed.gz
# chr1	13868	14793	1
# chr1	17394	18268	1
# chr1	17394	18269	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1_20x//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input1_20x/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input1_20x//chr1.bed.gz
# chr1	13802	14757	1
# chr1	13802	14759	2
# chr1	13868	14793	2
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input2/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2//chr1.bed.gz
# chr1	14843	15828	1
# chr1	14875	15723	1
# chr1	16771	17773	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2_20x//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input2_20x/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input2_20x//chr1.bed.gz
# chr1	13616	14780	1
# chr1	13809	14798	1
# chr1	14416	15496	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input3/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3//chr1.bed.gz
# chr1	14868	15889	1
# chr1	17400	18408	1
# chr1	17410	18497	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3_20x//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input3_20x/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input3_20x//chr1.bed.gz
# chr1	13622	14491	1
# chr1	13802	14759	1
# chr1	13835	14792	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input4/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4//chr1.bed.gz
# chr1	17394	18269	1
# chr1	17437	18425	1
# chr1	17445	18435	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4_20x//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input4_20x/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input4_20x//chr1.bed.gz
# chr1	13622	14491	1
# chr1	13655	14504	1
# chr1	13767	14799	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input5/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5//chr1.bed.gz
# chr1	17394	18225	1
# chr1	17408	18358	1
# chr1	17410	18335	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5_20x//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/Input5_20x/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/Input5_20x//chr1.bed.gz
# chr1	12225	13098	1
# chr1	13627	14515	2
# chr1	13868	14793	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_Dex//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX2_Dex/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_Dex//chr1.bed.gz
# chr1	13622	14491	1
# chr1	13623	14491	1
# chr1	14848	15901	2
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_DMSO//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX2_DMSO/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX2_DMSO//chr1.bed.gz
# chr1	13616	14781	1
# chr1	13617	14781	1
# chr1	14919	15869	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_Dex//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX3_Dex/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_Dex//chr1.bed.gz
# chr1	14903	15879	1
# chr1	14903	15880	1
# chr1	14904	15879	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_DMSO//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX3_DMSO/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX3_DMSO//chr1.bed.gz
# chr1	13444	14495	1
# chr1	13445	14495	1
# chr1	15134	16261	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_Dex//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX4_Dex/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_Dex//chr1.bed.gz
# chr1	15143	16267	1
# chr1	16913	17842	1
# chr1	16913	17843	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_DMSO//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX4_DMSO/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX4_DMSO//chr1.bed.gz
# chr1	13752	14778	1
# chr1	14868	15888	1
# chr1	14868	15889	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_Dex//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX5_Dex/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_Dex//chr1.bed.gz
# chr1	14449	15491	3
# chr1	14450	15491	1
# chr1	14710	15703	1
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_DMSO//chr1.bed.gz
# Output file:  /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/nuc/TFX5_DMSO/chr1.bed.gz
#
# Show the first few lines of the input file
# /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect/count_fragment/TFX5_DMSO//chr1.bed.gz
# chr1	13684	14776	1
# chr1	14912	15900	1
# chr1	14912	15901	2
#
# Done!
# Run Time: 1 seconds
