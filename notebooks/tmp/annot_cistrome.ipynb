# %%
FD_OUT=/data/reddylab/Kuei
ls $FD_OUT
# Out:
# envs  GitRepo  learn  out  pkgs  source

# %%
wget -O $FD_OUT/source/cistrome_hg38.zip https://springernature.figshare.com/ndownloader/files/13033769
# Out:
# --2021-04-13 11:24:26--  https://springernature.figshare.com/ndownloader/files/13033769
# Resolving springernature.figshare.com... 52.209.23.90, 54.72.81.52
# Connecting to springernature.figshare.com|52.209.23.90|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pstorage-npg-968563215/13033769/cistrome_hg38.zip [following]
# --2021-04-13 11:24:26--  https://s3-eu-west-1.amazonaws.com/pstorage-npg-968563215/13033769/cistrome_hg38.zip
# Resolving s3-eu-west-1.amazonaws.com... 52.218.30.11
# Connecting to s3-eu-west-1.amazonaws.com|52.218.30.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 199574748 (190M) [application/zip]
# Saving to: “/data/reddylab/Kuei/source/cistrome_hg38.zip”
#
# 100%[======================================>] 199,574,748 14.8M/s   in 26s
#
# 2021-04-13 11:24:53 (7.36 MB/s) - “/data/reddylab/Kuei/source/cistrome_hg38.zip” saved [199574748/199574748]

# %%
ls $FD_OUT/source
# Out:
# cistrome_hg38.zip  GSE113394_RAW.tar  Reddylab_PROcap

# %%
ls $FD_OUT/out
# Out:
# annotation  Dex_ChIPseq  Dex_Multitreat  Dex_PROcap  Dex_RNAseq  GSE113394

# %%
unzip $FD_OUT/source/cistrome_hg38.zip -d $FD_OUT/out/annotation
# Out:
# Archive:  /data/reddylab/Kuei/source/cistrome_hg38.zip
#    creating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/AHR_HUMAN.C.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/ALX4_HUMAN.C.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/ANDR_HUMAN.A.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/ANDR_HUMAN.B.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/ANDR_HUMAN.C.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/ANDR_HUMAN.D.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/AP2A_HUMAN.A.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/AP2A_HUMAN.B.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/AP2A_HUMAN.C.bed
#   inflating: /data/reddylab/Kuei/out/annotation/hg38_cismotifs/AP2A_HUMAN.D.bed
# ...

# %%
ls $FD_OUT/out/annotation
# Out:
# description_hg38.txt	       hg38_cismotifs
# gencode.v34.annotation.gtf     hg38_cistrome
# gencode.v34.annotation.gtf.gz  Homo_sapiens.GRCh38.dna.primary_assembly.fa
# gencode_v34_transcript.tsv     Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz

# %%
ls $FD_OUT/out/annotation/hg38_cistrome | head
# Out:
# AEBP2_HUMAN.C.bed
# AHR_HUMAN.C.bed
# ALX4_HUMAN.C.bed
# ANDR_HUMAN.A.bed
# ANDR_HUMAN.B.bed
# ANDR_HUMAN.C.bed
# ANDR_HUMAN.D.bed
# AP2A_HUMAN.A.bed
# AP2A_HUMAN.B.bed
# AP2A_HUMAN.C.bed

# %%
ls $FD_OUT/out/annotation/hg38_cismotifs | head
# Out:
# AHR_HUMAN.C.bed
# ALX4_HUMAN.C.bed
# ANDR_HUMAN.A.bed
# ANDR_HUMAN.B.bed
# ANDR_HUMAN.C.bed
# ANDR_HUMAN.D.bed
# AP2A_HUMAN.A.bed
# AP2A_HUMAN.B.bed
# AP2A_HUMAN.C.bed
# AP2A_HUMAN.D.bed

# %%
head $FD_OUT/out/annotation/hg38_cistrome/AP2A_HUMAN.A.bed
# Out:
# chr1	917005	917426
# chr1	938315	938776
# chr1	976258	976699
# chr1	999930	1000555
# chr1	1013141	1013592
# chr1	1021478	1021823
# chr1	1079443	1079775
# chr1	1122918	1123251
# chr1	1125182	1125829
# chr1	1132462	1133176

# %%
head $FD_OUT/out/annotation/hg38_cismotifs/AP2A_HUMAN.A.bed
# Out:
# chr1	917005	917426	5.170258476824839
# chr1	938315	938776	4.153223808222851
# chr1	976258	976699	5.276301717254923
# chr1	999930	1000555	4.280406626483349
# chr1	1013141	1013592	4.216825717925434
# chr1	1021478	1021823	6.083555147004067
# chr1	1122918	1123251	5.424708052819197
# chr1	1125182	1125829	4.5346356233368
# chr1	1132462	1133176	4.789335580309889
# chr1	1137581	1138198	4.513461854490867
