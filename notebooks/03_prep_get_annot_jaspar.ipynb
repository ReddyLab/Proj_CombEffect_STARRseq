# %%
FD_OUT=/data/reddylab/Kuei
ls $FD_OUT
# Out:
# envs  exe  GitRepo  learn  out	pkgs  source

# %%
ls $FD_OUT/out/annotation
# Out:
# cistrome  genome  JASPAR2020

# %%
wget -O $FD_OUT/out/annotation/JASPAR2020/MA0002.2.tsv.gz http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/MA0002.2.tsv.gz
# Out:
# --2021-05-11 17:16:46--  http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/MA0002.2.tsv.gz
# Resolving expdata.cmmt.ubc.ca... 137.82.44.19
# Connecting to expdata.cmmt.ubc.ca|137.82.44.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190933122 (182M) [application/x-gzip]
# Saving to: “/data/reddylab/Kuei/out/annotation/jaspar2020/MA0002.2.tsv.gz”
#
# 100%[======================================>] 190,933,122 22.3M/s   in 8.4s
#
# 2021-05-11 17:16:55 (21.8 MB/s) - “/data/reddylab/Kuei/out/annotation/jaspar2020/MA0002.2.tsv.gz” saved [190933122/190933122]

# %% [markdown]
# ```
# FD_OUT=/data/reddylab/Kuei
# wget -O \
#      --recursive \
#      --no-parent \
#      --reject "index.html*" \
#      http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/ \
#      $FD_OUT/out/annotation/JASPAR2020
# ```

# %%
FD_OUT=/data/reddylab/Kuei
wget --recursive --no-parent \
    http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/ \
    $FD_OUT/out/annotation/JASPAR2020
# Out:
# --2021-05-14 02:31:04--  http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/
# Resolving expdata.cmmt.ubc.ca... 137.82.44.19
# Connecting to expdata.cmmt.ubc.ca|137.82.44.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: “expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/index.html”
#
#     [   <=>                                 ] 161,204      364K/s   in 0.4s
#
# 2021-05-14 02:31:04 (364 KB/s) - “expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/index.html” saved [161204]
#
# Loading robots.txt; please ignore errors.
# --2021-05-14 02:31:04--  http://expdata.cmmt.ubc.ca/robots.txt
# Connecting to expdata.cmmt.ubc.ca|137.82.44.19|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-05-14 02:31:05 ERROR 404: Not Found.
#
# --2021-05-14 02:31:05--  http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/?C=N;O=D
# ...

# %%
ls $FD_OUT/out/annotation/JASPAR2020
# Out:
# chr17.bed  chr22.bed

# %%
FD_OUT=/data/reddylab/Kuei
mv ./expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/MA* $FD_OUT/out/annotation/JASPAR2020/

# %%
ls $FD_OUT/out/annotation/JASPAR2020
# Out:
# chr17.bed	 MA0520.1.tsv.gz  MA0770.1.tsv.gz  MA1142.1.tsv.gz
# chr22.bed	 MA0521.1.tsv.gz  MA0771.1.tsv.gz  MA1143.1.tsv.gz
# MA0002.2.tsv.gz  MA0522.3.tsv.gz  MA0772.1.tsv.gz  MA1144.1.tsv.gz
# MA0003.4.tsv.gz  MA0523.1.tsv.gz  MA0773.1.tsv.gz  MA1145.1.tsv.gz
# MA0004.1.tsv.gz  MA0524.2.tsv.gz  MA0774.1.tsv.gz  MA1146.1.tsv.gz
# MA0006.1.tsv.gz  MA0525.2.tsv.gz  MA0775.1.tsv.gz  MA1147.1.tsv.gz
# MA0007.3.tsv.gz  MA0526.3.tsv.gz  MA0776.1.tsv.gz  MA1148.1.tsv.gz
# MA0009.2.tsv.gz  MA0527.1.tsv.gz  MA0777.1.tsv.gz  MA1149.1.tsv.gz
# MA0014.3.tsv.gz  MA0528.2.tsv.gz  MA0778.1.tsv.gz  MA1150.1.tsv.gz
# MA0017.2.tsv.gz  MA0591.1.tsv.gz  MA0779.1.tsv.gz  MA1151.1.tsv.gz
# MA0018.4.tsv.gz  MA0592.3.tsv.gz  MA0780.1.tsv.gz  MA1152.1.tsv.gz
# MA0019.1.tsv.gz  MA0593.1.tsv.gz  MA0781.1.tsv.gz  MA1153.1.tsv.gz
# MA0024.3.tsv.gz  MA0594.2.tsv.gz  MA0782.2.tsv.gz  MA1154.1.tsv.gz
# MA0025.2.tsv.gz  MA0595.1.tsv.gz  MA0783.1.tsv.gz  MA1155.1.tsv.gz
# ...

# %%
zcat $FD_OUT/out/annotation/JASPAR2020/MA0002.2.tsv.gz | head
# Out:
# chr10	10423	10434	RUNX1	804	269	-
# chr10	10458	10469	RUNX1	807	272	+
# chr10	10496	10507	RUNX1	861	337	+
# chr10	10540	10551	RUNX1	804	269	+
# chr10	10602	10613	RUNX1	804	269	+
# chr10	10707	10718	RUNX1	850	323	-
# chr10	10936	10947	RUNX1	876	356	+
# chr10	10949	10960	RUNX1	880	362	-
# chr10	11043	11054	RUNX1	839	308	-
# chr10	11118	11129	RUNX1	858	332	-

# %%
zcat $FD_OUT/out/annotation/JASPAR2020/MA0002.2.tsv.gz | head

# %%
ls $FD_OUT/out/annotation/jaspar2020
# Out:
# MA0002.2.tsv.gz

# %%
zcat $FD_OUT/out/annotation/jaspar2020/MA0002.2.tsv.gz | wc -l
# Out:
# 20310564

# %%
zcat $FD_OUT/out/annotation/jaspar2020/MA0002.2.tsv.gz | head
# Out:
# chr10	10423	10434	RUNX1	804	269	-
# chr10	10458	10469	RUNX1	807	272	+
# chr10	10496	10507	RUNX1	861	337	+
# chr10	10540	10551	RUNX1	804	269	+
# chr10	10602	10613	RUNX1	804	269	+
# chr10	10707	10718	RUNX1	850	323	-
# chr10	10936	10947	RUNX1	876	356	+
# chr10	10949	10960	RUNX1	880	362	-
# chr10	11043	11054	RUNX1	839	308	-
# chr10	11118	11129	RUNX1	858	332	-

# %%
zcat $FD_OUT/out/annotation/jaspar2020/MA0002.2.tsv.gz | tail
# Out:
# chrY	57217339	57217350	RUNX1	855	329	+
# chrY	57217348	57217359	RUNX1	864	341	+
# chrY	57217354	57217365	RUNX1	855	329	+
# chrY	57217361	57217372	RUNX1	864	341	+
# chrY	57217367	57217378	RUNX1	849	321	+
# chrY	57217373	57217384	RUNX1	849	321	+
# chrY	57217379	57217390	RUNX1	849	321	+
# chrY	57217387	57217398	RUNX1	864	341	+
# chrY	57217393	57217404	RUNX1	855	329	+
# chrY	57217400	57217411	RUNX1	864	341	+

# %%
wget -O $FD_OUT/source/JASPAR2020_hg38.bb http://expdata.cmmt.ubc.ca/JASPAR/downloads/UCSC_tracks/2020/hg38/MA0002.2.tsv.gz

# %%
MA0002.2.tsv.gz
