# %% [markdown]
# # Motif marginal effect in the upstream of PER1 region

# %% [markdown]
# **Set environment**

# %%
suppressMessages(suppressWarnings(source("config_sing.R")))
print(FD_WORK)
print(FD_RES)
# Out:
# [1] "/home/mount/work"
# [1] "/home/mount/work/out/proj_combeffect"

# %% [markdown]
# **Check input file**

# %%
fdiry = file.path(FD_RES, "annotation_fragment", "Input1", "target_PER1")
fname = "*_merge.bed.gz"
fglob = file.path(fdiry, fname)
system(paste("ls -lh", fglob), intern = TRUE)
# Out:
#   [1] "-rw-rw-r-- 1 kk319 reddylab  504 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/AHR_merge.bed.gz"
#   [2] "-rw-rw-r-- 1 kk319 reddylab  173 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/AIRE_merge.bed.gz"
#   [3] "-rw-rw-r-- 1 kk319 reddylab  878 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/AP1_1_merge.bed.gz"
#   [4] "-rw-rw-r-- 1 kk319 reddylab  990 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/AP1_2_merge.bed.gz"
#   [5] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ARI5A_merge.bed.gz"
#   [6] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ARI5B_merge.bed.gz"
#   [7] "-rw-rw-r-- 1 kk319 reddylab  695 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/BATF_merge.bed.gz"
#   [8] "-rw-rw-r-- 1 kk319 reddylab  173 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/BCL6_1_merge.bed.gz"
#   [9] "-rw-rw-r-- 1 kk319 reddylab  622 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/BCL6_2_merge.bed.gz"
#  [10] "-rw-rw-r-- 1 kk319 reddylab  615 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CCAAT_CEBP_merge.bed.gz"
#  [11] "-rw-rw-r-- 1 kk319 reddylab  308 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CENBP_merge.bed.gz"
#  [12] "-rw-rw-r-- 1 kk319 reddylab  301 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CPEB1_merge.bed.gz"
#  [13] "-rw-rw-r-- 1 kk319 reddylab  889 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CREB3_XBP1_merge.bed.gz"
#  [14] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CREB_ATF_1_merge.bed.gz"
#  [15] "-rw-rw-r-- 1 kk319 reddylab  476 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CREB_ATF_2_merge.bed.gz"
#  [16] "-rw-rw-r-- 1 kk319 reddylab  124 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CREB_ATF_3_merge.bed.gz"
#  [17] "-rw-rw-r-- 1 kk319 reddylab 2.5K Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CTCF_merge.bed.gz"
#  [18] "-rw-rw-r-- 1 kk319 reddylab  199 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CUX_1_merge.bed.gz"
#  [19] "-rw-rw-r-- 1 kk319 reddylab  155 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CUX_2_merge.bed.gz"
#  [20] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/CUX_3_merge.bed.gz"
#  [21] "-rw-rw-r-- 1 kk319 reddylab  147 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/DDIT3+CEBPA_merge.bed.gz"
#  [22] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/DMRT3_merge.bed.gz"
#  [23] "-rw-rw-r-- 1 kk319 reddylab  528 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/E2F_1_merge.bed.gz"
#  [24] "-rw-rw-r-- 1 kk319 reddylab 3.1K Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/E2F_2_merge.bed.gz"
#  [25] "-rw-rw-r-- 1 kk319 reddylab  193 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/E2F_3_merge.bed.gz"
#  [26] "-rw-rw-r-- 1 kk319 reddylab  459 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/E2F_4_merge.bed.gz"
#  [27] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/EBF1_merge.bed.gz"
#  [28] "-rw-rw-r-- 1 kk319 reddylab  997 Oct 12 19:40 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CACCTG_merge.bed.gz"
#  [29] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CACGTG_1_merge.bed.gz"
#  [30] "-rw-rw-r-- 1 kk319 reddylab 2.0K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CACGTG_2_merge.bed.gz"
#  [31] "-rw-rw-r-- 1 kk319 reddylab 3.0K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CAGATGG_merge.bed.gz"
#  [32] "-rw-rw-r-- 1 kk319 reddylab 2.5K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CAGCTG_merge.bed.gz"
#  [33] "-rw-rw-r-- 1 kk319 reddylab  147 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/Ebox_CATATG_merge.bed.gz"
#  [34] "-rw-rw-r-- 1 kk319 reddylab 2.0K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/EGR_merge.bed.gz"
#  [35] "-rw-rw-r-- 1 kk319 reddylab 1.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ETS_1_merge.bed.gz"
#  [36] "-rw-rw-r-- 1 kk319 reddylab 4.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ETS_2_merge.bed.gz"
#  [37] "-rw-rw-r-- 1 kk319 reddylab  447 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/EVI1_MECOM_merge.bed.gz"
#  [38] "-rw-rw-r-- 1 kk319 reddylab  433 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/EWSR1_FLI1_merge.bed.gz"
#  [39] "-rw-rw-r-- 1 kk319 reddylab  308 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FEZF1_merge.bed.gz"
#  [40] "-rw-rw-r-- 1 kk319 reddylab  218 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_1_merge.bed.gz"
#  [41] "-rw-rw-r-- 1 kk319 reddylab  375 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_2_merge.bed.gz"
#  [42] "-rw-rw-r-- 1 kk319 reddylab  415 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_3_merge.bed.gz"
#  [43] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_4_merge.bed.gz"
#  [44] "-rw-rw-r-- 1 kk319 reddylab  958 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_5_merge.bed.gz"
#  [45] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_6_merge.bed.gz"
#  [46] "-rw-rw-r-- 1 kk319 reddylab 1.6K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_7_merge.bed.gz"
#  [47] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_8_merge.bed.gz"
#  [48] "-rw-rw-r-- 1 kk319 reddylab  359 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/FOX_9_merge.bed.gz"
#  [49] "-rw-rw-r-- 1 kk319 reddylab  544 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GATA_merge.bed.gz"
#  [50] "-rw-rw-r-- 1 kk319 reddylab  616 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GCM_merge.bed.gz"
#  [51] "-rw-rw-r-- 1 kk319 reddylab 8.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GC-tract_merge.bed.gz"
#  [52] "-rw-rw-r-- 1 kk319 reddylab  580 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GFI_merge.bed.gz"
#  [53] "-rw-rw-r-- 1 kk319 reddylab 1.9K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GLI_merge.bed.gz"
#  [54] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GLIS_merge.bed.gz"
#  [55] "-rw-rw-r-- 1 kk319 reddylab  177 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GMEB2_1_merge.bed.gz"
#  [56] "-rw-rw-r-- 1 kk319 reddylab  539 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GMEB2_2_merge.bed.gz"
#  [57] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GMEB2_3_merge.bed.gz"
#  [58] "-rw-rw-r-- 1 kk319 reddylab  843 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/GRHL_merge.bed.gz"
#  [59] "-rw-rw-r-- 1 kk319 reddylab  204 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HAND1_merge.bed.gz"
#  [60] "-rw-rw-r-- 1 kk319 reddylab  122 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_10_merge.bed.gz"
#  [61] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_11_merge.bed.gz"
#  [62] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_12_merge.bed.gz"
#  [63] "-rw-rw-r-- 1 kk319 reddylab  252 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_13_merge.bed.gz"
#  [64] "-rw-rw-r-- 1 kk319 reddylab  143 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_14_merge.bed.gz"
#  [65] "-rw-rw-r-- 1 kk319 reddylab  163 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_15_merge.bed.gz"
#  [66] "-rw-rw-r-- 1 kk319 reddylab  221 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_16_merge.bed.gz"
#  [67] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_17_merge.bed.gz"
#  [68] "-rw-rw-r-- 1 kk319 reddylab  392 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_18_merge.bed.gz"
#  [69] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_19_merge.bed.gz"
#  [70] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_1_merge.bed.gz"
#  [71] "-rw-rw-r-- 1 kk319 reddylab  964 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_20_merge.bed.gz"
#  [72] "-rw-rw-r-- 1 kk319 reddylab  543 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_21_merge.bed.gz"
#  [73] "-rw-rw-r-- 1 kk319 reddylab 2.6K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_22_merge.bed.gz"
#  [74] "-rw-rw-r-- 1 kk319 reddylab  175 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_23_merge.bed.gz"
#  [75] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_24_merge.bed.gz"
#  [76] "-rw-rw-r-- 1 kk319 reddylab  139 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_25_merge.bed.gz"
#  [77] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_2_merge.bed.gz"
#  [78] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_3_merge.bed.gz"
#  [79] "-rw-rw-r-- 1 kk319 reddylab  183 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_4_merge.bed.gz"
#  [80] "-rw-rw-r-- 1 kk319 reddylab  289 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_5_merge.bed.gz"
#  [81] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_6_merge.bed.gz"
#  [82] "-rw-rw-r-- 1 kk319 reddylab  130 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_7_merge.bed.gz"
#  [83] "-rw-rw-r-- 1 kk319 reddylab  346 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_8_merge.bed.gz"
#  [84] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HD_9_merge.bed.gz"
#  [85] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HEN1_merge.bed.gz"
#  [86] "-rw-rw-r-- 1 kk319 reddylab  586 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HIC_1_merge.bed.gz"
#  [87] "-rw-rw-r-- 1 kk319 reddylab  486 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HIC_2_merge.bed.gz"
#  [88] "-rw-rw-r-- 1 kk319 reddylab  564 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HIF_merge.bed.gz"
#  [89] "-rw-rw-r-- 1 kk319 reddylab  664 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HINFP1_1_merge.bed.gz"
#  [90] "-rw-rw-r-- 1 kk319 reddylab  162 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HINFP1_2_merge.bed.gz"
#  [91] "-rw-rw-r-- 1 kk319 reddylab  188 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HINFP1_3_merge.bed.gz"
#  [92] "-rw-rw-r-- 1 kk319 reddylab  138 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HLTF_merge.bed.gz"
#  [93] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HOMEZ_merge.bed.gz"
#  [94] "-rw-rw-r-- 1 kk319 reddylab  543 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HSF_merge.bed.gz"
#  [95] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/HSFY2_merge.bed.gz"
#  [96] "-rw-rw-r-- 1 kk319 reddylab 1.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/INSM1_merge.bed.gz"
#  [97] "-rw-rw-r-- 1 kk319 reddylab  383 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/IRF_1_merge.bed.gz"
#  [98] "-rw-rw-r-- 1 kk319 reddylab 2.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/IRF_2_merge.bed.gz"
#  [99] "-rw-rw-r-- 1 kk319 reddylab  111 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/IRF_3_merge.bed.gz"
# [100] "-rw-rw-r-- 1 kk319 reddylab  110 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/IRF_4_merge.bed.gz"
# [101] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/KAISO_merge.bed.gz"
# [102] "-rw-rw-r-- 1 kk319 reddylab 4.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/KLF_SP_1_merge.bed.gz"
# [103] "-rw-rw-r-- 1 kk319 reddylab 8.9K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/KLF_SP_2_merge.bed.gz"
# [104] "-rw-rw-r-- 1 kk319 reddylab  724 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/KLF_SP_3_merge.bed.gz"
# [105] "-rw-rw-r-- 1 kk319 reddylab  682 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/LEF1_merge.bed.gz"
# [106] "-rw-rw-r-- 1 kk319 reddylab  124 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/LIN54_merge.bed.gz"
# [107] "-rw-rw-r-- 1 kk319 reddylab  919 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MAF_merge.bed.gz"
# [108] "-rw-rw-r-- 1 kk319 reddylab  850 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MBD2_merge.bed.gz"
# [109] "-rw-rw-r-- 1 kk319 reddylab  888 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MECP2_merge.bed.gz"
# [110] "-rw-rw-r-- 1 kk319 reddylab  448 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MEF2_merge.bed.gz"
# [111] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MFZ1_merge.bed.gz"
# [112] "-rw-rw-r-- 1 kk319 reddylab  439 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MIES_merge.bed.gz"
# [113] "-rw-rw-r-- 1 kk319 reddylab  461 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MTF1_merge.bed.gz"
# [114] "-rw-rw-r-- 1 kk319 reddylab  168 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MYB_1_merge.bed.gz"
# [115] "-rw-rw-r-- 1 kk319 reddylab  136 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MYB_2_merge.bed.gz"
# [116] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MYB_3_merge.bed.gz"
# [117] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MYB_4_merge.bed.gz"
# [118] "-rw-rw-r-- 1 kk319 reddylab  175 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MYB_5_merge.bed.gz"
# [119] "-rw-rw-r-- 1 kk319 reddylab 2.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/MZF1_merge.bed.gz"
# [120] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFAC_2_merge.bed.gz"
# [121] "-rw-rw-r-- 1 kk319 reddylab  587 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFAT_1_merge.bed.gz"
# [122] "-rw-rw-r-- 1 kk319 reddylab  947 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFAT_2_merge.bed.gz"
# [123] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFAT_3_merge.bed.gz"
# [124] "-rw-rw-r-- 1 kk319 reddylab  376 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFAT_4_merge.bed.gz"
# [125] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFI_1_merge.bed.gz"
# [126] "-rw-rw-r-- 1 kk319 reddylab  861 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFI_2_merge.bed.gz"
# [127] "-rw-rw-r-- 1 kk319 reddylab 2.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFI_3_merge.bed.gz"
# [128] "-rw-rw-r-- 1 kk319 reddylab 1.6K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFKB_1_merge.bed.gz"
# [129] "-rw-rw-r-- 1 kk319 reddylab  908 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFKB_2_merge.bed.gz"
# [130] "-rw-rw-r-- 1 kk319 reddylab  814 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFKB_3_merge.bed.gz"
# [131] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NFY_merge.bed.gz"
# [132] "-rw-rw-r-- 1 kk319 reddylab  508 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_10_merge.bed.gz"
# [133] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_11_merge.bed.gz"
# [134] "-rw-rw-r-- 1 kk319 reddylab 2.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_12_merge.bed.gz"
# [135] "-rw-rw-r-- 1 kk319 reddylab  644 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_13_merge.bed.gz"
# [136] "-rw-rw-r-- 1 kk319 reddylab  190 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_14_merge.bed.gz"
# [137] "-rw-rw-r-- 1 kk319 reddylab 1.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_15_merge.bed.gz"
# [138] "-rw-rw-r-- 1 kk319 reddylab 2.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_16_merge.bed.gz"
# [139] "-rw-rw-r-- 1 kk319 reddylab 1.9K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_17_merge.bed.gz"
# [140] "-rw-rw-r-- 1 kk319 reddylab 2.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_18_merge.bed.gz"
# [141] "-rw-rw-r-- 1 kk319 reddylab 1.5K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_19_merge.bed.gz"
# [142] "-rw-rw-r-- 1 kk319 reddylab 1.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_1_merge.bed.gz"
# [143] "-rw-rw-r-- 1 kk319 reddylab  654 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_20_merge.bed.gz"
# [144] "-rw-rw-r-- 1 kk319 reddylab  418 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR2E3_merge.bed.gz"
# [145] "-rw-rw-r-- 1 kk319 reddylab  150 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_2_merge.bed.gz"
# [146] "-rw-rw-r-- 1 kk319 reddylab 4.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_3_merge.bed.gz"
# [147] "-rw-rw-r-- 1 kk319 reddylab  614 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_4_merge.bed.gz"
# [148] "-rw-rw-r-- 1 kk319 reddylab  275 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_5_merge.bed.gz"
# [149] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_6_merge.bed.gz"
# [150] "-rw-rw-r-- 1 kk319 reddylab  551 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_7_merge.bed.gz"
# [151] "-rw-rw-r-- 1 kk319 reddylab  671 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_8_merge.bed.gz"
# [152] "-rw-rw-r-- 1 kk319 reddylab  174 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NR_9_merge.bed.gz"
# [153] "-rw-rw-r-- 1 kk319 reddylab 1005 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/NRF1_merge.bed.gz"
# [154] "-rw-rw-r-- 1 kk319 reddylab  502 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/OCT4+SOX2_merge.bed.gz"
# [155] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/OSR2_merge.bed.gz"
# [156] "-rw-rw-r-- 1 kk319 reddylab   97 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/OVOL1_merge.bed.gz"
# [157] "-rw-rw-r-- 1 kk319 reddylab  952 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/P53-like_1_merge.bed.gz"
# [158] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PAX_1_merge.bed.gz"
# [159] "-rw-rw-r-- 1 kk319 reddylab 1.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PAX_2_merge.bed.gz"
# [160] "-rw-rw-r-- 1 kk319 reddylab  319 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PAX-halfsite_merge.bed.gz"
# [161] "-rw-rw-r-- 1 kk319 reddylab 1.5K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PLAG1_merge.bed.gz"
# [162] "-rw-rw-r-- 1 kk319 reddylab  286 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/POU_1_merge.bed.gz"
# [163] "-rw-rw-r-- 1 kk319 reddylab  191 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/POU_2_merge.bed.gz"
# [164] "-rw-rw-r-- 1 kk319 reddylab  456 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/POU_3_merge.bed.gz"
# [165] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PRDM14_merge.bed.gz"
# [166] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PRDM1_merge.bed.gz"
# [167] "-rw-rw-r-- 1 kk319 reddylab  858 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PRDM4_merge.bed.gz"
# [168] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/PROX1_merge.bed.gz"
# [169] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RBPJ_merge.bed.gz"
# [170] "-rw-rw-r-- 1 kk319 reddylab 2.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/REL-halfsite_merge.bed.gz"
# [171] "-rw-rw-r-- 1 kk319 reddylab 1.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/REST_NRSF_merge.bed.gz"
# [172] "-rw-rw-r-- 1 kk319 reddylab 1.6K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RFX_1_merge.bed.gz"
# [173] "-rw-rw-r-- 1 kk319 reddylab  263 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RFX_2_merge.bed.gz"
# [174] "-rw-rw-r-- 1 kk319 reddylab  906 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RFX_3_merge.bed.gz"
# [175] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RUNX_1_merge.bed.gz"
# [176] "-rw-rw-r-- 1 kk319 reddylab  672 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/RUNX_2_merge.bed.gz"
# [177] "-rw-rw-r-- 1 kk319 reddylab  290 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SCRT1_merge.bed.gz"
# [178] "-rw-rw-r-- 1 kk319 reddylab  168 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SIX_1_merge.bed.gz"
# [179] "-rw-rw-r-- 1 kk319 reddylab  169 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SIX_2_merge.bed.gz"
# [180] "-rw-rw-r-- 1 kk319 reddylab 2.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SMAD_merge.bed.gz"
# [181] "-rw-rw-r-- 1 kk319 reddylab  757 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SMARCA1_merge.bed.gz"
# [182] "-rw-rw-r-- 1 kk319 reddylab  813 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SMARCA5_merge.bed.gz"
# [183] "-rw-rw-r-- 1 kk319 reddylab  954 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SNAI2_merge.bed.gz"
# [184] "-rw-rw-r-- 1 kk319 reddylab 1.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_1_merge.bed.gz"
# [185] "-rw-rw-r-- 1 kk319 reddylab  287 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_2_merge.bed.gz"
# [186] "-rw-rw-r-- 1 kk319 reddylab  349 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_3_merge.bed.gz"
# [187] "-rw-rw-r-- 1 kk319 reddylab  225 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_4_merge.bed.gz"
# [188] "-rw-rw-r-- 1 kk319 reddylab  138 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_5_merge.bed.gz"
# [189] "-rw-rw-r-- 1 kk319 reddylab  432 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_6_merge.bed.gz"
# [190] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_7_merge.bed.gz"
# [191] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SOX_8_merge.bed.gz"
# [192] "-rw-rw-r-- 1 kk319 reddylab  233 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SPDEF_1_merge.bed.gz"
# [193] "-rw-rw-r-- 1 kk319 reddylab  186 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SPDEF_2_merge.bed.gz"
# [194] "-rw-rw-r-- 1 kk319 reddylab  748 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SPI_merge.bed.gz"
# [195] "-rw-rw-r-- 1 kk319 reddylab  690 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SPZ1_merge.bed.gz"
# [196] "-rw-rw-r-- 1 kk319 reddylab 2.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SREBF1_merge.bed.gz"
# [197] "-rw-rw-r-- 1 kk319 reddylab  325 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/SRF_merge.bed.gz"
# [198] "-rw-rw-r-- 1 kk319 reddylab  319 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/STAT_1_merge.bed.gz"
# [199] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/STAT_2_merge.bed.gz"
# [200] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TATA_merge.bed.gz"
# [201] "-rw-rw-r-- 1 kk319 reddylab  205 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TBX_1_merge.bed.gz"
# [202] "-rw-rw-r-- 1 kk319 reddylab  637 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TBX_2_merge.bed.gz"
# [203] "-rw-rw-r-- 1 kk319 reddylab 2.0K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TBX_3_merge.bed.gz"
# [204] "-rw-rw-r-- 1 kk319 reddylab 2.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TBX_4_merge.bed.gz"
# [205] "-rw-rw-r-- 1 kk319 reddylab  533 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TCF_LEF_merge.bed.gz"
# [206] "-rw-rw-r-- 1 kk319 reddylab  653 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TEAD_merge.bed.gz"
# [207] "-rw-rw-r-- 1 kk319 reddylab 3.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TFAP2_1_merge.bed.gz"
# [208] "-rw-rw-r-- 1 kk319 reddylab 1020 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TFAP2_2_merge.bed.gz"
# [209] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/TFCP2_merge.bed.gz"
# [210] "-rw-rw-r-- 1 kk319 reddylab  870 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/THAP1_merge.bed.gz"
# [211] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/YY1_merge.bed.gz"
# [212] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBED1_merge.bed.gz"
# [213] "-rw-rw-r-- 1 kk319 reddylab  319 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBTB14_merge.bed.gz"
# [214] "-rw-rw-r-- 1 kk319 reddylab  727 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBTB48_merge.bed.gz"
# [215] "-rw-rw-r-- 1 kk319 reddylab  508 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBTB49_merge.bed.gz"
# [216] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBTB6_merge.bed.gz"
# [217] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZBTB7A_merge.bed.gz"
# [218] "-rw-rw-r-- 1 kk319 reddylab 1.3K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZFN121_merge.bed.gz"
# [219] "-rw-rw-r-- 1 kk319 reddylab 2.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZFX_merge.bed.gz"
# [220] "-rw-rw-r-- 1 kk319 reddylab 3.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZIC_2_merge.bed.gz"
# [221] "-rw-rw-r-- 1 kk319 reddylab 1.8K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZIC_merge.bed.gz"
# [222] "-rw-rw-r-- 1 kk319 reddylab  396 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZIM3_merge.bed.gz"
# [223] "-rw-rw-r-- 1 kk319 reddylab  775 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZKSCAN1_merge.bed.gz"
# [224] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF134_merge.bed.gz"
# [225] "-rw-rw-r-- 1 kk319 reddylab  319 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF136_merge.bed.gz"
# [226] "-rw-rw-r-- 1 kk319 reddylab  571 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF140_merge.bed.gz"
# [227] "-rw-rw-r-- 1 kk319 reddylab 2.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF143_merge.bed.gz"
# [228] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF146_merge.bed.gz"
# [229] "-rw-rw-r-- 1 kk319 reddylab  142 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF232_merge.bed.gz"
# [230] "-rw-rw-r-- 1 kk319 reddylab  154 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF24_merge.bed.gz"
# [231] "-rw-rw-r-- 1 kk319 reddylab  363 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF250_merge.bed.gz"
# [232] "-rw-rw-r-- 1 kk319 reddylab 1011 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF257_merge.bed.gz"
# [233] "-rw-rw-r-- 1 kk319 reddylab  723 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF274_merge.bed.gz"
# [234] "-rw-rw-r-- 1 kk319 reddylab  634 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF282_merge.bed.gz"
# [235] "-rw-rw-r-- 1 kk319 reddylab  806 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF28_merge.bed.gz"
# [236] "-rw-rw-r-- 1 kk319 reddylab  300 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF306_merge.bed.gz"
# [237] "-rw-rw-r-- 1 kk319 reddylab  135 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF317_merge.bed.gz"
# [238] "-rw-rw-r-- 1 kk319 reddylab 2.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF320_merge.bed.gz"
# [239] "-rw-rw-r-- 1 kk319 reddylab 2.0K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF324_merge.bed.gz"
# [240] "-rw-rw-r-- 1 kk319 reddylab  430 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF329_merge.bed.gz"
# [241] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF331_merge.bed.gz"
# [242] "-rw-rw-r-- 1 kk319 reddylab  939 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF332_merge.bed.gz"
# [243] "-rw-rw-r-- 1 kk319 reddylab 1.9K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF335_merge.bed.gz"
# [244] "-rw-rw-r-- 1 kk319 reddylab 2.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF354_merge.bed.gz"
# [245] "-rw-rw-r-- 1 kk319 reddylab  572 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF382_merge.bed.gz"
# [246] "-rw-rw-r-- 1 kk319 reddylab  224 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF384_1_merge.bed.gz"
# [247] "-rw-rw-r-- 1 kk319 reddylab  632 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF384_2_merge.bed.gz"
# [248] "-rw-rw-r-- 1 kk319 reddylab  295 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF410_merge.bed.gz"
# [249] "-rw-rw-r-- 1 kk319 reddylab  704 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF418_merge.bed.gz"
# [250] "-rw-rw-r-- 1 kk319 reddylab 1.5K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF41_merge.bed.gz"
# [251] "-rw-rw-r-- 1 kk319 reddylab  416 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF423_merge.bed.gz"
# [252] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF435_merge.bed.gz"
# [253] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF436_merge.bed.gz"
# [254] "-rw-rw-r-- 1 kk319 reddylab 1.4K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF449_merge.bed.gz"
# [255] "-rw-rw-r-- 1 kk319 reddylab  165 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF490_merge.bed.gz"
# [256] "-rw-rw-r-- 1 kk319 reddylab 1.1K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF524_merge.bed.gz"
# [257] "-rw-rw-r-- 1 kk319 reddylab  815 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF528_merge.bed.gz"
# [258] "-rw-rw-r-- 1 kk319 reddylab  995 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF53_merge.bed.gz"
# [259] "-rw-rw-r-- 1 kk319 reddylab  425 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF547_merge.bed.gz"
# [260] "-rw-rw-r-- 1 kk319 reddylab  658 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF549_merge.bed.gz"
# [261] "-rw-rw-r-- 1 kk319 reddylab 1.2K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF554_merge.bed.gz"
# [262] "-rw-rw-r-- 1 kk319 reddylab 1.9K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF563_merge.bed.gz"
# [263] "-rw-rw-r-- 1 kk319 reddylab  619 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF586_merge.bed.gz"
# [264] "-rw-rw-r-- 1 kk319 reddylab 1.5K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF667_merge.bed.gz"
# [265] "-rw-rw-r-- 1 kk319 reddylab  562 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF680_merge.bed.gz"
# [266] "-rw-rw-r-- 1 kk319 reddylab  739 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF708_merge.bed.gz"
# [267] "-rw-rw-r-- 1 kk319 reddylab   20 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF713_merge.bed.gz"
# [268] "-rw-rw-r-- 1 kk319 reddylab 1.7K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF768_merge.bed.gz"
# [269] "-rw-rw-r-- 1 kk319 reddylab  463 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF784_merge.bed.gz"
# [270] "-rw-rw-r-- 1 kk319 reddylab  492 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZNF85_merge.bed.gz"
# [271] "-rw-rw-r-- 1 kk319 reddylab 1.6K Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZSCAN3_merge.bed.gz"
# [272] "-rw-rw-r-- 1 kk319 reddylab  463 Oct 12 19:41 /home/mount/work/out/proj_combeffect/annotation_fragment/Input1/target_PER1/ZSCAN4_merge.bed.gz"

# %% [markdown]
# **Check environment**

# %%
detectCores()
# Out:
# [1] 56

# %%
mem_used()
# Out:
# 76.8 MB

# %% [markdown]
# ## Import library size

# %%
###################################################
# Import library size
###################################################

### Helper function to get
get_group = function(idn_sample){
    idn = idn_sample
    
    idn = str_replace(
        string = idn, 
        pattern = "Input[0-9]", 
        replacement = "Input")
    
    idn = str_remove(
        string = idn, 
        pattern = "_20x")
    
    idn = str_replace(
        string = idn, 
        pattern = "TFX[0-9]_", 
        replacement="TFX_")
    return(idn)
}

### set path
fdiry = file.path(FD_RES, "source")
fname = "library_size.txt"
fpath = file.path(fdiry, fname)

### import library size
ctypes = c(col_integer(), col_character())
cnames = c("Size", "FPath")
dat_lib = read_tsv(fpath, col_types=ctypes, col_names = cnames)

### remove the total size
dat_lib = dat_lib %>% dplyr::filter(FPath != "total")

### summarize info from the file path
### stackoverflow: Extract only folder name right before filename from full path
dat_lib = dat_lib %>% 
    #mutate(Sample = tools::file_path_sans_ext(basename(FPath))) %>%
    mutate(Sample = basename(dirname(FPath))) %>%
    mutate(Group = get_group(Sample))
dat_lib = dat_lib %>% dplyr::select(Size, Sample, Group)
dat_lib
# Out:
#    Size      Sample              Group
# 1  371718546 Input1_20x          Input
# 2   18666630 Input1              Input
# 3  347635732 Input2_20x          Input
# 4   20167924 Input2              Input
# 5  349994051 Input3_20x          Input
# 6   23280988 Input3              Input
# 7  413508358 Input4_20x          Input
# 8   19003938 Input4              Input
# 9  341110487 Input5_20x          Input
# 10  15325016 Input5              Input
# 11  48376253 TFX2_AZD2906        TFX_AZD2906
# 12  52542517 TFX2_AZD9567        TFX_AZD9567
# 13  43646484 TFX2_CORT108297     TFX_CORT108297
# 14  41732268 TFX2_CpdA           TFX_CpdA
# 15  45413539 TFX2_Dex            TFX_Dex
# 16  43844606 TFX2_DMSO           TFX_DMSO
# 17  56207769 TFX2_GW870086       TFX_GW870086
# 18  47829936 TFX2_Hydrocortisone TFX_Hydrocortisone
# 19  38120420 TFX2_Mapracorat     TFX_Mapracorat
# 20  47687319 TFX2_RU486          TFX_RU486
# 21  45455167 TFX2_ZK216348       TFX_ZK216348
# 22  26840149 TFX3_AZD2906        TFX_AZD2906
# 23  44435989 TFX3_AZD9567        TFX_AZD9567
# 24  32701206 TFX3_CORT108297     TFX_CORT108297
# 25  26352610 TFX3_CpdA           TFX_CpdA
# 26  26400671 TFX3_Dex            TFX_Dex
# 27  26819569 TFX3_DMSO           TFX_DMSO
# 28  36774709 TFX3_GW870086       TFX_GW870086
# 29  40293787 TFX3_Hydrocortisone TFX_Hydrocortisone
# 30  26384034 TFX3_Mapracorat     TFX_Mapracorat
# 31  31454676 TFX3_RU486          TFX_RU486
# 32  41139261 TFX3_ZK216348       TFX_ZK216348
# 33  27175305 TFX4_AZD2906        TFX_AZD2906
# 34  33610712 TFX4_AZD9567        TFX_AZD9567
# 35  59429741 TFX4_CORT108297     TFX_CORT108297
# 36  31202573 TFX4_CpdA           TFX_CpdA
# 37  34590086 TFX4_Dex            TFX_Dex
# 38  30951533 TFX4_DMSO           TFX_DMSO
# 39  43395226 TFX4_GW870086       TFX_GW870086
# 40  27190016 TFX4_Hydrocortisone TFX_Hydrocortisone
# 41  36460601 TFX4_Mapracorat     TFX_Mapracorat
# 42  31196111 TFX4_RU486          TFX_RU486
# 43  38035173 TFX4_ZK216348       TFX_ZK216348
# 44  43862195 TFX5_AZD2906        TFX_AZD2906
# 45  48356547 TFX5_AZD9567        TFX_AZD9567
# 46  42880899 TFX5_CORT108297     TFX_CORT108297
# 47  40239413 TFX5_CpdA           TFX_CpdA
# 48  42310249 TFX5_Dex            TFX_Dex
# 49  28859151 TFX5_DMSO           TFX_DMSO
# 50  39710444 TFX5_GW870086       TFX_GW870086
# 51  34580732 TFX5_Hydrocortisone TFX_Hydrocortisone
# 52  48311553 TFX5_Mapracorat     TFX_Mapracorat
# 53  49785981 TFX5_RU486          TFX_RU486
# 54  35907183 TFX5_ZK216348       TFX_ZK216348

# %% [markdown]
# ## Run linear model on each motif

# %%
### arguments
TARGET = "target_PER1"
IS_INPUT20X = TRUE
THRESHOLD = 10
#FDIRY  = "test_marginal_pool"
FDIRY  = "test_marginal_split"

### set samples and path
SAMPLES_TOT = c(
    paste0("Input", 1:5),
    paste0("Input", 1:5, "_20x"),
    paste0("TFX",   2:5, "_DMSO"),
    paste0("TFX",   2:5, "_Dex"))

SAMPLES_INP = c(
    paste0("Input", 1:5),
    paste0("TFX",   2:5, "_DMSO"),
    paste0("TFX",   2:5, "_Dex"))

SAMPLES_INP20X = c(
    paste0("Input", 1:5, "_20x"),
    paste0("TFX",   2:5, "_DMSO"),
    paste0("TFX",   2:5, "_Dex"))

if (IS_INPUT20X) {
    SAMPLES = SAMPLES_INP20X
    FDIRY   = paste0(FDIRY, "_input20x")
} else {
    SAMPLES = SAMPLES_INP
}
FD_OUT = file.path(FD_RES, "model_linear", FDIRY, TARGET)
dir.create(FD_OUT, recursive = TRUE)

### set motifs
fdiry  = file.path(FD_RES, "annotation_fragment", SAMPLES[1], TARGET)
fname  = "*_merge.bed.gz"
fglob  = file.path(fdiry, fname)
fpaths = Sys.glob(fglob)
MOTIFS = basename(fpaths)

### set column names and types
CTYPES = c(col_character(), col_integer(), col_integer(), col_integer(),
           col_character(), col_integer(), col_integer(),
           col_character(), col_double(),  col_integer())
CNAMES = c("Chrom_Frag", "Start_Frag", "End_Frag", "Count_Frag",
           "Chrom_MTF",  "Start_MTF",  "End_MTF",
           "Motif", "Score", "Overlap")

### START message
cat("Target:          ", TARGET, "\n")
cat("Output Directory:", FD_OUT, "\n")
cat("Threshold:       ", THRESHOLD, "\n")
# Out:
# Target:           target_PER1
# Output Directory: /home/mount/work/out/proj_combeffect/model_linear/test_marginal_split_input20x/target_PER1
# Threshold:        10

# %%
lst_res = foreach(fname = MOTIFS[1:5]) %do% {
    ###
    mtf = str_remove_all(fname, pattern = "_merge.bed.gz")
    msg = paste(mtf, "Start")
    print(msg); flush.console()
    
    ###
    fdiry  = file.path(FD_RES, "annotation_fragment")
    lst_dat = lapply(SAMPLES, function(sam){
        ### set path
        fpath = file.path(fdiry, sam, TARGET, fname)    
        #print(fpath); flush.console()
        
        ### import data
        dat = read_tsv(fpath, col_types=CTYPES, col_names=CNAMES)
        if (nrow(dat) == 0){
            return(NULL)
        } else {
            dat = dat %>% 
                mutate(Sample = sam) %>%
                mutate(Length_MTF = End_MTF - Start_MTF) %>%
                mutate(Length_Dif = Length_MTF - Overlap)
            return(dat)
        }
    })
    
    ### arrange data
    dat = bind_rows(lst_dat)
    
    ###################################################
    # Preprocess
    ###################################################
    #cat("+++++ Preprocess +++++\n")
    
    ### Filter out empty data
    if(nrow(dat) == 0){
        msg = paste(mtf, "Empty")
        print(msg)
        return(msg)
    }
    
    ### Filter: fully cover the motif
    dat = dat %>% dplyr::filter(Length_Dif == 0)
    
    ### Filter: No/Low coverage
    cnt = sum(dat$Count_Frag)
    if(cnt <= THRESHOLD){
        msg = paste(mtf, "Low_Coverage")
        print(msg)
        return(msg)
    }
    
    ###################################################
    # Create Count Table
    ###################################################
    #cat("+++++ Create Count Table +++++\n")
    
    ### get fragments
    dat = dat %>% 
        dplyr::select(Chrom_Frag, Start_Frag, End_Frag, Count_Frag, Sample) %>%
        distinct()

    ### count
    dat = dat %>% group_by(Sample) %>% summarise(Value = sum(Count_Frag))
    
    ### normalize counts by library size
    dat = dat %>% left_join(dat_lib, by="Sample")
    dat = dat %>%
        mutate(Norm_Value    = Value / Size) %>% 
        mutate(Lognorm_Value = log10(Value) - log10(Size)) %>%
        mutate(X = Group)
    
    ###################################################
    # Analyze w/ Linear Model
    ###################################################
    #cat("+++++ Analyze +++++\n")
    
    ### create design matrix
    idxs  = c("Input", "TFX_DMSO", "TFX_Dex")
    dat$X = factor(dat$X, levels=idxs)
    X = model.matrix(~X, dat)
    y = dat$Norm_Value

    ### setup design matrix
    X[,"XTFX_DMSO"] = X[,"XTFX_DMSO"] + X[,"XTFX_Dex"]
    
    ### fit model and get the summary
    fit = lm(y ~ X + 0)
    
    ### arrange
    lst = list()
    lst$fit = fit
    lst$cnt = dat
    lst$X   = X
    lst$y   = y
    
    ### store the results
    fdiry = FD_OUT
    fname = paste0(mtf, ".RDS") # str_replace(mtf, pattern = "/", replacement = "_")
    fpath = file.path(fdiry, fname)
    
    #dir.create(fdiry)
    saveRDS(lst, fpath)
    
    ###
    msg = paste(mtf, "Done")
    print(msg)
    return(msg)
}
# Out:
# [1] "AHR Start"
# [1] "AHR Done"
# [1] "AIRE Start"
# [1] "AIRE Done"
# [1] "AP1_1 Start"
# [1] "AP1_1 Done"
# [1] "AP1_2 Start"
# [1] "AP1_2 Done"
# [1] "ARI5A Start"
# [1] "ARI5A Empty"
