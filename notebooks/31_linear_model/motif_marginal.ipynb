# %% [markdown]
# # Estimate motif marginal effect

# %% [markdown]
# **Set environment**

# %%
source ../config_duke.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect

# %% [markdown]
# **R script**

# %%
cat > motif_marginal.R << 'EOF'

###################################################
# Set environment
###################################################
cat("\n++++++++++ Set environment  ++++++++++\n")

#source("/home/mount/project/config_sing.R")
source("config_sing.R")

###################################################
# Set global variables
###################################################
cat("\n++++++++++ Set global variables ++++++++++\n")

### Get argument: Chromomsome
ARGS            = commandArgs(trailingOnly=TRUE)
TARGET          = as.character(ARGS[1])  # which chromosome or region to run
IS_INPUT20X     = as.logical(ARGS[2])    # is the new input being used
IS_LOG          = as.logical(ARGS[3])
FDIRY           = as.character(ARGS[4])  # the name of the output folder
N_CORE          = as.integer(ARGS[5])    # number of cores to register during the parallelization
THRESHOLD_COVER = as.integer(ARGS[6])    # threshold for the low coverage filteration
THRESHOLD_MOTIF = as.numeric(ARGS[7])    # threshold for the motif score filteration

### set global variables
SAMPLES_INP = c(
    paste0("Input", 1:5),
    paste0("TFX",   2:5, "_DMSO"),
    paste0("TFX",   2:5, "_Dex"))

SAMPLES_INP20X = c(
    paste0("Input", 1:5, "_20x"),
    paste0("TFX",   2:5, "_DMSO"),
    paste0("TFX",   2:5, "_Dex"))

if (IS_INPUT20X) {
    SAMPLES = SAMPLES_INP20X
    FDIRY   = paste0(FDIRY, "_", "input20x")
} else {
    SAMPLES = SAMPLES_INP
}

if (IS_LOG) {
    FDIRY   = paste0(FDIRY, "_", "log")
} 

FD_OUT = file.path(FD_RES, "model_linear", FDIRY, TARGET)
dir.create(FD_OUT, recursive = TRUE, showWarnings = FALSE)

### set motifs
fdiry  = file.path(FD_RES, "annotation_fragment", SAMPLES[1], TARGET)
fname  = "*_merge.bed.gz"
fglob  = file.path(fdiry, fname)
fpaths = Sys.glob(fglob)
MOTIFS = basename(fpaths)

### set column names and types
CTYPES = c(col_character(), col_integer(), col_integer(), col_integer(),
           col_character(), col_integer(), col_integer(),
           col_character(), col_double(),  col_integer())
CNAMES = c("Chrom_Frag", "Start_Frag", "End_Frag", "Count_Frag",
           "Chrom_MTF",  "Start_MTF",  "End_MTF",
           "Motif", "Score", "Overlap")
           

### print start message
cat("Target:           ", TARGET,          "\n")
cat("Is Input20x used? ", IS_INPUT20X,     "\n")
cat("Is Log transform? ", IS_LOG,          "\n")
cat("Output Directory: ", FD_OUT,          "\n")
cat("#Cores Resgister: ", N_CORE,          "\n")
cat("Threshold (Cover):", THRESHOLD_COVER, "\n")
cat("Threshold (Motif):", THRESHOLD_MOTIF, "\n")

###################################################
# Import library size
###################################################
cat("\n++++++++++ Import library size ++++++++++\n")

### Helper function to get
get_group = function(idn_sample){
    idn = idn_sample
    
    idn = str_replace(
        string = idn, 
        pattern = "Input[0-9]", 
        replacement = "Input")
    
    idn = str_remove(
        string = idn, 
        pattern = "_20x")
    
    idn = str_replace(
        string = idn, 
        pattern = "TFX[0-9]_", 
        replacement="TFX_")
    return(idn)
}

### set path
fdiry = file.path(FD_RES, "source")
fname = "library_size.txt"
fpath = file.path(fdiry, fname)

### import library size
ctypes = c(col_integer(), col_character())
cnames = c("Size", "FPath")
dat_lib = read_tsv(fpath, col_types=ctypes, col_names = cnames)

### remove the total size
dat_lib = dat_lib %>% dplyr::filter(FPath != "total")

### summarize info from the file path
### stackoverflow: Extract only folder name right before filename from full path
dat_lib = dat_lib %>% 
    mutate(Sample = basename(dirname(FPath))) %>%
    mutate(Group = get_group(Sample))
dat_lib = dat_lib %>% dplyr::select(Size, Sample, Group)

###################################################
# Run motif analysis
###################################################
cat("\n++++++++++ Run motif analysis ++++++++++\n")

### start
#registerDoParallel(N_CORE)
timer_start = Sys.time()

### loop through each motif to get the marginal effect
lst_res = foreach(fname = MOTIFS[1:10]) %do% {
    
    ### start message and get the name of motif
    mtf = str_remove_all(fname, pattern = "_merge.bed.gz")
    msg = paste(mtf, "Start")
    cat(msg, "\n"); flush.console()
    
    ### import fragment annotation
    fdiry  = file.path(FD_RES, "annotation_fragment")
    lst_dat = lapply(SAMPLES, function(sam){
        ### set path
        fpath = file.path(fdiry, sam, TARGET, fname)    
        msg = paste(mtf, "Import", fpath)
        cat(msg, "\n"); flush.console()
        
        ### import data
        dat = read_tsv(fpath, col_types=CTYPES, col_names=CNAMES)
        if (nrow(dat) == 0){
            return(NULL)
        } else {
            ###
            num1 = nrow(dat)    
            dat = dat %>% 
                mutate(Sample = sam) %>%
                mutate(Length_MTF = End_MTF - Start_MTF)  %>%
                mutate(Length_Dif = Length_MTF - Overlap) %>% 
                dplyr::filter(Length_Dif == 0) %>%
                dplyr::filter(Score >= THRESHOLD_MOTIF)
            num2 = nrow(dat)
            
            ###
            msg = paste(num1, num2, sep="-")
            msg = paste(mtf, "Filter", sam, msg)
            cat(msg, "\n"); flush.console()
            return(dat)
        }
    })
    
    ### arrange data
    dat = bind_rows(lst_dat)
    msg = paste(mtf, "Total", nrow(dat))
    cat(msg, "\n"); flush.console()
    
    ###################################################
    # Preprocess
    ###################################################
    #cat("+++++ Preprocess +++++\n")
    
    ### Filter out empty data
    if(nrow(dat) == 0){
        msg = paste(mtf, "Skip Empty")
        cat(msg, "\n"); flush.console()
        return(msg)
    }
    
    ### Filter: fully cover the motif and motif score
    #num1 = nrow(dat)
    #dat = dat %>% 
    #    dplyr::filter(Length_Dif == 0) %>%
    #    dplyr::filter(Score >= THRESHOLD_MOTIF)
    #num2 = nrow(dat)
    #msg = paste(num1, num2, sep="-")
    #msg = paste(mtf, "Filter", msg)
    #cat(msg, "\n"); flush.console()
    
    ### Filter out empty data    
    #if(nrow(dat) == 0){
    #    msg = paste(mtf, "Filter Empty")
    #    cat(msg, "\n"); flush.console()
    #    return(msg)
    #}
    
    ### Filter: No/Low coverage
    cnt = sum(dat$Count_Frag)
    if(cnt <= THRESHOLD_COVER){
        msg = paste(mtf, "Filter Low_Coverage")
        cat(msg, "\n"); flush.console()
        return(msg)
    }
    
    ###################################################
    # Create Count Table
    ###################################################
    #cat("+++++ Create Count Table +++++\n")
    
    ### get fragments
    dat = dat %>% 
        dplyr::select(Chrom_Frag, Start_Frag, End_Frag, Count_Frag, Sample) %>%
        distinct()

    ### get count for each sample
    dat = dat %>% group_by(Sample) %>% summarise(Value = sum(Count_Frag))
    
    ### normalize counts by library size
    dat = dat %>% left_join(dat_lib, by="Sample")
    dat = dat %>%
        mutate(Norm_Value    = Value / Size) %>% 
        mutate(Lognorm_Value = log10(Value) - log10(Size)) %>%
        mutate(X = Group)
    
    ###################################################
    # Analyze w/ Linear Model
    ###################################################
    #cat("+++++ Analyze w/ Linear Model +++++\n")
    
    ### create design matrix
    idxs  = c("Input", "TFX_DMSO", "TFX_Dex")
    dat$X = factor(dat$X, levels=idxs)
    X = model.matrix(~X, dat)
    if (IS_LOG){
        y = dat$Lognorm_Value
    } else {
        y = dat$Norm_Value
    }

    ### setup design matrix
    X[,"XTFX_DMSO"] = X[,"XTFX_DMSO"] + X[,"XTFX_Dex"]
    
    ### fit model and get the summary
    fit = lm(y ~ X + 0)
    
    ### arrange
    lst = list()
    lst$fit = fit
    lst$cnt = dat
    lst$X   = X
    lst$y   = y
    
    ### store the results
    fdiry = FD_OUT
    fname = paste0(mtf, ".RDS") # str_replace(mtf, pattern = "/", replacement = "_")
    fpath = file.path(fdiry, fname)
    saveRDS(lst, fpath)
    
    ### end message
    msg = paste(mtf, "Done")
    cat(msg, "\n"); flush.console()
    return(msg)
}

### print end message
timer = Sys.time()
cat("Timer of the loop:\n")
print(timer - timer_start)

EOF

# %% [markdown]
# ## Test: upstream of PER1 region

# %% [markdown]
# **Remove the folder**

# %% [markdown]
# `rm -rf ${FD_RES}/model_linear/marginal_filter*/target_PER1`

# %% [markdown]
# **Run all the possible combinations**

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=8G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \a
    --job-name='Marginal PER1 f00 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_per1_filter00.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
#CHROM=chrY

TARGET=target_PER1
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter00
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=0

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26604334

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=8G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \
    --job-name='Marginal PER1 f00 logT' \
    -o ${FD_LOG}/linear_model_marginal_input20x_per1_filter00_log.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
#CHROM=chrY

TARGET=target_PER1
IS_INPUT20X=TRUE
IS_LOG=TRUE
FDIRY=marginal_filter00
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=0

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26604335

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=8G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \
    --job-name='Marginal PER1 f95 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_per1_filter95.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
#CHROM=chrY

TARGET=target_PER1
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26604336

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=8G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \
    --job-name='Marginal PER1 f95 logT' \
    -o ${FD_LOG}/linear_model_marginal_input20x_per1_filter95_log.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
#CHROM=chrY

TARGET=target_PER1
IS_INPUT20X=TRUE
IS_LOG=TRUE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26604337

# %% [markdown]
# **Check**

# %%
cat ${FD_LOG}/linear_model_marginal_input20x_per1_filter00.txt
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect
#
# Slurm Array Index:
# Time Stamp:         10-15-21+20:38:03
#
#
# ++++++++++ Set environment  ++++++++++
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘pryr’
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, partial
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: iterators
# Loading required package: parallel
#
# ++++++++++ Set global variables ++++++++++
# Target:            target_PER1
# Is Input20x used?  TRUE
# Is Log transform?  FALSE
# Output Directory:  /home/mount/work/out/proj_combeffect/model_linear/marginal_filter00_input20x/target_PER1
# #Cores Resgister:  20
# Threshold (Cover): 10
# Threshold (Motif): 0
#
# ++++++++++ Import library size ++++++++++
#
# ++++++++++ Run motif analysis ++++++++++
# AHR Start
# AIRE Start
# AP1_1 Start
# AP1_2 Start
# ARI5A Start
# ARI5B Start
# BATF Start
# BCL6_1 Start
# BCL6_2 Start
# CCAAT_CEBP Start
# CENBP Start
# CPEB1 Start
# CREB3_XBP1 Start
# CREB_ATF_1 Start
# CREB_ATF_2 Start
# CREB_ATF_3 Start
# CTCF Start
# CUX_1 Start
# CUX_2 Start
# CUX_3 Start
# ARI5B Skip Empty
# E2F_4 Start
# ARI5A Skip Empty
# E2F_3 Start
# CUX_3 Skip Empty
# FOX_1 Start
# AIRE Filter 1389-1333
# CUX_2 Filter 2079-2006
# AHR Filter 11572-11541
# BCL6_1 Filter 4018-3985
# CPEB1 Filter 2761-2687
# AIRE Done
# DMRT3 Start
# CREB_ATF_3 Filter 515-504
# CREB_ATF_2 Filter 11557-11369
# E2F_3 Filter 1745-1667
# CUX_2 Done
# FEZF1 Start
# AP1_1 Filter 16060-15845
# CPEB1 Done
# Ebox_CAGCTG Start
# AP1_2 Filter 20345-20053
# BCL6_1 Done
# Ebox_CACCTG Start
# CREB_ATF_3 Done
# ETS_2 Start
# CUX_1 Filter 2399-2305
# AHR Done
# DDIT3+CEBPA Start
# E2F_3 Done
# FOX_6 Start
# BCL6_2 Filter 17450-17124
# CENBP Filter 6668-6416
# CCAAT_CEBP Filter 9361-9172
# DMRT3 Skip Empty
# FOX_3 Start
# BATF Filter 16528-16145
# CREB_ATF_2 Done
# ETS_1 Start
# CUX_1 Done
# EWSR1_FLI1 Start
# CREB3_XBP1 Filter 17498-17188
# AP1_1 Done
# E2F_1 Start
# AP1_2 Done
# E2F_2 Start
# CENBP Done
# Ebox_CAGATGG Start
# FOX_1 Filter 2545-2471
# CCAAT_CEBP Done
# Ebox_CACGTG_2 Start
# CREB_ATF_1 Filter 30218-29790
# FOX_6 Skip Empty
# HD_15 Start
# BCL6_2 Done
# Ebox_CACGTG_1 Start
# BATF Done
# EBF1 Start
# FOX_1 Done
# HD_10 Start
# CREB3_XBP1 Done
# Ebox_CATATG Start
# E2F_4 Filter 15978-15881
# CREB_ATF_1 Done
# EGR Start
# CTCF Filter 66349-64915
# E2F_4 Done
# FOX_7 Start
# CTCF Done
# EVI1_MECOM Start
# DDIT3+CEBPA Filter 894-868
# DDIT3+CEBPA Done
# FOX_2 Start
# FEZF1 Filter 3481-3398
# FEZF1 Done
# HAND1 Start
# Ebox_CACCTG Filter 22795-22529
# FOX_3 Filter 4465-4096
# HD_15 Filter 2158-2153
# Ebox_CATATG Filter 1197-1162
# EWSR1_FLI1 Filter 7912-7541
# Ebox_CAGCTG Filter 71272-70350
# FOX_3 Done
# HD_12 Start
# HD_15 Done
# HEN1 Start
# E2F_1 Filter 10396-10298
# Ebox_CATATG Done
# GLI Start
# ETS_1 Filter 42361-41589
# EWSR1_FLI1 Done
# GRHL Start
# Ebox_CACCTG Done
# FOX_9 Start
# HD_10 Filter 1217-1116
# E2F_1 Done
# FOX_4 Start
# Ebox_CACGTG_1 Filter 25413-24982
# HD_10 Done
# HD_5 Start
# E2F_2 Filter 90764-89626
# EBF1 Filter 20453-20055
# ETS_1 Done
# GMEB2_1 Start
# Ebox_CACGTG_1 Done
# GATA Start
# Ebox_CAGCTG Done
# GFI Start
# EBF1 Done
# FOX_8 Start
# Ebox_CACGTG_2 Filter 51003-50283
# EGR Filter 57636-56581
# FOX_7 Filter 44424-43708
# Ebox_CAGATGG Filter 88509-86414
# ETS_2 Filter 143986-141323
# E2F_2 Done
# FOX_5 Start
# FOX_8 Skip Empty
# HD_17 Start
# Ebox_CACGTG_2 Done
# GCM Start
# HD_17 Skip Empty
# HIC_2 Start
# FOX_7 Done
# HD_16 Start
# EGR Done
# GLIS Start
# EVI1_MECOM Filter 8229-7811
# FOX_2 Filter 6444-6144
# Ebox_CAGATGG Done
# GC-tract Start
# FOX_2 Done
# HD_11 Start
# EVI1_MECOM Done
# GMEB2_3 Start
# HD_11 Skip Empty
# HD_6 Start
# GMEB2_3 Skip Empty
# HD_2 Start
# ETS_2 Done
# GMEB2_2 Start
# HAND1 Filter 2673-2640
# HD_6 Skip Empty
# KAISO Start
# HAND1 Done
# HD_4 Start
# KAISO Skip Empty
# NFAT_1 Start
# FOX_9 Filter 6139-6026
# GMEB2_1 Filter 1821-1760
# FOX_4 Filter 24681-24294
# HEN1 Filter 38222-37247
# FOX_9 Done
# HD_18 Start
# HD_12 Filter 27065-26676
# GLI Filter 46204-45379
# GMEB2_1 Done
# HD_24 Start
# HD_5 Filter 3985-3848
# HD_5 Done
# IRF_4 Start
# GATA Filter 8891-8724
# GFI Filter 9427-9313
# FOX_4 Done
# HD_13 Start
# GRHL Filter 15656-15357
# HD_12 Done
# HD_7 Start
# HD_24 Skip Empty
# HSFY2 Start
# HEN1 Done
# LEF1 Start
# GLI Done
# HD_22 Start
# GFI Done
# HD_21 Start
# GATA Done
# HD_19 Start
# GRHL Done
# HD_3 Start
# HSFY2 Skip Empty
# MYB_2 Start
# HD_19 Skip Empty
# HINFP1_1 Start
# FOX_5 Filter 16140-15369
# HD_3 Skip Empty
# IRF_2 Start
# FOX_5 Done
# HD_14 Start
# HIC_2 Filter 11777-11715
# HD_16 Filter 2090-2055
# GCM Filter 10001-9801
# HD_16 Done
# HIC_1 Start
# HIC_2 Done
# MAF Start
# GLIS Filter 29428-28747
# GCM Done
# HD_1 Start
# GLIS Done
# HD_23 Start
# HD_1 Skip Empty
# HINFP1_2 Start
# HD_4 Filter 1481-1443
# GMEB2_2 Filter 8169-8044
# HD_2 Filter 23667-23223
# HD_4 Done
# IRF_3 Start
# GMEB2_2 Done
# HD_25 Start
# NFAT_1 Filter 9322-9095
# HD_2 Done
# IRF_1 Start
# NFAT_1 Done
# NR_19 Start
# IRF_4 Filter 398-369
# HD_18 Filter 7158-6957
# IRF_4 Done
# NFAC_2 Start
# HD_18 Done
# HIF Start
# HD_7 Filter 675-655
# HD_13 Filter 4072-4020
# HD_7 Done
# KLF_SP_1 Start
# HD_13 Done
# HD_8 Start
# HD_21 Filter 10138-10020
# LEF1 Filter 10444-9981
# MYB_2 Filter 1926-1872
# MYB_2 Done
# NR_13 Start
# HD_21 Done
# HLTF Start
# LEF1 Done
# NFI_1 Start
# HD_22 Filter 71256-70152
# HINFP1_1 Filter 17788-17460
# HD_14 Filter 2533-2472
# HINFP1_1 Done
# MECP2 Start
# HD_14 Done
# HD_9 Start
# HD_22 Done
# HOMEZ Start
# HD_25 Filter 816-801
# HD_9 Skip Empty
# KLF_SP_3 Start
# HD_25 Done
# INSM1 Start
# IRF_2 Filter 63217-60747
# MAF Filter 20199-19865
# HIC_1 Filter 11435-11278
# HOMEZ Skip Empty
# MTF1 Start
# IRF_3 Filter 740-727
# HIC_1 Done
# LIN54 Start
# HD_23 Filter 1962-1928
# IRF_3 Done
# MZF1 Start
# MAF Done
# NFI_3 Start
# HD_23 Done
# HSF Start
# HINFP1_2 Filter 3741-3462
# HINFP1_2 Done
# MEF2 Start
# IRF_2 Done
# MYB_5 Start
# NR_19 Filter 32659-32097
# IRF_1 Filter 5054-4778
# IRF_1 Done
# MYB_4 Start
# HLTF Filter 825-818
# NFAC_2 Filter 31616-30852
# HD_8 Filter 4064-4017
# NR_19 Done
# PLAG1 Start
# HIF Filter 12598-12504
# HLTF Done
# MIES Start
# HD_8 Done
# KLF_SP_2 Start
# MYB_4 Skip Empty
# NR_15 Start
# HIF Done
# MBD2 Start
# GC-tract Filter 280342-266038
# NFAC_2 Done
# NR_18 Start
# NR_13 Filter 10891-10608
# NR_13 Done
# OSR2 Start
# NFI_1 Filter 27705-27278
# KLF_SP_1 Filter 123889-121820
# NFI_1 Done
# NR_2 Start
# MECP2 Filter 18349-18118
# KLF_SP_3 Filter 15029-14744
# MTF1 Filter 9395-9280
# MECP2 Done
# NFKB_2 Start
# LIN54 Filter 1174-1141
# MTF1 Done
# NR_11 Start
# KLF_SP_3 Done
# NFAT_4 Start
# LIN54 Done
# NFI_2 Start
# HSF Filter 15061-14900
# INSM1 Filter 49758-48756
# GC-tract Done
# HD_20 Start
# KLF_SP_1 Done
# NFAT_2 Start
# MZF1 Filter 69524-67157
# HSF Done
# MYB_1 Start
# NFI_3 Filter 79511-78169
# MYB_5 Filter 1107-1087
# PLAG1 Filter 28785-28102
# MYB_5 Done
# NR_16 Start
# INSM1 Done
# MYB_3 Start
# MEF2 Filter 6589-6335
# MIES Filter 7604-7462
# MEF2 Done
# NFKB_3 Start
# PLAG1 Done
# SMARCA1 Start
# MIES Done
# NR_10 Start
# MBD2 Filter 20903-20659
# MZF1 Done
# NR_17 Start
# MYB_3 Skip Empty
# NR_14 Start
# NFI_3 Done
# NR_4 Start
# OSR2 Filter 33672-33154
# MBD2 Done
# NFKB_1 Start
# NR_15 Filter 37274-36244
# NR_2 Filter 882-860
# NR_2 Done
# PRDM14 Start
# NR_18 Filter 61694-59594
# OSR2 Done
# RUNX_1 Start
# NR_15 Done
# P53-like_1 Start
# PRDM14 Skip Empty
# SOX_2 Start
# NR_18 Done
# PAX-halfsite Start
# NFAT_4 Filter 6790-6487
# NFKB_2 Filter 17767-17480
# NFAT_4 Done
# NR2E3 Start
# NR_11 Filter 37190-36504
# NFKB_2 Done
# NR_6 Start
# NFI_2 Filter 15698-15592
# NFAT_2 Filter 20417-19778
# NFI_2 Done
# NR_3 Start
# NR_6 Skip Empty
# RBPJ Start
# NR_11 Done
# NRF1 Start
# MYB_1 Filter 1646-1628
# NFAT_2 Done
# NR_1 Start
# MYB_1 Done
# NR_12 Start
# HD_20 Filter 18230-17988
# NR_14 Filter 1321-1298
# KLF_SP_2 Filter 282004-270156
# SMARCA1 Filter 15539-15041
# NR_14 Done
# OVOL1 Start
# NR_10 Filter 7924-7679
# HD_20 Done
# HINFP1_3 Start
# SMARCA1 Done
# TBX_1 Start
# NR_10 Done
# NR_9 Start
# NR_16 Filter 73552-71178
# NFKB_3 Filter 17859-17499
# NR_17 Filter 45468-44311
# NFKB_1 Filter 36048-35254
# RUNX_1 Filter 34785-34275
# NFKB_3 Done
# NR_7 Start
# NR_4 Filter 10834-10569
# SOX_2 Filter 3606-3586
# NFKB_1 Done
# NR_5 Start
# NR_17 Done
# PAX_2 Start
# SOX_2 Done
# TCF_LEF Start
# NR_4 Done
# PRDM4 Start
# RUNX_1 Done
# SPZ1 Start
# NR_16 Done
# PAX_1 Start
# P53-like_1 Filter 15407-14923
# PAX-halfsite Filter 6203-6188
# P53-like_1 Done
# SCRT1 Start
# PAX-halfsite Done
# SMAD Start
# NR2E3 Filter 6442-6395
# NR2E3 Done
# POU_3 Start
# OVOL1 Filter 420-408
# KLF_SP_2 Done
# NFAT_3 Start
# OVOL1 Done
# RUNX_2 Start
# NRF1 Filter 24107-23763
# NFAT_3 Skip Empty
# NR_20 Start
# TBX_1 Filter 2584-2514
# NRF1 Done
# RFX_2 Start
# NR_12 Filter 50400-48626
# RBPJ Filter 29439-29013
# NR_9 Filter 1609-1539
# TBX_1 Done
# ZIC Start
# NR_9 Done
# RFX_1 Start
# NR_1 Filter 44676-43670
# HINFP1_3 Filter 2626-2514
# RBPJ Done
# SOX_6 Start
# NR_12 Done
# OCT4+SOX2 Start
# HINFP1_3 Done
# MFZ1 Start
# NR_5 Filter 3690-3581
# NR_1 Done
# POU_1 Start
# NR_5 Done
# PROX1 Start
# TCF_LEF Filter 11270-11044
# NR_7 Filter 8114-7819
# PROX1 Skip Empty
# SOX_5 Start
# NR_3 Filter 139235-135301
# SPZ1 Filter 15022-14587
# TCF_LEF Done
# ZNF136 Start
# NR_7 Done
# REL-halfsite Start
# PAX_2 Filter 38292-37031
# SPZ1 Done
# ZBTB49 Start
# PRDM4 Filter 21845-21488
# PAX_1 Filter 29771-29089
# PAX_2 Done
# SIX_2 Start
# PRDM4 Done
# SOX_4 Start
# SCRT1 Filter 4644-4595
# PAX_1 Done
# SIX_1 Start
# SCRT1 Done
# SRF Start
# SMAD Filter 56117-55039
# NR_3 Done
# PRDM1 Start
# POU_3 Filter 7371-7142
# POU_3 Done
# SOX_1 Start
# RUNX_2 Filter 20423-19980
# RFX_2 Filter 3316-3239
# SMAD Done
# TATA Start
# RFX_2 Done
# SPDEF_2 Start
# NR_20 Filter 18635-18359
# ZIC Filter 51880-50764
# RUNX_2 Done
# SREBF1 Start
# TATA Skip Empty
# ZIC_2 Start
# NR_20 Done
# POU_2 Start
# SOX_6 Filter 7662-7356
# OCT4+SOX2 Filter 6464-6140
# ZIC Done
# ZNF331 Start
# RFX_1 Filter 44446-43344
# SOX_6 Done
# TFCP2 Start
# OCT4+SOX2 Done
# RFX_3 Start
# SOX_5 Filter 913-896
# POU_1 Filter 4759-4523
# SOX_5 Done
# TFAP2_2 Start
# POU_1 Done
# SMARCA5 Start
# TFCP2 Skip Empty
# ZNF232 Start
# RFX_1 Done
# SPDEF_1 Start
# ZNF136 Filter 4979-4651
# ZNF136 Done
# ZNF382 Start
# MFZ1 Filter 25420-25021
# ZBTB49 Filter 13101-12693
# MFZ1 Done
# NFY Start
# ZBTB49 Done
# ZNF28 Start
# SIX_2 Filter 2794-2720
# SOX_4 Filter 2717-2631
# SOX_4 Done
# TFAP2_1 Start
# SIX_1 Filter 1559-1544
# SIX_2 Done
# STAT_2 Start
# REL-halfsite Filter 61243-60423
# SIX_1 Done
# STAT_1 Start
# SRF Filter 6282-6167
# SRF Done
# ZBTB7A Start
# PRDM1 Filter 24710-24177
# SOX_1 Filter 33933-32935
# REL-halfsite Done
# SOX_7 Start
# PRDM1 Done
# SOX_3 Start
# SPDEF_2 Filter 2067-2004
# SPDEF_2 Done
# ZBTB14 Start
# SOX_7 Skip Empty
# THAP1 Start
# SOX_1 Done
# TBX_4 Start
# POU_2 Filter 2711-2581
# POU_2 Done
# SNAI2 Start
# ZNF331 Filter 27407-26487
# SREBF1 Filter 55420-54705
# ZNF232 Filter 870-852
# ZNF331 Done
# ZNF554 Start
# RFX_3 Filter 26436-26073
# ZNF232 Done
# ZNF418 Start
# SPDEF_1 Filter 4140-4059
# SREBF1 Done
# ZBTB6 Start
# TFAP2_2 Filter 27026-26574
# SPDEF_1 Done
# ZBED1 Start
# RFX_3 Done
# SPI Start
# ZNF382 Filter 13635-13048
# SMARCA5 Filter 12179-11837
# ZIC_2 Filter 97734-96619
# ZNF382 Done
# ZNF680 Start
# TFAP2_2 Done
# ZNF146 Start
# SMARCA5 Done
# TBX_2 Start
# ZBED1 Skip Empty
# ZNF257 Start
# ZNF146 Skip Empty
# ZNF410 Start
# ZNF28 Filter 14455-13333
# ZIC_2 Done
# ZNF329 Start
# STAT_2 Filter 23489-23205
# ZNF28 Done
# ZNF490 Start
# NFY Filter 27631-27026
# STAT_1 Filter 4725-4670
# STAT_2 Done
# ZFX Start
# STAT_1 Done
# ZFN121 Start
# NFY Done
# NR_8 Start
# ZBTB7A Filter 38900-38478
# TFAP2_1 Filter 86107-84907
# SOX_3 Filter 6853-6736
# SOX_3 Done
# TEAD Start
# ZBTB14 Filter 9634-9517
# SNAI2 Filter 17645-17444
# ZBTB7A Done
# ZNF317 Start
# ZBTB14 Done
# ZNF274 Start
# TBX_4 Filter 45393-43127
# THAP1 Filter 21654-21412
# SNAI2 Done
# TBX_3 Start
# TFAP2_1 Done
# ZNF143 Start
# ZNF554 Filter 32456-31413
# THAP1 Done
# ZNF24 Start
# TBX_4 Done
# ZNF134 Start
# ZNF554 Done
# ZBTB6 Filter 34361-33681
# ZNF418 Filter 15666-15231
# ZNF680 Filter 14667-14183
# ZNF680 Done
# ZNF418 Done
# ZNF784 Start
# ZNF257 Filter 20172-19877
# ZBTB6 Done
# ZNF306 Start
# TBX_2 Filter 9439-9137
# SPI Filter 14844-14459
# ZNF410 Filter 3606-3537
# TBX_2 Done
# ZNF410 Done
# ZNF768 StartZIM3 Start
#
# ZNF257 Done
# ZNF435 Start
# SPI Done
# ZBTB48 Start
# ZNF435 Skip Empty
# ZSCAN4 Start
# ZNF329 Filter 7306-7063
# ZNF490 Filter 3874-3853
# ZNF329 Done
# ZNF549 Start
# ZNF490 Done
# ZFX Filter 52584-51721
# ZFN121 Filter 23699-22628
# NR_8 Filter 14083-13701
# ZNF317 Filter 1976-1875
# ZNF274 Filter 11975-11612
# TEAD Filter 16306-15913
# ZFX Done
# ZNF324 Start
# ZNF317 Done
# ZNF528 Start
# ZFN121 Done
# ZNF320 Start
# NR_8 Done
# REST_NRSF Start
# ZNF274 Done
# ZNF436 Start
# TEAD Done
# ZNF140 Start
# TBX_3 Filter 50367-48861
# ZNF134 Filter 25199-24324
# ZNF24 Filter 3476-3384
# ZNF24 Done
# ZNF41 Start
# TBX_3 Done
# ZKSCAN1 Start
# ZNF134 Done
# ZNF354 Start
# ZNF784 Filter 7264-7117
# ZNF306 Filter 6990-6857
# ZNF784 Done
# ZNF306 Done
# ZNF524 Start
# ZNF143 Filter 77175-74949
# ZIM3 Filter 5673-5457
# ZSCAN4 Filter 6589-6396
# ZBTB48 Filter 15833-15587
# ZNF768 Filter 38024-37089
# ZIM3 Done
# ZNF332 Start
# ZSCAN4 Done
# ZBTB48 Done
# ZNF282 Start
# ZNF768 Done
# ZNF143 Done
# ZNF384_2 Start
# ZNF549 Filter 10915-10507
# ZNF549 Done
# ZNF436 Filter 27661-26327
# ZNF528 Filter 15853-15308
# ZNF140 Filter 9707-9370
# ZNF324 Filter 53593-51994
# ZNF320 Filter 60026-58372
# ZNF140 Done
# ZNF384_1 Start
# ZNF436 Done
# ZNF528 Done
# REST_NRSF Filter 38054-36769
# ZKSCAN1 Filter 17431-16954
# ZNF524 Filter 18672-18320
# ZNF354 Filter 57466-54635
# ZKSCAN1 Done
# ZNF335 Start
# ZNF324 Done
# ZNF547 Start
# ZNF320 Done
# ZNF53 Start
# REST_NRSF Done
# SOX_8 Start
# ZNF41 Filter 36806-35156
# ZNF524 Done
# SOX_8 Skip Empty
# YY1 Start
# ZNF332 Filter 19691-19299
# ZNF41 Done
# ZNF85 Start
# ZNF354 Done
# ZNF667 Start
# ZNF332 Done
# ZNF563 Start
# ZNF282 Filter 14807-14475
# ZNF282 Done
# ZNF449 Start
# ZNF384_2 Filter 7710-7243
# ZNF384_2 Done
# ZNF713 Start
# ZNF713 Skip Empty
# ZNF384_1 Filter 2689-2633
# ZNF335 Filter 42271-40996
# ZNF384_1 Done
# ZNF708 Start
# ZNF547 Filter 6093-5980
# ZNF53 Filter 20680-20516
# ZNF547 Done
# ZNF335 Done
# ZNF586 Start
# ZNF53 Done
# ZNF667 Filter 33458-32300
# ZNF563 Filter 51836-50402
# YY1 Filter 29642-29013
# ZNF667 Done
# ZNF85 Filter 11662-11327
# ZNF449 Filter 29979-29486
# ZNF85 Done
# YY1 Done
# ZNF250 Start
# ZNF563 Done
# ZNF449 Done
# ZNF708 Filter 14335-13717
# ZNF586 Filter 13823-13347
# ZNF708 Done
# ZNF586 Done
# ZNF250 Filter 5891-5511
# ZNF250 Done
# ZNF423 Start
# ZNF423 Filter 8699-8420
# ZNF423 Done
# ZSCAN3 Start
# ZSCAN3 Filter 42485-41407
# ZSCAN3 Done
# Timer of the loop:
# Time difference of 23.84817 secs
#
# Done!
# Run Time: 33 seconds

# %%
cat ${FD_LOG}/linear_model_marginal_input20x_per1_filter95.txt
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect
#
# Slurm Array Index:
# Time Stamp:         10-15-21+20:18:32
#
#
# ++++++++++ Set environment  ++++++++++
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘pryr’
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, partial
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: iterators
# Loading required package: parallel
#
# ++++++++++ Set global variables ++++++++++
# Target:            target_PER1
# Is Input20x used?  TRUE
# Is Log transform?  TRUE
# Output Directory:  /home/mount/work/out/proj_combeffect/model_linear/marginal_filter95_input20x_log/target_PER1
# #Cores Resgister:  20
# Threshold (Cover): 10
# Threshold (Motif): 10.81
#
# ++++++++++ Import library size ++++++++++
#
# ++++++++++ Run motif analysis ++++++++++
# AHR Start
# AIRE Start
# AP1_1 Start
# AP1_2 Start
# ARI5A Start
# ARI5A Skip Empty
# AIRE Filter 1389-0
# AIRE Filter Empty
# AHR Filter 11572-0
# AHR Filter Empty
# AP1_1 Filter 16060-0
# AP1_1 Filter Empty
# AP1_2 Filter 20345-560
# AP1_2 Done
# Timer of the loop:
# Time difference of 1.047383 secs
#
# Done!
# Run Time: 4 seconds

# %% [markdown]
# ## Test: chromosome Y

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=8G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \
    --job-name='Marginal PER1 f00 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_per1_filter00.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
#CHROM=chrY

TARGET=target_PER1
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter00
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=0

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26597506

# %% [markdown]
# **Check**

# %%
cat ${FD_LOG}/linear_model_marginal_input20x_chrY.txt
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect
#
# Slurm Array Index:
# Time Stamp:         10-14-21+14:40:14
#
#
# ++++++++++ Set environment  ++++++++++
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘pryr’
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, partial
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: iterators
# Loading required package: parallel
#
# ++++++++++ Set global variables ++++++++++
# Target:            chrY
# Is Input20x used?  TRUE
# Output Directory:  /home/mount/work/out/proj_combeffect/model_linear/marginal_filter95_input20x/chrY
# #Cores Resgister:  20
# Threshold (Cover): 10
# Threshold (Motif): 10.81
#
# ++++++++++ Import library size ++++++++++
#
# Done!
# Run Time: 4 seconds

# %% [markdown]
# ## Test: chromsome X

# %%
echo ${FD_PRJ}
# Out:
# /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks

# %%
### set log file directory
sbatch -p all \
    --mem=20G \
    --nodelist=x1-02-3 \
    --job-name='Test' \
    -o ./test.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun /data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks/sing_proj_combeffect.sh Rscript -e "print('hello')"
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26607225

# %%
cat ./test.txt
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect
#
# Slurm Array Index:
# Time Stamp:         10-18-21+12:55:58
#
# [1] "hello"
#
# Done!
# Run Time: 3 seconds

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=20G \
    --job-name='Marginal PER1 f00 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_chrX_filter95.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
CHROM=chrX

TARGET=${CHROM}
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26606924

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=20G \
    --job-name='Marginal PER1 f00 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_chrX_filter95_log.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
CHROM=chrX

TARGET=${CHROM}
IS_INPUT20X=TRUE
IS_LOG=TRUE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26606640

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=20G \
    --job-name='Marginal chr1 f95 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_chr1_filter95.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
CHROM=chr1

TARGET=${CHROM}
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26606638

# %%
### set log file directory
sbatch -p ${NODE} \
    --mem=20G \
    --job-name='Marginal chr1 f95 logT' \
    -o ${FD_LOG}/linear_model_marginal_input20x_chr1_filter95_log.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

#CHROMS=($(seq 1 22) X Y)
#CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
CHROM=chr1

TARGET=${CHROM}
IS_INPUT20X=TRUE
IS_LOG=TRUE
FDIRY=marginal_filter95_log
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26606658

# %%
cat ${FD_LOG}/linear_model_marginal_input20x_chrX_filter95.txt
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect
#
# Slurm Array Index:
# Time Stamp:         10-18-21+01:44:24
#
#
# ++++++++++ Set environment  ++++++++++
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.1     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘pryr’
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, partial
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: iterators
# Loading required package: parallel
#
# ++++++++++ Set global variables ++++++++++
# Target:            chrX
# Is Input20x used?  TRUE
# Is Log transform?  FALSE
# Output Directory:  /home/mount/work/out/proj_combeffect/model_linear/marginal_filter95_input20x/chrX
# #Cores Resgister:  20
# Threshold (Cover): 10
# Threshold (Motif): 10.81
#
# ++++++++++ Import library size ++++++++++
#
# ++++++++++ Run motif analysis ++++++++++
# AHR Start
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/AHR_merge.bed.gz
# AHR Filter Input1_20x 2108932-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/AHR_merge.bed.gz
# AHR Filter Input2_20x 2009775-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/AHR_merge.bed.gz
# AHR Filter Input3_20x 2023879-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/AHR_merge.bed.gz
# AHR Filter Input4_20x 2345082-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/AHR_merge.bed.gz
# AHR Filter Input5_20x 2002150-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/AHR_merge.bed.gz
# AHR Filter TFX2_DMSO 330146-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/AHR_merge.bed.gz
# AHR Filter TFX3_DMSO 210784-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/AHR_merge.bed.gz
# AHR Filter TFX4_DMSO 247290-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/AHR_merge.bed.gz
# AHR Filter TFX5_DMSO 223959-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/AHR_merge.bed.gz
# AHR Filter TFX2_Dex 322673-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/AHR_merge.bed.gz
# AHR Filter TFX3_Dex 196106-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/AHR_merge.bed.gz
# AHR Filter TFX4_Dex 265103-0
# AHR Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/AHR_merge.bed.gz
# AHR Filter TFX5_Dex 324717-0
# AHR Skip Empty
# AIRE Start
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/AIRE_merge.bed.gz
# AIRE Filter Input1_20x 2487649-3573
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/AIRE_merge.bed.gz
# AIRE Filter Input2_20x 2373754-3374
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/AIRE_merge.bed.gz
# AIRE Filter Input3_20x 2376928-3348
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/AIRE_merge.bed.gz
# AIRE Filter Input4_20x 2806627-4001
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/AIRE_merge.bed.gz
# AIRE Filter Input5_20x 2373893-3358
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX2_DMSO 266422-337
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX3_DMSO 171960-202
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX4_DMSO 197630-225
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX5_DMSO 173256-217
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX2_Dex 255585-309
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX3_Dex 156172-207
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX4_Dex 205764-221
# AIRE Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/AIRE_merge.bed.gz
# AIRE Filter TFX5_Dex 251218-282
# AIRE Skip Empty
# AP1_1 Start
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter Input1_20x 10689700-268435
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter Input2_20x 10192425-256468
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter Input3_20x 10212323-256861
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter Input4_20x 12018315-301859
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter Input5_20x 10184182-255152
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX2_DMSO 1306303-46910
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX3_DMSO 841075-30124
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX4_DMSO 980604-35414
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX5_DMSO 869927-31658
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX2_Dex 1295392-46746
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX3_Dex 789015-28545
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX4_Dex 1058313-38652
# AP1_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/AP1_1_merge.bed.gz
# AP1_1 Filter TFX5_Dex 1287528-47533
# AP1_1 Skip Empty
# AP1_2 Start
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter Input1_20x 10583379-346644
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter Input2_20x 10085650-330294
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter Input3_20x 10125355-331992
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter Input4_20x 11826825-388442
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter Input5_20x 10041550-328726
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX2_DMSO 1455501-55714
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX3_DMSO 929653-36233
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX4_DMSO 1090981-44283
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX5_DMSO 979173-37873
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX2_Dex 1417558-52115
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX3_Dex 857289-31141
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX4_Dex 1153847-43332
# AP1_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/AP1_2_merge.bed.gz
# AP1_2 Filter TFX5_Dex 1406029-51701
# AP1_2 Skip Empty
# ARI5A Start
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/ARI5A_merge.bed.gz
# ARI5A Filter Input1_20x 1313118-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/ARI5A_merge.bed.gz
# ARI5A Filter Input2_20x 1253266-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/ARI5A_merge.bed.gz
# ARI5A Filter Input3_20x 1253555-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/ARI5A_merge.bed.gz
# ARI5A Filter Input4_20x 1490266-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/ARI5A_merge.bed.gz
# ARI5A Filter Input5_20x 1260551-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX2_DMSO 130183-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX3_DMSO 84820-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX4_DMSO 95315-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX5_DMSO 82243-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX2_Dex 126660-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX3_Dex 78261-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX4_Dex 102323-0
# ARI5A Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/ARI5A_merge.bed.gz
# ARI5A Filter TFX5_Dex 124523-0
# ARI5A Skip Empty
# ARI5B Start
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/ARI5B_merge.bed.gz
# ARI5B Filter Input1_20x 2154586-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/ARI5B_merge.bed.gz
# ARI5B Filter Input2_20x 2055751-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/ARI5B_merge.bed.gz
# ARI5B Filter Input3_20x 2055399-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/ARI5B_merge.bed.gz
# ARI5B Filter Input4_20x 2428537-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/ARI5B_merge.bed.gz
# ARI5B Filter Input5_20x 2055698-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX2_DMSO 238599-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX3_DMSO 155328-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX4_DMSO 177912-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX5_DMSO 159028-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX2_Dex 234218-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX3_Dex 142257-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX4_Dex 191584-0
# ARI5B Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/ARI5B_merge.bed.gz
# ARI5B Filter TFX5_Dex 232068-0
# ARI5B Skip Empty
# BATF Start
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/BATF_merge.bed.gz
# BATF Filter Input1_20x 4476585-55295
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/BATF_merge.bed.gz
# BATF Filter Input2_20x 4265798-52926
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/BATF_merge.bed.gz
# BATF Filter Input3_20x 4266509-53046
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/BATF_merge.bed.gz
# BATF Filter Input4_20x 5046055-62423
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/BATF_merge.bed.gz
# BATF Filter Input5_20x 4275188-53031
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/BATF_merge.bed.gz
# BATF Filter TFX2_DMSO 492177-7027
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/BATF_merge.bed.gz
# BATF Filter TFX3_DMSO 318448-4545
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/BATF_merge.bed.gz
# BATF Filter TFX4_DMSO 366193-5427
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/BATF_merge.bed.gz
# BATF Filter TFX5_DMSO 321633-4593
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/BATF_merge.bed.gz
# BATF Filter TFX2_Dex 487024-6358
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/BATF_merge.bed.gz
# BATF Filter TFX3_Dex 299907-3831
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/BATF_merge.bed.gz
# BATF Filter TFX4_Dex 392926-5297
# BATF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/BATF_merge.bed.gz
# BATF Filter TFX5_Dex 481301-6388
# BATF Skip Empty
# BCL6_1 Start
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter Input1_20x 505641-3276
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter Input2_20x 482756-3203
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter Input3_20x 482800-3072
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter Input4_20x 570903-3814
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter Input5_20x 482389-3182
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX2_DMSO 55719-270
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX3_DMSO 36322-171
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX4_DMSO 41895-227
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX5_DMSO 36800-234
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX2_Dex 54994-266
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX3_Dex 32623-175
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX4_Dex 43642-218
# BCL6_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/BCL6_1_merge.bed.gz
# BCL6_1 Filter TFX5_Dex 53037-277
# BCL6_1 Skip Empty
# BCL6_2 Start
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter Input1_20x 4286085-130045
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter Input2_20x 4090074-124199
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter Input3_20x 4094513-124122
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter Input4_20x 4815773-146173
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter Input5_20x 4084742-124211
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX2_DMSO 512810-15106
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX3_DMSO 332296-10157
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX4_DMSO 386015-11079
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX5_DMSO 340252-9661
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX2_Dex 514247-14627
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX3_Dex 315008-9009
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX4_Dex 419855-12795
# BCL6_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/BCL6_2_merge.bed.gz
# BCL6_2 Filter TFX5_Dex 511203-15060
# BCL6_2 Skip Empty
# CCAAT_CEBP Start
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter Input1_20x 6277121-20559
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter Input2_20x 5982338-19446
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter Input3_20x 5992234-19586
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter Input4_20x 7073208-23033
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter Input5_20x 5986731-19179
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX2_DMSO 702351-2462
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX3_DMSO 454085-1527
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX4_DMSO 520357-1636
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX5_DMSO 459537-1686
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX2_Dex 709764-2428
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX3_Dex 437166-1523
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX4_Dex 585339-2040
# CCAAT_CEBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CCAAT_CEBP_merge.bed.gz
# CCAAT_CEBP Filter TFX5_Dex 703708-2399
# CCAAT_CEBP Skip Empty
# CENBP Start
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CENBP_merge.bed.gz
# CENBP Filter Input1_20x 859547-12818
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CENBP_merge.bed.gz
# CENBP Filter Input2_20x 820047-12496
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CENBP_merge.bed.gz
# CENBP Filter Input3_20x 825371-12534
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CENBP_merge.bed.gz
# CENBP Filter Input4_20x 953908-14562
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CENBP_merge.bed.gz
# CENBP Filter Input5_20x 816078-12519
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX2_DMSO 151871-2654
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX3_DMSO 97594-1907
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX4_DMSO 115129-2451
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX5_DMSO 104373-1969
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX2_Dex 145566-2228
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX3_Dex 88193-1465
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX4_Dex 118342-1959
# CENBP Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CENBP_merge.bed.gz
# CENBP Filter TFX5_Dex 143803-2207
# CENBP Skip Empty
# CPEB1 Start
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter Input1_20x 4931473-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter Input2_20x 4704379-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter Input3_20x 4702073-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter Input4_20x 5588837-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter Input5_20x 4722523-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX2_DMSO 466910-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX3_DMSO 305715-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX4_DMSO 344614-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX5_DMSO 297413-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX2_Dex 443600-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX3_Dex 271886-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX4_Dex 356589-0
# CPEB1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CPEB1_merge.bed.gz
# CPEB1 Filter TFX5_Dex 431859-0
# CPEB1 Skip Empty
# CREB3_XBP1 Start
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter Input1_20x 4560877-75772
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter Input2_20x 4345803-72087
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter Input3_20x 4365622-72536
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter Input4_20x 5086666-84015
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter Input5_20x 4325076-71682
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX2_DMSO 646280-13201
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX3_DMSO 414252-8308
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX4_DMSO 485177-9974
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX5_DMSO 433941-8945
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX2_Dex 635678-13121
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX3_Dex 385510-8165
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX4_Dex 517849-11286
# CREB3_XBP1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CREB3_XBP1_merge.bed.gz
# CREB3_XBP1 Filter TFX5_Dex 635957-13890
# CREB3_XBP1 Skip Empty
# CREB_ATF_1 Start
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter Input1_20x 7526116-23768
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter Input2_20x 7172729-22781
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter Input3_20x 7190168-22964
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter Input4_20x 8440832-26904
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter Input5_20x 7156615-22961
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX2_DMSO 944829-5391
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX3_DMSO 607407-3566
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX4_DMSO 705302-4176
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX5_DMSO 627223-3729
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX2_Dex 953752-4869
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX3_Dex 582727-2976
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX4_Dex 778107-4217
# CREB_ATF_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CREB_ATF_1_merge.bed.gz
# CREB_ATF_1 Filter TFX5_Dex 955670-4726
# CREB_ATF_1 Skip Empty
# CREB_ATF_2 Start
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter Input1_20x 4142210-156978
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter Input2_20x 3950947-149389
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter Input3_20x 3956938-149625
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter Input4_20x 4657428-176947
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter Input5_20x 3947551-150113
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX2_DMSO 507796-21352
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX3_DMSO 328012-13866
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX4_DMSO 379225-15833
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX5_DMSO 337838-14112
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX2_Dex 515612-21088
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX3_Dex 316994-13157
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX4_Dex 424903-17842
# CREB_ATF_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CREB_ATF_2_merge.bed.gz
# CREB_ATF_2 Filter TFX5_Dex 521035-21316
# CREB_ATF_2 Skip Empty
# CREB_ATF_3 Start
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter Input1_20x 1548145-53043
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter Input2_20x 1474784-50723
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter Input3_20x 1477130-50577
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter Input4_20x 1740281-59496
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter Input5_20x 1473746-50639
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX2_DMSO 192988-6606
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX3_DMSO 124712-4538
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX4_DMSO 146376-4888
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX5_DMSO 129931-4590
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX2_Dex 197013-6402
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX3_Dex 122268-3977
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX4_Dex 164341-5302
# CREB_ATF_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CREB_ATF_3_merge.bed.gz
# CREB_ATF_3 Filter TFX5_Dex 198214-6351
# CREB_ATF_3 Skip Empty
# CTCF Start
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CTCF_merge.bed.gz
# CTCF Filter Input1_20x 18018377-442730
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CTCF_merge.bed.gz
# CTCF Filter Input2_20x 17157605-420308
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CTCF_merge.bed.gz
# CTCF Filter Input3_20x 17282254-425796
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CTCF_merge.bed.gz
# CTCF Filter Input4_20x 19945655-488300
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CTCF_merge.bed.gz
# CTCF Filter Input5_20x 17003742-415980
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX2_DMSO 2968257-77272
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX3_DMSO 1885728-49397
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX4_DMSO 2229494-57106
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX5_DMSO 2015875-52574
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX2_Dex 2950977-74515
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX3_Dex 1793888-44227
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX4_Dex 2443170-60764
# CTCF Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CTCF_merge.bed.gz
# CTCF Filter TFX5_Dex 2954719-73423
# CTCF Skip Empty
# CUX_1 Start
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter Input1_20x 3912804-97984
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter Input2_20x 3738439-93332
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter Input3_20x 3733717-92776
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter Input4_20x 4445917-111284
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter Input5_20x 3749131-94081
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX2_DMSO 370621-8974
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX3_DMSO 241856-5550
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX4_DMSO 273930-6435
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX5_DMSO 235861-5698
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX2_Dex 350166-8255
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX3_Dex 215600-4904
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX4_Dex 281612-6418
# CUX_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CUX_1_merge.bed.gz
# CUX_1 Filter TFX5_Dex 343324-8024
# CUX_1 Skip Empty
# CUX_2 Start
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter Input1_20x 2029067-40951
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter Input2_20x 1934906-39008
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter Input3_20x 1936185-39020
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter Input4_20x 2285244-46421
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter Input5_20x 1934900-38708
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX2_DMSO 269203-4521
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX3_DMSO 176371-3178
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX4_DMSO 201523-3324
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX5_DMSO 178940-3326
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX2_Dex 243422-4058
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX3_Dex 145466-2340
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX4_Dex 190844-3362
# CUX_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CUX_2_merge.bed.gz
# CUX_2 Filter TFX5_Dex 234423-4149
# CUX_2 Skip Empty
# CUX_3 Start
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter Input1_20x 560586-5255
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter Input2_20x 535250-5005
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter Input3_20x 535033-5002
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter Input4_20x 635569-6012
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter Input5_20x 535807-5040
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX2_DMSO 52813-603
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX3_DMSO 35030-460
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX4_DMSO 39342-344
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX5_DMSO 33682-302
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX2_Dex 49278-429
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX3_Dex 30754-232
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX4_Dex 39707-359
# CUX_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/CUX_3_merge.bed.gz
# CUX_3 Filter TFX5_Dex 49029-444
# CUX_3 Skip Empty
# DDIT3+CEBPA Start
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter Input1_20x 2971754-33769
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter Input2_20x 2830319-32421
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter Input3_20x 2838578-32389
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter Input4_20x 3341104-38791
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter Input5_20x 2827707-32110
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX2_DMSO 328335-3636
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX3_DMSO 209812-2502
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX4_DMSO 242452-2466
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX5_DMSO 213736-2359
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX2_Dex 318212-3463
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX3_Dex 190994-2135
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX4_Dex 251935-2870
# DDIT3+CEBPA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/DDIT3+CEBPA_merge.bed.gz
# DDIT3+CEBPA Filter TFX5_Dex 308542-3593
# DDIT3+CEBPA Skip Empty
# DMRT3 Start
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter Input1_20x 1466859-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter Input2_20x 1400964-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter Input3_20x 1397112-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter Input4_20x 1661738-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter Input5_20x 1404590-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX2_DMSO 139731-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX3_DMSO 90454-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX4_DMSO 104380-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX5_DMSO 89388-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX2_Dex 133734-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX3_Dex 83103-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX4_Dex 107457-0
# DMRT3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/DMRT3_merge.bed.gz
# DMRT3 Filter TFX5_Dex 131705-0
# DMRT3 Skip Empty
# E2F_1 Start
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter Input1_20x 6080618-43711
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter Input2_20x 5796714-41292
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter Input3_20x 5806971-41416
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter Input4_20x 6832058-48901
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter Input5_20x 5787317-41610
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX2_DMSO 728691-5451
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX3_DMSO 471265-3339
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX4_DMSO 543341-4076
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX5_DMSO 479379-3252
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX2_Dex 698334-4897
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX3_Dex 423059-2891
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX4_Dex 566000-3855
# E2F_1 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/E2F_1_merge.bed.gz
# E2F_1 Filter TFX5_Dex 687349-4811
# E2F_1 Skip Empty
# E2F_2 Start
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter Input1_20x 22723103-562505
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter Input2_20x 21638649-534236
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter Input3_20x 21775188-540932
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter Input4_20x 25281903-620680
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter Input5_20x 21515787-530277
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX2_DMSO 3327034-97504
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX3_DMSO 2089328-59897
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX4_DMSO 2457246-71469
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX5_DMSO 2193142-63041
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX2_Dex 3265437-91264
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX3_Dex 1962833-54660
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX4_Dex 2654865-73830
# E2F_2 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/E2F_2_merge.bed.gz
# E2F_2 Filter TFX5_Dex 3217947-88067
# E2F_2 Skip Empty
# E2F_3 Start
# E2F_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/E2F_3_merge.bed.gz
# E2F_3 Filter Input1_20x 3353676-15928
# E2F_3 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/E2F_3_merge.bed.gz
# E2F_3 Filter Input2_20x 3199954-15403
# ...
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter Input2_20x 21588621-362979
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter Input3_20x 21591186-361972
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter Input4_20x 25575831-428411
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter Input5_20x 21617785-360088
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX2_DMSO 2458545-61035
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX3_DMSO 1594157-40893
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX4_DMSO 1827146-47522
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX5_DMSO 1602484-43667
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX2_Dex 2409248-64966
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX3_Dex 1482677-42044
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX4_Dex 1959077-56371
# FOX_4 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_4_merge.bed.gz
# FOX_4 Filter TFX5_Dex 2381836-67754
# FOX_4 Skip Empty
# FOX_5 Start
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter Input1_20x 22325840-328317
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter Input2_20x 21305955-313705
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter Input3_20x 21299799-312533
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter Input4_20x 25285927-370273
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter Input5_20x 21364903-313576
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX2_DMSO 2323107-35872
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX3_DMSO 1508377-23361
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX4_DMSO 1718207-25892
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX5_DMSO 1501057-23061
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX2_Dex 2246869-33649
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX3_Dex 1385449-20565
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX4_Dex 1820252-26446
# FOX_5 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_5_merge.bed.gz
# FOX_5 Filter TFX5_Dex 2211195-32590
# FOX_5 Skip Empty
# FOX_6 Start
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter Input1_20x 3803182-55239
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter Input2_20x 3632868-52549
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter Input3_20x 3626311-52957
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter Input4_20x 4319021-63161
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter Input5_20x 3648625-53281
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX2_DMSO 357203-4892
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX3_DMSO 232406-3294
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX4_DMSO 261410-4012
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX5_DMSO 223814-3031
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX2_Dex 339245-4717
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX3_Dex 210370-3278
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX4_Dex 274087-4195
# FOX_6 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_6_merge.bed.gz
# FOX_6 Filter TFX5_Dex 331735-4647
# FOX_6 Skip Empty
# FOX_7 Start
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter Input1_20x 11580494-347122
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter Input2_20x 11036930-330833
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter Input3_20x 11076573-332979
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter Input4_20x 12939318-387901
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter Input5_20x 10989763-328857
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX2_DMSO 1554791-44811
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX3_DMSO 994502-28267
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX4_DMSO 1156257-33249
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX5_DMSO 1033178-29128
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX2_Dex 1531671-47297
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX3_Dex 927452-28916
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX4_Dex 1250642-39122
# FOX_7 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_7_merge.bed.gz
# FOX_7 Filter TFX5_Dex 1524629-47413
# FOX_7 Skip Empty
# FOX_8 Start
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter Input1_20x 2223837-31443
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter Input2_20x 2119059-30042
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter Input3_20x 2123236-29852
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter Input4_20x 2502763-35353
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter Input5_20x 2118905-30192
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX2_DMSO 253831-4347
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX3_DMSO 164292-3034
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX4_DMSO 190205-3491
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX5_DMSO 168120-3029
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX2_Dex 262845-4798
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX3_Dex 160749-3209
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX4_Dex 217809-3861
# FOX_8 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_8_merge.bed.gz
# FOX_8 Filter TFX5_Dex 264355-5098
# FOX_8 Skip Empty
# FOX_9 Start
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter Input1_20x 2319988-55969
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter Input2_20x 2211075-53064
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter Input3_20x 2217700-53359
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter Input4_20x 2607939-61871
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter Input5_20x 2211207-52684
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX2_DMSO 281195-7850
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX3_DMSO 182062-5098
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX4_DMSO 211365-5817
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX5_DMSO 185125-4984
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX2_Dex 275801-6876
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX3_Dex 168419-4234
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX4_Dex 224892-6090
# FOX_9 Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/FOX_9_merge.bed.gz
# FOX_9 Filter TFX5_Dex 274711-6873
# FOX_9 Skip Empty
# GATA Start
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/GATA_merge.bed.gz
# GATA Filter Input1_20x 7180723-260736
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/GATA_merge.bed.gz
# GATA Filter Input2_20x 6845947-248994
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/GATA_merge.bed.gz
# GATA Filter Input3_20x 6856662-249684
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/GATA_merge.bed.gz
# GATA Filter Input4_20x 8103721-293266
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/GATA_merge.bed.gz
# GATA Filter Input5_20x 6861220-249174
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/GATA_merge.bed.gz
# GATA Filter TFX2_DMSO 775258-31401
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/GATA_merge.bed.gz
# GATA Filter TFX3_DMSO 499261-19721
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/GATA_merge.bed.gz
# GATA Filter TFX4_DMSO 577750-23358
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/GATA_merge.bed.gz
# GATA Filter TFX5_DMSO 499577-20659
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/GATA_merge.bed.gz
# GATA Filter TFX2_Dex 756135-30533
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/GATA_merge.bed.gz
# GATA Filter TFX3_Dex 460956-18317
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/GATA_merge.bed.gz
# GATA Filter TFX4_Dex 608945-24335
# GATA Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/GATA_merge.bed.gz
# GATA Filter TFX5_Dex 743525-29833
# GATA Skip Empty
# GCM Start
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/GCM_merge.bed.gz
# GCM Filter Input1_20x 8517200-74135
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/GCM_merge.bed.gz
# GCM Filter Input2_20x 8115983-70055
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/GCM_merge.bed.gz
# GCM Filter Input3_20x 8150588-71261
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input4_20x/chrX/GCM_merge.bed.gz
# GCM Filter Input4_20x 9506698-81560
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input5_20x/chrX/GCM_merge.bed.gz
# GCM Filter Input5_20x 8070574-69168
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_DMSO/chrX/GCM_merge.bed.gz
# GCM Filter TFX2_DMSO 1166935-10151
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_DMSO/chrX/GCM_merge.bed.gz
# GCM Filter TFX3_DMSO 748661-6525
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_DMSO/chrX/GCM_merge.bed.gz
# GCM Filter TFX4_DMSO 872860-7539
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_DMSO/chrX/GCM_merge.bed.gz
# GCM Filter TFX5_DMSO 786037-6834
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX2_Dex/chrX/GCM_merge.bed.gz
# GCM Filter TFX2_Dex 1135662-9577
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX3_Dex/chrX/GCM_merge.bed.gz
# GCM Filter TFX3_Dex 689869-5997
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX4_Dex/chrX/GCM_merge.bed.gz
# GCM Filter TFX4_Dex 926789-7655
# GCM Import /home/mount/work/out/proj_combeffect/annotation_fragment/TFX5_Dex/chrX/GCM_merge.bed.gz
# GCM Filter TFX5_Dex 1132089-10019
# GCM Skip Empty
# GC-tract Start
# GC-tract Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input1_20x/chrX/GC-tract_merge.bed.gz
# GC-tract Filter Input1_20x 62465600-2645368
# GC-tract Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input2_20x/chrX/GC-tract_merge.bed.gz
# GC-tract Filter Input2_20x 59509733-2520954
# GC-tract Import /home/mount/work/out/proj_combeffect/annotation_fragment/Input3_20x/chrX/GC-tract_merge.bed.gz
# /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks/sing_proj_combeffect.sh: line 21: 56729 Killed                  singularity exec -H ${PWD}:/home -B ${FD_WORK}:/home/mount/work -B ${FD_PRJ}:/home/mount/project -B ${FD_RLAB}:/home/mount/reddylab ${FD_SING}/singularity_proj_combeffect.sif "$@"
# slurmstepd: error: Detected 1 oom-kill event(s) in StepId=26606645.0 cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.
# srun: error: x2-05-3: task 0: Out Of Memory
#
# Done!
# Run Time: 1 hours 4 minutes and 22 seconds
# slurmstepd: error: Detected 1 oom-kill event(s) in StepId=26606645.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.

# %% [markdown]
# ## RUN

# %%
### set log file directory
sbatch -p ${NODE} \
    --array=0-23 \
    --mem=16G \
    --tasks-per-node=1 \
    --cpus-per-task=21 \
    --job-name='Marginal PER1 f00 logF' \
    -o ${FD_LOG}/linear_model_marginal_input20x_chrom_filter95.%a.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh -v

###
CHROMS=($(seq 1 22) X Y)
CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}

###
TARGET=${CHROM}
IS_INPUT20X=TRUE
IS_LOG=FALSE
FDIRY=marginal_filter95
NCORE=20
THRESHOLD_COVER=10
THRESHOLD_MOTIF=10.81

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

### run the model
srun ${FD_PRJ}/sing_proj_combeffect.sh Rscript motif_marginal.R \
    ${TARGET} ${IS_INPUT20X} ${IS_LOG} ${FDIRY} ${NCORE} ${THRESHOLD_COVER} ${THRESHOLD_MOTIF}
echo

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 26604348
