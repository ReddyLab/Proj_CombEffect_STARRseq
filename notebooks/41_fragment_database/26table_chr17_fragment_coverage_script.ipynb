# %%
source ../config_duke.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Proj_CombEffect_STARRseq/notebooks
# PATH OF RESULTS:    /gpfs/fs1/data/reddylab/Kuei/out/proj_combeffect

# %%
source ../config_duke.sh

sbatch -p ${NODE} \
    --mem 8G \
    -o ${FD_LOG}/db_table_fragment_coverage_chr17.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh

### print start message
timer_start=`date +%s`
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}
echo "Time Stamp:        " $(date +"%m-%d-%y+%T")
echo

###
${FD_PRJ}/sing_proj_combeffect.sh python table_fragment_coverage.py chr17

### print end message
timer=`date +%s`
runtime=$(echo "${timer} - ${timer_start}" | bc -l)
echo
echo 'Done!'
echo "Run Time: $(displaytime ${runtime})"

EOF
# Out:
# Submitted batch job 27562216

# %%
scancel 27559855

# %%
cat ${FD_LOG}/db_table_fragment_coverage_chr17.txt
# Out:
# Slurm Array Index:
# Time Stamp:         03-04-22+11:55:01
#
# You are on Duke Server: Singularity: Proj CombEffect
# BASE DIRECTORY:     /mount/work
# PATH OF SOURCE:     /mount/work/source
# PATH OF EXECUTABLE: /mount/work/exe
# PATH OF ANNOTATION: /mount/work/annotation
# PATH OF PROJECT:    /mount/project
# PATH OF RESULTS:    /mount/work/out/proj_combeffect
#
# Global variables:
# Chromsome:       chr17
# Database:        /mount/work/out/proj_combeffect/database/fragment_chr17.db
# Table file name: chr17_perbase.tsv.gz
#
# /mount/work/out/proj_combeffect/coverage/Input1/chr17_perbase.tsv.gz
# Sample:  Input1
# [['chr17', '1', '0', 'Input1'], ['chr17', '2', '0', 'Input1'], ['chr17', '3', '0', 'Input1']]
# [['chr17', '4', '0', 'Input1'], ['chr17', '5', '0', 'Input1'], ['chr17', '6', '0', 'Input1']]
# [['chr17', '7', '0', 'Input1'], ['chr17', '8', '0', 'Input1'], ['chr17', '9', '0', 'Input1']]
# [['chr17', '10', '0', 'Input1']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input2/chr17_perbase.tsv.gz
# Sample:  Input2
# [['chr17', '1', '0', 'Input2'], ['chr17', '2', '0', 'Input2'], ['chr17', '3', '0', 'Input2']]
# [['chr17', '4', '0', 'Input2'], ['chr17', '5', '0', 'Input2'], ['chr17', '6', '0', 'Input2']]
# [['chr17', '7', '0', 'Input2'], ['chr17', '8', '0', 'Input2'], ['chr17', '9', '0', 'Input2']]
# [['chr17', '10', '0', 'Input2']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input3/chr17_perbase.tsv.gz
# Sample:  Input3
# [['chr17', '1', '0', 'Input3'], ['chr17', '2', '0', 'Input3'], ['chr17', '3', '0', 'Input3']]
# [['chr17', '4', '0', 'Input3'], ['chr17', '5', '0', 'Input3'], ['chr17', '6', '0', 'Input3']]
# [['chr17', '7', '0', 'Input3'], ['chr17', '8', '0', 'Input3'], ['chr17', '9', '0', 'Input3']]
# [['chr17', '10', '0', 'Input3']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input4/chr17_perbase.tsv.gz
# Sample:  Input4
# [['chr17', '1', '0', 'Input4'], ['chr17', '2', '0', 'Input4'], ['chr17', '3', '0', 'Input4']]
# [['chr17', '4', '0', 'Input4'], ['chr17', '5', '0', 'Input4'], ['chr17', '6', '0', 'Input4']]
# [['chr17', '7', '0', 'Input4'], ['chr17', '8', '0', 'Input4'], ['chr17', '9', '0', 'Input4']]
# [['chr17', '10', '0', 'Input4']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input5/chr17_perbase.tsv.gz
# Sample:  Input5
# [['chr17', '1', '0', 'Input5'], ['chr17', '2', '0', 'Input5'], ['chr17', '3', '0', 'Input5']]
# [['chr17', '4', '0', 'Input5'], ['chr17', '5', '0', 'Input5'], ['chr17', '6', '0', 'Input5']]
# [['chr17', '7', '0', 'Input5'], ['chr17', '8', '0', 'Input5'], ['chr17', '9', '0', 'Input5']]
# [['chr17', '10', '0', 'Input5']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input1_20x/chr17_perbase.tsv.gz
# Sample:  Input1_20x
# [['chr17', '1', '0', 'Input1_20x'], ['chr17', '2', '0', 'Input1_20x'], ['chr17', '3', '0', 'Input1_20x']]
# [['chr17', '4', '0', 'Input1_20x'], ['chr17', '5', '0', 'Input1_20x'], ['chr17', '6', '0', 'Input1_20x']]
# [['chr17', '7', '0', 'Input1_20x'], ['chr17', '8', '0', 'Input1_20x'], ['chr17', '9', '0', 'Input1_20x']]
# [['chr17', '10', '0', 'Input1_20x']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input2_20x/chr17_perbase.tsv.gz
# Sample:  Input2_20x
# [['chr17', '1', '0', 'Input2_20x'], ['chr17', '2', '0', 'Input2_20x'], ['chr17', '3', '0', 'Input2_20x']]
# [['chr17', '4', '0', 'Input2_20x'], ['chr17', '5', '0', 'Input2_20x'], ['chr17', '6', '0', 'Input2_20x']]
# [['chr17', '7', '0', 'Input2_20x'], ['chr17', '8', '0', 'Input2_20x'], ['chr17', '9', '0', 'Input2_20x']]
# [['chr17', '10', '0', 'Input2_20x']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input3_20x/chr17_perbase.tsv.gz
# Sample:  Input3_20x
# [['chr17', '1', '0', 'Input3_20x'], ['chr17', '2', '0', 'Input3_20x'], ['chr17', '3', '0', 'Input3_20x']]
# [['chr17', '4', '0', 'Input3_20x'], ['chr17', '5', '0', 'Input3_20x'], ['chr17', '6', '0', 'Input3_20x']]
# [['chr17', '7', '0', 'Input3_20x'], ['chr17', '8', '0', 'Input3_20x'], ['chr17', '9', '0', 'Input3_20x']]
# [['chr17', '10', '0', 'Input3_20x']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input4_20x/chr17_perbase.tsv.gz
# Sample:  Input4_20x
# [['chr17', '1', '0', 'Input4_20x'], ['chr17', '2', '0', 'Input4_20x'], ['chr17', '3', '0', 'Input4_20x']]
# [['chr17', '4', '0', 'Input4_20x'], ['chr17', '5', '0', 'Input4_20x'], ['chr17', '6', '0', 'Input4_20x']]
# [['chr17', '7', '0', 'Input4_20x'], ['chr17', '8', '0', 'Input4_20x'], ['chr17', '9', '0', 'Input4_20x']]
# [['chr17', '10', '0', 'Input4_20x']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/Input5_20x/chr17_perbase.tsv.gz
# Sample:  Input5_20x
# [['chr17', '1', '0', 'Input5_20x'], ['chr17', '2', '0', 'Input5_20x'], ['chr17', '3', '0', 'Input5_20x']]
# [['chr17', '4', '0', 'Input5_20x'], ['chr17', '5', '0', 'Input5_20x'], ['chr17', '6', '0', 'Input5_20x']]
# [['chr17', '7', '0', 'Input5_20x'], ['chr17', '8', '0', 'Input5_20x'], ['chr17', '9', '0', 'Input5_20x']]
# [['chr17', '10', '0', 'Input5_20x']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX2_DMSO/chr17_perbase.tsv.gz
# Sample:  TFX2_DMSO
# [['chr17', '1', '0', 'TFX2_DMSO'], ['chr17', '2', '0', 'TFX2_DMSO'], ['chr17', '3', '0', 'TFX2_DMSO']]
# [['chr17', '4', '0', 'TFX2_DMSO'], ['chr17', '5', '0', 'TFX2_DMSO'], ['chr17', '6', '0', 'TFX2_DMSO']]
# [['chr17', '7', '0', 'TFX2_DMSO'], ['chr17', '8', '0', 'TFX2_DMSO'], ['chr17', '9', '0', 'TFX2_DMSO']]
# [['chr17', '10', '0', 'TFX2_DMSO']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX3_DMSO/chr17_perbase.tsv.gz
# Sample:  TFX3_DMSO
# [['chr17', '1', '0', 'TFX3_DMSO'], ['chr17', '2', '0', 'TFX3_DMSO'], ['chr17', '3', '0', 'TFX3_DMSO']]
# [['chr17', '4', '0', 'TFX3_DMSO'], ['chr17', '5', '0', 'TFX3_DMSO'], ['chr17', '6', '0', 'TFX3_DMSO']]
# [['chr17', '7', '0', 'TFX3_DMSO'], ['chr17', '8', '0', 'TFX3_DMSO'], ['chr17', '9', '0', 'TFX3_DMSO']]
# [['chr17', '10', '0', 'TFX3_DMSO']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX4_DMSO/chr17_perbase.tsv.gz
# Sample:  TFX4_DMSO
# [['chr17', '1', '0', 'TFX4_DMSO'], ['chr17', '2', '0', 'TFX4_DMSO'], ['chr17', '3', '0', 'TFX4_DMSO']]
# [['chr17', '4', '0', 'TFX4_DMSO'], ['chr17', '5', '0', 'TFX4_DMSO'], ['chr17', '6', '0', 'TFX4_DMSO']]
# [['chr17', '7', '0', 'TFX4_DMSO'], ['chr17', '8', '0', 'TFX4_DMSO'], ['chr17', '9', '0', 'TFX4_DMSO']]
# [['chr17', '10', '0', 'TFX4_DMSO']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX5_DMSO/chr17_perbase.tsv.gz
# Sample:  TFX5_DMSO
# [['chr17', '1', '0', 'TFX5_DMSO'], ['chr17', '2', '0', 'TFX5_DMSO'], ['chr17', '3', '0', 'TFX5_DMSO']]
# [['chr17', '4', '0', 'TFX5_DMSO'], ['chr17', '5', '0', 'TFX5_DMSO'], ['chr17', '6', '0', 'TFX5_DMSO']]
# [['chr17', '7', '0', 'TFX5_DMSO'], ['chr17', '8', '0', 'TFX5_DMSO'], ['chr17', '9', '0', 'TFX5_DMSO']]
# [['chr17', '10', '0', 'TFX5_DMSO']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX2_Dex/chr17_perbase.tsv.gz
# Sample:  TFX2_Dex
# [['chr17', '1', '0', 'TFX2_Dex'], ['chr17', '2', '0', 'TFX2_Dex'], ['chr17', '3', '0', 'TFX2_Dex']]
# [['chr17', '4', '0', 'TFX2_Dex'], ['chr17', '5', '0', 'TFX2_Dex'], ['chr17', '6', '0', 'TFX2_Dex']]
# [['chr17', '7', '0', 'TFX2_Dex'], ['chr17', '8', '0', 'TFX2_Dex'], ['chr17', '9', '0', 'TFX2_Dex']]
# [['chr17', '10', '0', 'TFX2_Dex']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX3_Dex/chr17_perbase.tsv.gz
# Sample:  TFX3_Dex
# [['chr17', '1', '0', 'TFX3_Dex'], ['chr17', '2', '0', 'TFX3_Dex'], ['chr17', '3', '0', 'TFX3_Dex']]
# [['chr17', '4', '0', 'TFX3_Dex'], ['chr17', '5', '0', 'TFX3_Dex'], ['chr17', '6', '0', 'TFX3_Dex']]
# [['chr17', '7', '0', 'TFX3_Dex'], ['chr17', '8', '0', 'TFX3_Dex'], ['chr17', '9', '0', 'TFX3_Dex']]
# [['chr17', '10', '0', 'TFX3_Dex']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX4_Dex/chr17_perbase.tsv.gz
# Sample:  TFX4_Dex
# [['chr17', '1', '0', 'TFX4_Dex'], ['chr17', '2', '0', 'TFX4_Dex'], ['chr17', '3', '0', 'TFX4_Dex']]
# [['chr17', '4', '0', 'TFX4_Dex'], ['chr17', '5', '0', 'TFX4_Dex'], ['chr17', '6', '0', 'TFX4_Dex']]
# [['chr17', '7', '0', 'TFX4_Dex'], ['chr17', '8', '0', 'TFX4_Dex'], ['chr17', '9', '0', 'TFX4_Dex']]
# [['chr17', '10', '0', 'TFX4_Dex']]
# #Rows: 10
# /mount/work/out/proj_combeffect/coverage/TFX5_Dex/chr17_perbase.tsv.gz
# Sample:  TFX5_Dex
# [['chr17', '1', '0', 'TFX5_Dex'], ['chr17', '2', '0', 'TFX5_Dex'], ['chr17', '3', '0', 'TFX5_Dex']]
# [['chr17', '4', '0', 'TFX5_Dex'], ['chr17', '5', '0', 'TFX5_Dex'], ['chr17', '6', '0', 'TFX5_Dex']]
# [['chr17', '7', '0', 'TFX5_Dex'], ['chr17', '8', '0', 'TFX5_Dex'], ['chr17', '9', '0', 'TFX5_Dex']]
# [['chr17', '10', '0', 'TFX5_Dex']]
# #Rows: 10
#
# #Rows Total: 180
# #Rows Table: [(180,)]
# ('chr17', 1, 0, 'Input1')
# ('chr17', 2, 0, 'Input1')
# ('chr17', 3, 0, 'Input1')
# ('chr17', 4, 0, 'Input1')
# ('chr17', 5, 0, 'Input1')
# ('chr17', 6, 0, 'Input1')
# ('chr17', 7, 0, 'Input1')
# ('chr17', 8, 0, 'Input1')
# ('chr17', 9, 0, 'Input1')
# ('chr17', 10, 0, 'Input1')
# ('chr17', 1, 0, 'Input2')
# ('chr17', 2, 0, 'Input2')
# ('chr17', 3, 0, 'Input2')
# ('chr17', 4, 0, 'Input2')
# ('chr17', 5, 0, 'Input2')
# ('chr17', 6, 0, 'Input2')
# ('chr17', 7, 0, 'Input2')
# ('chr17', 8, 0, 'Input2')
# ('chr17', 9, 0, 'Input2')
# ('chr17', 10, 0, 'Input2')
# ('chr17', 1, 0, 'Input3')
# ('chr17', 2, 0, 'Input3')
# ('chr17', 3, 0, 'Input3')
# ('chr17', 4, 0, 'Input3')
# ('chr17', 5, 0, 'Input3')
# ('chr17', 6, 0, 'Input3')
# ('chr17', 7, 0, 'Input3')
# ('chr17', 8, 0, 'Input3')
# ('chr17', 9, 0, 'Input3')
# ('chr17', 10, 0, 'Input3')
# ('chr17', 1, 0, 'Input4')
# ('chr17', 2, 0, 'Input4')
# ('chr17', 3, 0, 'Input4')
# ('chr17', 4, 0, 'Input4')
# ('chr17', 5, 0, 'Input4')
# ('chr17', 6, 0, 'Input4')
# ('chr17', 7, 0, 'Input4')
# ('chr17', 8, 0, 'Input4')
# ('chr17', 9, 0, 'Input4')
# ('chr17', 10, 0, 'Input4')
# ('chr17', 1, 0, 'Input5')
# ('chr17', 2, 0, 'Input5')
# ('chr17', 3, 0, 'Input5')
# ('chr17', 4, 0, 'Input5')
# ('chr17', 5, 0, 'Input5')
# ('chr17', 6, 0, 'Input5')
# ('chr17', 7, 0, 'Input5')
# ('chr17', 8, 0, 'Input5')
# ('chr17', 9, 0, 'Input5')
# ('chr17', 10, 0, 'Input5')
# ('chr17', 1, 0, 'Input1_20x')
# ('chr17', 2, 0, 'Input1_20x')
# ('chr17', 3, 0, 'Input1_20x')
# ('chr17', 4, 0, 'Input1_20x')
# ('chr17', 5, 0, 'Input1_20x')
# ('chr17', 6, 0, 'Input1_20x')
# ('chr17', 7, 0, 'Input1_20x')
# ('chr17', 8, 0, 'Input1_20x')
# ('chr17', 9, 0, 'Input1_20x')
# ('chr17', 10, 0, 'Input1_20x')
# ('chr17', 1, 0, 'Input2_20x')
# ('chr17', 2, 0, 'Input2_20x')
# ('chr17', 3, 0, 'Input2_20x')
# ('chr17', 4, 0, 'Input2_20x')
# ('chr17', 5, 0, 'Input2_20x')
# ('chr17', 6, 0, 'Input2_20x')
# ('chr17', 7, 0, 'Input2_20x')
# ('chr17', 8, 0, 'Input2_20x')
# ('chr17', 9, 0, 'Input2_20x')
# ('chr17', 10, 0, 'Input2_20x')
# ('chr17', 1, 0, 'Input3_20x')
# ('chr17', 2, 0, 'Input3_20x')
# ('chr17', 3, 0, 'Input3_20x')
# ('chr17', 4, 0, 'Input3_20x')
# ('chr17', 5, 0, 'Input3_20x')
# ('chr17', 6, 0, 'Input3_20x')
# ('chr17', 7, 0, 'Input3_20x')
# ('chr17', 8, 0, 'Input3_20x')
# ('chr17', 9, 0, 'Input3_20x')
# ('chr17', 10, 0, 'Input3_20x')
# ('chr17', 1, 0, 'Input4_20x')
# ('chr17', 2, 0, 'Input4_20x')
# ('chr17', 3, 0, 'Input4_20x')
# ('chr17', 4, 0, 'Input4_20x')
# ('chr17', 5, 0, 'Input4_20x')
# ('chr17', 6, 0, 'Input4_20x')
# ('chr17', 7, 0, 'Input4_20x')
# ('chr17', 8, 0, 'Input4_20x')
# ('chr17', 9, 0, 'Input4_20x')
# ('chr17', 10, 0, 'Input4_20x')
# ('chr17', 1, 0, 'Input5_20x')
# ('chr17', 2, 0, 'Input5_20x')
# ('chr17', 3, 0, 'Input5_20x')
# ('chr17', 4, 0, 'Input5_20x')
# ('chr17', 5, 0, 'Input5_20x')
# ('chr17', 6, 0, 'Input5_20x')
# ('chr17', 7, 0, 'Input5_20x')
# ('chr17', 8, 0, 'Input5_20x')
# ('chr17', 9, 0, 'Input5_20x')
# ('chr17', 10, 0, 'Input5_20x')
# ('chr17', 1, 0, 'TFX2_DMSO')
# ('chr17', 2, 0, 'TFX2_DMSO')
# ('chr17', 3, 0, 'TFX2_DMSO')
# ('chr17', 4, 0, 'TFX2_DMSO')
# ('chr17', 5, 0, 'TFX2_DMSO')
# ('chr17', 6, 0, 'TFX2_DMSO')
# ('chr17', 7, 0, 'TFX2_DMSO')
# ('chr17', 8, 0, 'TFX2_DMSO')
# ('chr17', 9, 0, 'TFX2_DMSO')
# ('chr17', 10, 0, 'TFX2_DMSO')
# ('chr17', 1, 0, 'TFX3_DMSO')
# ('chr17', 2, 0, 'TFX3_DMSO')
# ('chr17', 3, 0, 'TFX3_DMSO')
# ('chr17', 4, 0, 'TFX3_DMSO')
# ('chr17', 5, 0, 'TFX3_DMSO')
# ('chr17', 6, 0, 'TFX3_DMSO')
# ('chr17', 7, 0, 'TFX3_DMSO')
# ('chr17', 8, 0, 'TFX3_DMSO')
# ('chr17', 9, 0, 'TFX3_DMSO')
# ('chr17', 10, 0, 'TFX3_DMSO')
# ('chr17', 1, 0, 'TFX4_DMSO')
# ('chr17', 2, 0, 'TFX4_DMSO')
# ('chr17', 3, 0, 'TFX4_DMSO')
# ('chr17', 4, 0, 'TFX4_DMSO')
# ('chr17', 5, 0, 'TFX4_DMSO')
# ('chr17', 6, 0, 'TFX4_DMSO')
# ('chr17', 7, 0, 'TFX4_DMSO')
# ('chr17', 8, 0, 'TFX4_DMSO')
# ('chr17', 9, 0, 'TFX4_DMSO')
# ('chr17', 10, 0, 'TFX4_DMSO')
# ('chr17', 1, 0, 'TFX5_DMSO')
# ('chr17', 2, 0, 'TFX5_DMSO')
# ('chr17', 3, 0, 'TFX5_DMSO')
# ('chr17', 4, 0, 'TFX5_DMSO')
# ('chr17', 5, 0, 'TFX5_DMSO')
# ('chr17', 6, 0, 'TFX5_DMSO')
# ('chr17', 7, 0, 'TFX5_DMSO')
# ('chr17', 8, 0, 'TFX5_DMSO')
# ('chr17', 9, 0, 'TFX5_DMSO')
# ('chr17', 10, 0, 'TFX5_DMSO')
# ('chr17', 1, 0, 'TFX2_Dex')
# ('chr17', 2, 0, 'TFX2_Dex')
# ('chr17', 3, 0, 'TFX2_Dex')
# ('chr17', 4, 0, 'TFX2_Dex')
# ('chr17', 5, 0, 'TFX2_Dex')
# ('chr17', 6, 0, 'TFX2_Dex')
# ('chr17', 7, 0, 'TFX2_Dex')
# ('chr17', 8, 0, 'TFX2_Dex')
# ('chr17', 9, 0, 'TFX2_Dex')
# ('chr17', 10, 0, 'TFX2_Dex')
# ('chr17', 1, 0, 'TFX3_Dex')
# ('chr17', 2, 0, 'TFX3_Dex')
# ('chr17', 3, 0, 'TFX3_Dex')
# ('chr17', 4, 0, 'TFX3_Dex')
# ('chr17', 5, 0, 'TFX3_Dex')
# ('chr17', 6, 0, 'TFX3_Dex')
# ('chr17', 7, 0, 'TFX3_Dex')
# ('chr17', 8, 0, 'TFX3_Dex')
# ('chr17', 9, 0, 'TFX3_Dex')
# ('chr17', 10, 0, 'TFX3_Dex')
# ('chr17', 1, 0, 'TFX4_Dex')
# ('chr17', 2, 0, 'TFX4_Dex')
# ('chr17', 3, 0, 'TFX4_Dex')
# ('chr17', 4, 0, 'TFX4_Dex')
# ('chr17', 5, 0, 'TFX4_Dex')
# ('chr17', 6, 0, 'TFX4_Dex')
# ('chr17', 7, 0, 'TFX4_Dex')
# ('chr17', 8, 0, 'TFX4_Dex')
# ('chr17', 9, 0, 'TFX4_Dex')
# ('chr17', 10, 0, 'TFX4_Dex')
# ('chr17', 1, 0, 'TFX5_Dex')
# ('chr17', 2, 0, 'TFX5_Dex')
# ('chr17', 3, 0, 'TFX5_Dex')
# ('chr17', 4, 0, 'TFX5_Dex')
# ('chr17', 5, 0, 'TFX5_Dex')
# ('chr17', 6, 0, 'TFX5_Dex')
# ('chr17', 7, 0, 'TFX5_Dex')
# ('chr17', 8, 0, 'TFX5_Dex')
# ('chr17', 9, 0, 'TFX5_Dex')
# ('chr17', 10, 0, 'TFX5_Dex')
#
# Done!
# Run Time: 3 seconds
