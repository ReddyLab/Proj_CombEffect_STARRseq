# %% [markdown]
# # Coverage of fragments in STARR-seq results
# - depth in bedgraph format
# - depth per base

# %% [markdown]
# **Set environment**

# %%
source ../config_duke.sh
# Out:
# You are on Duke Server: DCC
# BASE DIRECTORY:     /work/kk319
# WORK DIRECTORY:     /work/kk319/out/CombEffect_STARR
# LOG  DIRECTORY:     /work/kk319/out/CombEffect_STARR/log
# PATH OF SOURCE:     /work/kk319/source
# PATH OF EXECUTABLE: /work/kk319/exe
# PATH OF ANNOTATION: /work/kk319/annotation

# %% [markdown]
# ## Get coverage of all chromosomes

# %% [markdown]
# **RUN**

# %%
source ../config_duke.sh
source ../load_module_bedtools.sh

sbatch -p scavenger \
    --array 0-23 \
    --mem 8G \
    -o ${FD_LOG}/coverage_perbase_chrom.%a.txt \
    <<'EOF'
#!/bin/bash
### set directories & global variables
source ../config_duke.sh
CHROMS=($(seq 1 22) X Y)
CHROM=chr${CHROMS[${SLURM_ARRAY_TASK_ID}]}
TARGET=${CHROM}

### set input and output
FD_BEDS=($(ls -d ${FD_WRK}/data/*/))
FN_BED=${CHROM}.bed

FD_GEN=${FD_ANN}/genome/hg38
FN_GEN=hg38.chrom.sizes.${CHROM}

### print start message
echo "Slurm Array Index: " ${SLURM_ARRAY_TASK_ID}

### loop through each sample and count each fragment of a chromosome
echo "RUN: loop through samples; count fragment"

for FD_BED in ${FD_BEDS[@]}; do
    SAMPLE=$(basename ${FD_BED})
    FD_OUT=${FD_WRK}/coverage/${SAMPLE}
    FN_OUT=${TARGET}_perbase.txt
    
    ### START Message
    echo ++++++++++++++++++++++++++++++++++++++++++++++++
    echo "Input  file: " ${FD_BED}/${FN_BED}
    echo "Output file: " ${FD_OUT}/${FN_OUT}
    echo
    echo "Show the first few lines of the input file"
    echo ${FD_BED}/${FN_BED}
    head -n 5 ${FD_BED}/${FN_BED}
    echo
    echo "Show the last few lines of the input file"
    echo ${FD_BED}/${FN_BED}
    tail -n 5 ${FD_BED}/${FN_BED}
    echo
    
    ### init: create output folder if not exist
    mkdir -p ${FD_OUT}
    
    ### run: Bedtools genomecov -d to get coverage per base
    echo "Get coverage per base"
    bedtools genomecov -i ${FD_BED}/${FN_BED} -g ${FD_GEN}/${FN_GEN} -d > ${FD_OUT}/${FN_OUT}
    echo
    
    ### END Message
    echo "Show the first few lines of the output file"
    echo ${FD_OUT}/${FN_OUT}
    head -n 5 ${FD_OUT}/${FN_OUT}
    echo
    echo "Show the last few lines of the output file"
    echo ${FD_OUT}/${FN_OUT}
    tail -n 5 ${FD_OUT}/${FN_OUT}
    echo
done
echo "Done!"

EOF
# Out:
# You are on Duke Server: DCC
# BASE DIRECTORY:     /work/kk319
# WORK DIRECTORY:     /work/kk319/out/CombEffect_STARR
# LOG  DIRECTORY:     /work/kk319/out/CombEffect_STARR/log
# PATH OF SOURCE:     /work/kk319/source
# PATH OF EXECUTABLE: /work/kk319/exe
# PATH OF ANNOTATION: /work/kk319/annotation
#
# You are on Duke Server: DCC
# Bedtools 2.27.1
# >Submitted batch job 15006846

# %% [markdown]
# **CHECK**

# %%
readlink -f ${FD_LOG}/coverage_chrom.0.txt
# Out:
# /work/kk319/out/CombEffect_STARR/log/coverage_chrom.0.txt

# %%
cat ${FD_LOG}/coverage_perbase_chrom.0.txt
# Out:
# You are on Duke Server: DCC
# BASE DIRECTORY:     /work/kk319
# WORK DIRECTORY:     /work/kk319/out/CombEffect_STARR
# LOG  DIRECTORY:     /work/kk319/out/CombEffect_STARR/log
# PATH OF SOURCE:     /work/kk319/source
# PATH OF EXECUTABLE: /work/kk319/exe
# PATH OF ANNOTATION: /work/kk319/annotation
#
# Slurm Array Index:  0
# RUN: loop through samples; count fragment
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/Input//chr1.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/Input/chr1_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input//chr1.bed
# chr1	13868	14793
# chr1	14843	15828
# chr1	14868	15889
# chr1	14875	15723
# chr1	16771	17773
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input//chr1.bed
# chr1	248944005	248944992
# chr1	248944015	248944963
# chr1	248944029	248944962
# chr1	248944048	248944948
# chr1	248945363	248946213
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input/chr1_perbase.txt
# chr1	1	0
# chr1	2	0
# chr1	3	0
# chr1	4	0
# chr1	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input/chr1_perbase.txt
# chr1	248956418	0
# chr1	248956419	0
# chr1	248956420	0
# chr1	248956421	0
# chr1	248956422	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/Input1//chr1.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/Input1/chr1_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input1//chr1.bed
# chr1	13868	14793
# chr1	17394	18269
# chr1	17394	18268
# chr1	17396	18259
# chr1	17405	18377
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input1//chr1.bed
# chr1	248938314	248939220
# chr1	248938332	248939275
# chr1	248938349	248939181
# chr1	248940579	248941600
# chr1	248945363	248946213
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input1/chr1_perbase.txt
# chr1	1	0
# chr1	2	0
# chr1	3	0
# chr1	4	0
# chr1	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input1/chr1_perbase.txt
# chr1	248956418	0
# chr1	248956419	0
# chr1	248956420	0
# chr1	248956421	0
# chr1	248956422	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/Input2//chr1.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/Input2/chr1_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input2//chr1.bed
# chr1	14843	15828
# chr1	14875	15723
# chr1	16771	17773
# chr1	17394	18299
# chr1	17411	18388
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input2//chr1.bed
# chr1	248938227	248939114
# chr1	248938341	248939281
# chr1	248940573	248941617
# chr1	248942876	248943721
# chr1	248943613	248944645
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input2/chr1_perbase.txt
# chr1	1	0
# chr1	2	0
# chr1	3	0
# chr1	4	0
# chr1	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input2/chr1_perbase.txt
# chr1	248956418	0
# chr1	248956419	0
# chr1	248956420	0
# chr1	248956421	0
# chr1	248956422	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/Input3//chr1.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/Input3/chr1_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input3//chr1.bed
# chr1	14868	15889
# chr1	17400	18408
# chr1	17410	18497
# chr1	17415	18237
# chr1	17416	18428
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input3//chr1.bed
# chr1	248934176	248935071
# chr1	248934216	248935135
# chr1	248937501	248938408
# chr1	248937501	248938408
# chr1	248938304	248939520
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input3/chr1_perbase.txt
# chr1	1	0
# chr1	2	0
# chr1	3	0
# chr1	4	0
# chr1	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/Input3/chr1_perbase.txt
# chr1	248956418	0
# chr1	248956419	0
# chr1	248956420	0
# chr1	248956421	0
# chr1	248956422	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/Input4//chr1.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/Input4/chr1_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input4//chr1.bed
# chr1	17394	18269
# chr1	17437	18425
# chr1	17445	18435
# chr1	17452	18370
# chr1	17452	18351
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/Input4//chr1.bed
# chr1	248942992	248943960
# chr1	248943629	248944689
# chr1	248943640	248944605
# chr1	248944005	248944992
# chr1	248944048	248944948
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/TFX5_Dex//chr17.bed
# chr17	83231480	83232513
# chr17	83231480	83232514
# chr17	83231480	83232514
# chr17	83232322	83233346
# chr17	83237312	83238135
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX5_Dex/chr17_perbase.txt
# chr17	1	0
# chr17	2	0
# chr17	3	0
# chr17	4	0
# chr17	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX5_Dex/chr17_perbase.txt
# chr17	83257437	0
# chr17	83257438	0
# chr17	83257439	0
# chr17	83257440	0
# chr17	83257441	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/TFX_DMSO//chr17.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/TFX_DMSO/chr17_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/TFX_DMSO//chr17.bed
# chr17	87067	87989
# chr17	101601	102522
# chr17	158043	159066
# chr17	158043	159067
# chr17	159137	160020
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/TFX_DMSO//chr17.bed
# chr17	83237597	83238624
# chr17	83237599	83238503
# chr17	83237983	83238892
# chr17	83241042	83242975
# chr17	83241050	83242965
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX_DMSO/chr17_perbase.txt
# chr17	1	0
# chr17	2	0
# chr17	3	0
# chr17	4	0
# chr17	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX_DMSO/chr17_perbase.txt
# chr17	83257437	0
# chr17	83257438	0
# chr17	83257439	0
# chr17	83257440	0
# chr17	83257441	0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++
# Input  file:  /work/kk319/out/CombEffect_STARR/data/TFX_Dex//chr17.bed
# Output file:  /work/kk319/out/CombEffect_STARR/coverage/TFX_Dex/chr17_perbase.txt
#
# Show the first few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/TFX_Dex//chr17.bed
# chr17	70104	71559
# chr17	83638	84547
# chr17	92503	93508
# chr17	120738	123102
# chr17	152554	153491
#
# Show the last few lines of the input file
# /work/kk319/out/CombEffect_STARR/data/TFX_Dex//chr17.bed
# chr17	83232457	83233384
# chr17	83232459	83233384
# chr17	83233573	83234523
# chr17	83237312	83238135
# chr17	83242548	83243535
#
# Get coverage per base
#
# Show the first few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX_Dex/chr17_perbase.txt
# chr17	1	0
# chr17	2	0
# chr17	3	0
# chr17	4	0
# chr17	5	0
#
# Show the last few lines of the output file
# /work/kk319/out/CombEffect_STARR/coverage/TFX_Dex/chr17_perbase.txt
# chr17	83257437	0
# chr17	83257438	0
# chr17	83257439	0
# chr17	83257440	0
# chr17	83257441	0
#
# Done!

# %%
tail -n 3 ${FD_LOG}/coverage_perbase_chrom.*.txt
# Out:
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.0.txt <==
# chr1	248956422	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.1.txt <==
# chr2	242193529	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.10.txt <==
# chr11	135086622	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.11.txt <==
# chr12	133275309	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.12.txt <==
# chr13	114364328	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.13.txt <==
# chr14	107043718	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.14.txt <==
# chr15	101991189	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.15.txt <==
# chr16	90338345	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.16.txt <==
# chr17	83257441	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.17.txt <==
# chr18	80373285	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.18.txt <==
# chr19	58617616	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.19.txt <==
# chr20	64444167	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.2.txt <==
# chr3	198295559	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.20.txt <==
# chr21	46709983	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.21.txt <==
# chr22	50818468	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.22.txt <==
# chrX	156040895	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.23.txt <==
# chrY	57227415	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.3.txt <==
# chr4	190214555	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.4.txt <==
# chr5	181538259	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.5.txt <==
# chr6	170805979	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.6.txt <==
# chr7	159345973	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.7.txt <==
# chr8	145138636	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.8.txt <==
# chr9	138394717	0
#
# Done!
#
# ==> /work/kk319/out/CombEffect_STARR/log/coverage_perbase_chrom.9.txt <==
# chr10	133797422	0
#
# Done!
