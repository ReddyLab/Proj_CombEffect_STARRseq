# %%
source ../config_duke.sh
# Out:
# You are on Duke Server: DCC
# BASE DIRECTORY:     /work/kk319
# WORK DIRECTORY:     /work/kk319/out/CombEffect_STARR
# LOG  DIRECTORY:     /work/kk319/out/CombEffect_STARR/log
# PATH OF SOURCE:     /work/kk319/source
# PATH OF EXECUTABLE: /work/kk319/exe
# PATH OF ANNOTATION: /work/kk319/annotation

# %%
FDIRY=${FD_WRK}/coverage
ls ${FDIRY}/*/*bedpe
# Out:
# /work/kk319/out/CombEffect_STARR/coverage/Input1/Input1.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/Input2/Input2.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/Input3/Input3.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/Input4/Input4.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/Input5/Input5.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX2_DMSO/TFX2_DMSO.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX2_Dex/TFX2_Dex.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX3_DMSO/TFX3_DMSO.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX3_Dex/TFX3_Dex.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX4_DMSO/TFX4_DMSO.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX4_Dex/TFX4_Dex.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX5_DMSO/TFX5_DMSO.bedpe
# /work/kk319/out/CombEffect_STARR/coverage/TFX5_Dex/TFX5_Dex.bedpe

# %%
cd ${FDIRY}
ls */*bedpe
# Out:
# Input1/Input1.bedpe  TFX2_DMSO/TFX2_DMSO.bedpe  TFX4_Dex/TFX4_Dex.bedpe
# Input2/Input2.bedpe  TFX2_Dex/TFX2_Dex.bedpe    TFX5_DMSO/TFX5_DMSO.bedpe
# Input3/Input3.bedpe  TFX3_DMSO/TFX3_DMSO.bedpe  TFX5_Dex/TFX5_Dex.bedpe
# Input4/Input4.bedpe  TFX3_Dex/TFX3_Dex.bedpe
# Input5/Input5.bedpe  TFX4_DMSO/TFX4_DMSO.bedpe

# %%
cd ${FDIRY}
tar -czvf bedgraph_samples.tar.gz */*bedpe
# Out:
# Input1/Input1.bedpe
# Input2/Input2.bedpe
# Input3/Input3.bedpe
# Input4/Input4.bedpe
# Input5/Input5.bedpe
# TFX2_DMSO/TFX2_DMSO.bedpe
# TFX2_Dex/TFX2_Dex.bedpe
# TFX3_DMSO/TFX3_DMSO.bedpe
# TFX3_Dex/TFX3_Dex.bedpe
# TFX4_DMSO/TFX4_DMSO.bedpe
# TFX4_Dex/TFX4_Dex.bedpe
# TFX5_DMSO/TFX5_DMSO.bedpe
# TFX5_Dex/TFX5_Dex.bedpe

# %%
cd ${FDIRY}
ls Input?/*bedgraph
# Out:
# Input1/chr1.bedgraph         Input2/chr4.bedgraph   Input4/chr18.bedgraph
# Input1/chr10.bedgraph        Input2/chr5.bedgraph   Input4/chr19.bedgraph
# Input1/chr11.bedgraph        Input2/chr6.bedgraph   Input4/chr2.bedgraph
# Input1/chr12.bedgraph        Input2/chr7.bedgraph   Input4/chr20.bedgraph
# Input1/chr13.bedgraph        Input2/chr8.bedgraph   Input4/chr21.bedgraph
# Input1/chr14.bedgraph        Input2/chr9.bedgraph   Input4/chr22.bedgraph
# Input1/chr15.bedgraph        Input2/chrX.bedgraph   Input4/chr3.bedgraph
# Input1/chr16.bedgraph        Input2/chrY.bedgraph   Input4/chr4.bedgraph
# Input1/chr17.bedgraph        Input3/chr1.bedgraph   Input4/chr5.bedgraph
# Input1/chr18.bedgraph        Input3/chr10.bedgraph  Input4/chr6.bedgraph
# Input1/chr19.bedgraph        Input3/chr11.bedgraph  Input4/chr7.bedgraph
# Input1/chr2.bedgraph         Input3/chr12.bedgraph  Input4/chr8.bedgraph
# Input1/chr20.bedgraph        Input3/chr13.bedgraph  Input4/chr9.bedgraph
# ...

# %%
cd ${FDIRY}
tar -czvf bedgraph_chrom_input.tar.gz Input?/*bedgraph
# Out:
# Input1/chr1.bedgraph
# Input1/chr10.bedgraph
# Input1/chr11.bedgraph
# Input1/chr12.bedgraph
# Input1/chr13.bedgraph
# Input1/chr14.bedgraph
# Input1/chr15.bedgraph
# Input1/chr16.bedgraph
# Input1/chr17.bedgraph
# Input1/chr18.bedgraph
# Input1/chr19.bedgraph
# Input1/chr2.bedgraph
# Input1/chr20.bedgraph
# Input1/chr21.bedgraph
# Input1/chr22.bedgraph
# Input1/chr3.bedgraph
# Input1/chr4.bedgraph
# Input1/chr5.bedgraph
# Input1/chr6.bedgraph
# Input1/chr7.bedgraph
# Input1/chr8.bedgraph
# Input1/chr9.bedgraph
# Input1/chrX.bedgraph
# Input1/chrY.bedgraph
# Input1/target_PER1.bedgraph
# Input2/chr1.bedgraph
# Input2/chr10.bedgraph
# Input2/chr11.bedgraph
# Input2/chr12.bedgraph
# Input2/chr13.bedgraph
# Input2/chr14.bedgraph
# Input2/chr15.bedgraph
# Input2/chr16.bedgraph
# Input2/chr17.bedgraph
# Input2/chr18.bedgraph
# Input2/chr19.bedgraph
# Input2/chr2.bedgraph
# Input2/chr20.bedgraph
# Input2/chr21.bedgraph
# Input2/chr22.bedgraph
# Input2/chr3.bedgraph
# Input2/chr4.bedgraph
# ...

# %%
cd ${FDIRY}
tar -czvf bedgraph_chrom_output_dmso.tar.gz TFX?_DMSO/*bedgraph
# Out:
# TFX2_DMSO/chr1.bedgraph
# TFX2_DMSO/chr10.bedgraph
# TFX2_DMSO/chr11.bedgraph
# TFX2_DMSO/chr12.bedgraph
# TFX2_DMSO/chr13.bedgraph
# TFX2_DMSO/chr14.bedgraph
# TFX2_DMSO/chr15.bedgraph
# TFX2_DMSO/chr16.bedgraph
# TFX2_DMSO/chr17.bedgraph
# TFX2_DMSO/chr18.bedgraph
# TFX2_DMSO/chr19.bedgraph
# TFX2_DMSO/chr2.bedgraph
# TFX2_DMSO/chr20.bedgraph
# TFX2_DMSO/chr21.bedgraph
# TFX2_DMSO/chr22.bedgraph
# TFX2_DMSO/chr3.bedgraph
# TFX2_DMSO/chr4.bedgraph
# TFX2_DMSO/chr5.bedgraph
# TFX2_DMSO/chr6.bedgraph
# TFX2_DMSO/chr7.bedgraph
# TFX2_DMSO/chr8.bedgraph
# TFX2_DMSO/chr9.bedgraph
# TFX2_DMSO/chrX.bedgraph
# TFX2_DMSO/chrY.bedgraph
# TFX3_DMSO/chr1.bedgraph
# TFX3_DMSO/chr10.bedgraph
# TFX3_DMSO/chr11.bedgraph
# TFX3_DMSO/chr12.bedgraph
# TFX3_DMSO/chr13.bedgraph
# TFX3_DMSO/chr14.bedgraph
# TFX3_DMSO/chr15.bedgraph
# TFX3_DMSO/chr16.bedgraph
# TFX3_DMSO/chr17.bedgraph
# TFX3_DMSO/chr18.bedgraph
# TFX3_DMSO/chr19.bedgraph
# TFX3_DMSO/chr2.bedgraph
# TFX3_DMSO/chr20.bedgraph
# ...

# %%
cd ${FDIRY}
tar -czvf bedgraph_chrom_output_dex.tar.gz TFX?_Dex/*bedgraph
# Out:
# TFX2_Dex/chr1.bedgraph
# TFX2_Dex/chr10.bedgraph
# TFX2_Dex/chr11.bedgraph
# TFX2_Dex/chr12.bedgraph
# TFX2_Dex/chr13.bedgraph
# TFX2_Dex/chr14.bedgraph
# TFX2_Dex/chr15.bedgraph
# TFX2_Dex/chr16.bedgraph
# TFX2_Dex/chr17.bedgraph
# TFX2_Dex/chr18.bedgraph
# TFX2_Dex/chr19.bedgraph
# TFX2_Dex/chr2.bedgraph
# TFX2_Dex/chr20.bedgraph
# TFX2_Dex/chr21.bedgraph
# TFX2_Dex/chr22.bedgraph
# TFX2_Dex/chr3.bedgraph
# TFX2_Dex/chr4.bedgraph
# TFX2_Dex/chr5.bedgraph
# TFX2_Dex/chr6.bedgraph
# TFX2_Dex/chr7.bedgraph
# TFX2_Dex/chr8.bedgraph
# TFX2_Dex/chr9.bedgraph
# TFX2_Dex/chrX.bedgraph
# TFX2_Dex/chrY.bedgraph
# TFX3_Dex/chr1.bedgraph
# TFX3_Dex/chr10.bedgraph
# TFX3_Dex/chr11.bedgraph
# TFX3_Dex/chr12.bedgraph
# TFX3_Dex/chr13.bedgraph
# TFX3_Dex/chr14.bedgraph
# TFX3_Dex/chr15.bedgraph
# TFX3_Dex/chr16.bedgraph
# TFX3_Dex/chr17.bedgraph
# TFX3_Dex/chr18.bedgraph
# TFX3_Dex/chr19.bedgraph
# TFX3_Dex/chr2.bedgraph
# TFX3_Dex/chr20.bedgraph
# TFX3_Dex/chr21.bedgraph
# ...

# %%
du -sh
# Out:
# 1.1T	.
